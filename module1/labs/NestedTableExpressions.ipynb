# %% [markdown]
# # Nested Table Expressions
#
# **A third type of nested query!**
#
#
# Recall the Nested Table Expresion (aka Derived Table)
#
# ```SQL
# SELECT <col_list_a>
# FROM (
#     SELECT <col_list_b>
#     FROM <table_expressions_list>
#     WHERE ...
#     ) as <derived_table_alias>
# WHERE <row_constraints>
# ```
#
# ... also our examples.
#
# ** Example** from our DVD Rental database.
#
# How many movies have been rented more than four times?
#
# ```SQL
# SELECT COUNT(*)
# FROM (
#     SELECT inventory_id, COUNT(*)
#     FROM rental
#     GROUP BY inventory_id
#     HAVING COUNT(*) > 4
#     ) as rent_counts;
#
#  count
# -------
#   1139
# (1 row)
# ```
#
# Or, the actual Movie names?
#
# ```SQL
# SELECT i.film_id, f.title
# FROM film f
# JOIN inventory as i USING (film_id)
# NATURAL JOIN (
#     SELECT inventory_id, COUNT(*)
#     FROM rental
#     GROUP BY inventory_id
#     HAVING COUNT(*) > 4
#     ) as rent_counts;
# ```

# %%
# %load_ext sql
# %sql postgres://dsa_ro_user:readonly@dbase.dsa.missouri.edu/dvdrental
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: dsa_ro_user@dvdrental'

# %% [markdown]
# ## Use-Case: Multilevel Aggregation
#
# A typical use of the subquery table expession is the multilevel aggregation.
# Structurally, we have a nested query with an aggreation, then we compute aggregates over that sub-query or use it to constrain the data in some other way.
#
# ```SQL
# SELECT <aggr_f2(alias.aggr_col)>
# FROM (
#     SELECT <aggr_f1()> as aggr_col
#     FROM ...
#     ) as <alias>
# ```
#
# ### Example 1
#
# In the example below we are generating a table expression of `inventory_id, count` where `count > 4`.
# From that intermediate result, we are counting the rows.

# %%
# %%sql
# EXPLAIN ANALYZE
# SELECT COUNT(*)
# FROM (
#     SELECT inventory_id, COUNT(*)
#     FROM rental
#     GROUP BY inventory_id
#     HAVING COUNT(*) > 4
#     ) as rent_counts;
# Out:
# 8 rows affected.
# [('Aggregate  (cost=505.16..505.17 rows=1 width=0) (actual time=17.944..17.944 rows=1 loops=1)',),
#  ('  ->  HashAggregate  (cost=390.66..447.91 rows=4580 width=4) (actual time=17.352..17.862 rows=1139 loops=1)',),
#  ('        Group Key: rental.inventory_id',),
#  ('        Filter: (count(*) > 4)',),
#  ('        Rows Removed by Filter: 3441',),
#  ('        ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=4) (actual time=0.026..7.427 rows=16044 loops=1)',),
#  ('Planning time: 1.450 ms',),
#  ('Execution time: 18.392 ms',)]

# %%
# %%sql
# SELECT COUNT(*)
# FROM (
#     SELECT inventory_id, COUNT(*)
#     FROM rental
#     GROUP BY inventory_id
#     HAVING COUNT(*) > 4
#     ) as rent_counts;
# Out:
# 1 rows affected.
# [(1139,)]

# %% [markdown]
# Notice in the above query, we must supply a table alias to the derived table.
#
# ### Example 2
#
# These queries can become more complex, involving a mix of traditional tables and table expressions.

# %%
# %%sql
# EXPLAIN ANALYZE
# SELECT i.film_id, f.title
# FROM film f
# JOIN inventory as i USING (film_id)
# NATURAL JOIN (
#     SELECT inventory_id, COUNT(*)
#     FROM rental
#     GROUP BY inventory_id
#     HAVING COUNT(*) > 4
#     ) as rent_counts;
# Out:
# 17 rows affected.
# [('Hash Join  (cost=595.23..824.23 rows=4580 width=17) (actual time=16.883..18.461 rows=1139 loops=1)',),
#  ('  Hash Cond: (i.film_id = f.film_id)',),
#  ('  ->  Hash Join  (cost=518.73..684.76 rows=4580 width=2) (actual time=13.757..14.926 rows=1139 loops=1)',),
#  ('        Hash Cond: (rental.inventory_id = i.inventory_id)',),
#  ('        ->  HashAggregate  (cost=390.66..447.91 rows=4580 width=4) (actual time=9.449..10.062 rows=1139 loops=1)',),
#  ('              Group Key: rental.inventory_id',),
#  ('              Filter: (count(*) > 4)',),
#  ('              Rows Removed by Filter: 3441',),
#  ('              ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=4) (actual time=0.023..2.938 rows=16044 loops=1)',),
#  ('        ->  Hash  (cost=70.81..70.81 rows=4581 width=6) (actual time=4.179..4.179 rows=4581 loops=1)',),
#  ('              Buckets: 8192  Batches: 1  Memory Usage: 243kB',),
#  ('              ->  Seq Scan on inventory i  (cost=0.00..70.81 rows=4581 width=6) (actual time=0.040..2.232 rows=4581 loops=1)',),
#  ('  ->  Hash  (cost=64.00..64.00 rows=1000 width=19) (actual time=3.056..3.056 rows=1000 loops=1)',),
#  ('        Buckets: 1024  Batches: 1  Memory Usage: 60kB',),
#  ('        ->  Seq Scan on film f  (cost=0.00..64.00 rows=1000 width=19) (actual time=0.018..2.443 rows=1000 loops=1)',),
#  ('Planning time: 2.211 ms',),
#  ('Execution time: 18.812 ms',)]

# %%
# %%sql
# SELECT i.film_id, f.title
# FROM film f
# JOIN inventory as i USING (film_id)
# NATURAL JOIN (
#     SELECT inventory_id, COUNT(*)
#     FROM rental
#     GROUP BY inventory_id
#     HAVING COUNT(*) > 4
#     ) as rent_counts;
# Out:
# 1139 rows affected.
# [(440, 'Hunger Roof'),
#  (976, 'Wind Phantom'),
#  (130, 'Celebrity Horn'),
#  (388, 'Gunfight Moon'),
#  (486, 'Jet Neighbors'),
#  (797, 'Silence Kane'),
#  (6, 'Agent Truman'),
#  (738, 'Rocketeer Mother'),
#  (272, 'Edge Kissing'),
#  (958, 'Wardrobe Phantom'),
#  (247, 'Downhill Enough'),
#  (958, 'Wardrobe Phantom'),
#  (535, 'Love Suicides'),
#  (873, 'Sweethearts Suspects'),
#  (4, 'Affair Prejudice'),
#  (29, 'Antitrust Tomatoes'),
#  (435, 'Hotel Happiness'),
#  (387, 'Gun Bonnie'),
#  (778, 'Secrets Paradise'),
#  (203, 'Daisy Menagerie'),
#  (668, 'Peak Forever'),
#  (301, 'Family Sweet'),
#  (142, 'Chicken Hellfighters'),
#  (891, 'Timberland Sky'),
#  (101, 'Brotherhood Blanket'),
#  (443, 'Hurricane Affair'),
#  (778, 'Secrets Paradise'),
#  (15, 'Alien Center'),
#  (711, 'Raging Airplane'),
#  (280, 'Empire Malkovich'),
#  (951, 'Voyage Legally'),
#  (63, 'Bedazzled Married'),
#  (252, 'Dream Pickup'),
#  (661, 'Past Suicides'),
#  (391, 'Half Outfield'),
#  (28, 'Anthem Luke'),
#  (856, 'Streetcar Intentions'),
#  (429, 'Honey Ties'),
#  (764, 'Saturday Lambs'),
#  (518, 'Liaisons Sweet'),
#  (743, 'Room Roman'),
#  (478, 'Jaws Harry'),
#  (867, 'Super Wyoming'),
#  (843, 'Steel Santa'),
#  (155, 'Cleopatra Devil'),
#  (471, 'Island Exorcist'),
#  (621, 'Network Peak'),
#  (114, 'Camelot Vacation'),
#  (973, 'Wife Turn'),
#  (650, 'Pacific Amistad'),
#  (854, 'Strangers Graffiti'),
#  (132, 'Chainsaw Uptown'),
#  (274, 'Egg Igby'),
#  (465, 'Interview Liaisons'),
#  (116, 'Candidate Perdition'),
#  (514, 'Lebowski Soldiers'),
#  (741, 'Roman Punk'),
#  (715, 'Range Moonwalker'),
#  (782, 'Shakespeare Saddle'),
#  (961, 'Wash Heavenly'),
#  (851, 'Straight Hours'),
#  (572, 'Metropolis Coma'),
#  (206, 'Dancing Fever'),
#  (823, 'South Wait'),
#  (489, 'Juggler Hardly'),
#  (445, 'Hyde Doctor'),
#  (103, 'Bucket Brotherhood'),
#  (561, 'Mask Peach'),
#  (994, 'Wyoming Storm'),
#  (561, 'Mask Peach'),
#  (529, 'Lonely Elephant'),
#  (410, 'Heaven Freedom'),
#  (425, 'Holy Tadpole'),
#  (609, 'Muscle Bright'),
#  (348, 'Gandhi Kwai'),
#  (12, 'Alaska Phantom'),
#  (555, 'Mallrats United'),
#  (86, 'Boogie Amelie'),
#  (589, 'Modern Dorado'),
#  (725, 'Requiem Tycoon'),
#  (664, 'Patriot Roman'),
#  (176, 'Congeniality Quest'),
#  (891, 'Timberland Sky'),
#  (908, 'Trap Guys'),
#  (496, 'Kick Savannah'),
#  (920, 'Unbreakable Karate'),
#  (698, 'Princess Giant'),
#  (314, 'Fight Jawbreaker'),
#  (604, 'Mulan Moon'),
#  (290, 'Everyone Craft'),
#  (162, 'Clueless Bucket'),
#  (753, 'Rush Goodfellas'),
#  (167, 'Coma Head'),
#  (415, 'High Encino'),
#  (750, 'Run Pacific'),
#  (872, 'Sweet Brotherhood'),
#  (792, 'Shrek License'),
#  (156, 'Clerks Angels'),
#  (173, 'Confessions Maguire'),
#  (437, 'House Dynamite'),
#  (167, 'Coma Head'),
#  (991, 'Worst Banger'),
#  (327, 'Fool Mockingbird'),
#  (272, 'Edge Kissing'),
#  (621, 'Network Peak'),
#  (366, 'Goldfinger Sensibility'),
#  (826, 'Speed Suit'),
#  (520, 'License Weekend'),
#  (487, 'Jingle Sagebrush'),
#  (898, 'Tourist Pelican'),
#  (816, 'Snowman Rollercoaster'),
#  (135, 'Chance Resurrection'),
#  (411, 'Heavenly Gun'),
#  (331, 'Forward Temple'),
#  (639, 'Opposite Necklace'),
#  (766, 'Savannah Town'),
#  (142, 'Chicken Hellfighters'),
#  (129, 'Cause Date'),
#  (552, 'Majestic Floats'),
#  (230, 'Diary Panic'),
#  (931, 'Valentine Vanishing'),
#  (651, 'Packer Madigan'),
#  (776, 'Secret Groundhog'),
#  (164, 'Coast Rainbow'),
#  (26, 'Annie Identity'),
#  (119, 'Caper Motions'),
#  (744, 'Roots Remember'),
#  (314, 'Fight Jawbreaker'),
#  (131, 'Center Dinosaur'),
#  (140, 'Cheaper Clyde'),
#  (265, 'Dying Maker'),
#  (705, 'Purple Movie'),
#  (509, 'Language Cowboy'),
#  (951, 'Voyage Legally'),
#  (587, 'Mod Secretary'),
#  (73, 'Bingo Talented'),
#  (531, 'Lose Inch'),
#  (395, 'Handicap Boondock'),
#  (982, 'Women Dorado'),
#  (417, 'Hills Neighbors'),
#  (578, 'Million Ace'),
#  (560, 'Mars Roman'),
#  (771, 'Scorpion Apollo'),
#  (945, 'Virginian Pluto'),
#  (304, 'Fargo Gandhi'),
#  (736, 'Robbery Bright'),
#  (849, 'Storm Happiness'),
#  (182, 'Control Anthem'),
#  (807, 'Sleuth Orient'),
#  (271, 'Easy Gladiator'),
#  (413, 'Hedwig Alter'),
#  (625, 'None Spiking'),
#  (938, 'Velvet Terminator'),
#  (968, 'Werewolf Lola'),
#  (54, 'Banger Pinocchio'),
#  (347, 'Games Bowfinger'),
#  (288, 'Escape Metropolis'),
#  (878, 'Teen Apollo'),
#  (417, 'Hills Neighbors'),
#  (962, 'Wasteland Divine'),
#  (52, 'Ballroom Mockingbird'),
#  (442, 'Hunting Musketeers'),
#  (416, 'Highball Potter'),
#  (254, 'Driver Annie'),
#  (208, 'Dares Pluto'),
#  (401, 'Harold French'),
#  (331, 'Forward Temple'),
#  (141, 'Chicago North'),
#  (994, 'Wyoming Storm'),
#  (187, 'Cranes Reservoir'),
#  (219, 'Deep Crusade'),
#  (426, 'Home Pity'),
#  (463, 'Instinct Airport'),
#  (618, 'Necklace Outbreak'),
#  (317, 'Fireball Philadelphia'),
#  (387, 'Gun Bonnie'),
#  (521, 'Lies Treatment'),
#  (158, 'Clones Pinocchio'),
#  (893, 'Titans Jerk'),
#  (741, 'Roman Punk'),
#  (492, 'Jungle Closer'),
#  (142, 'Chicken Hellfighters'),
#  (267, 'Eagles Panky'),
#  (127, 'Cat Coneheads'),
#  (390, 'Guys Falcon'),
#  (641, 'Orange Grapes'),
#  (395, 'Handicap Boondock'),
#  (559, 'Married Go'),
#  (775, 'Seattle Expecations'),
#  (433, 'Horn Working'),
#  (717, 'Rear Trading'),
#  (967, 'Weekend Personal'),
#  (26, 'Annie Identity'),
#  (451, 'Igby Maker'),
#  (78, 'Blackout Private'),
#  (140, 'Cheaper Clyde'),
#  (216, 'Day Unfaithful'),
#  (345, 'Gables Metropolis'),
#  (818, 'Something Duck'),
#  (244, 'Dorado Notting'),
#  (19, 'Amadeus Holy'),
#  (164, 'Coast Rainbow'),
#  (334, 'Freddy Storm'),
#  (887, 'Thief Pelican'),
#  (575, 'Midsummer Groundhog'),
#  (251, 'Dragonfly Strangers'),
#  (491, 'Jumping Wrath'),
#  (154, 'Clash Freddy'),
#  (757, 'Sagebrush Clueless'),
#  (841, 'Star Operation'),
#  (898, 'Tourist Pelican'),
#  (791, 'Show Lord'),
#  (151, 'Cincinatti Whisperer'),
#  (86, 'Boogie Amelie'),
#  (45, 'Attraction Newton'),
#  (494, 'Karate Moon'),
#  (304, 'Fargo Gandhi'),
#  (150, 'Cider Desire'),
#  (609, 'Muscle Bright'),
#  (474, 'Jade Bunch'),
#  (388, 'Gunfight Moon'),
#  (382, 'Grit Clockwork'),
#  (572, 'Metropolis Coma'),
#  (367, 'Goldmine Tycoon'),
#  (688, 'Polish Brooklyn'),
#  (744, 'Roots Remember'),
#  (863, 'Sun Confessions'),
#  (361, 'Gleaming Jawbreaker'),
#  (929, 'Usual Untouchables'),
#  (735, 'Robbers Joon'),
#  (266, 'Dynamite Tarzan'),
#  (417, 'Hills Neighbors'),
#  (614, 'Name Detective'),
#  (277, 'Elephant Trojan'),
#  (160, 'Club Graffiti'),
#  (882, 'Tenenbaums Command'),
#  (515, 'Legally Secretary'),
#  (284, 'Enemy Odds'),
#  (681, 'Pirates Roxanne'),
#  (78, 'Blackout Private'),
#  (59, 'Bear Graceland'),
#  (84, 'Boiled Dares'),
#  (881, 'Temple Attraction'),
#  (948, 'Voice Peach'),
#  (966, 'Wedding Apollo'),
#  (81, 'Blindness Gun'),
#  (804, 'Sleeping Suspects'),
#  (945, 'Virginian Pluto'),
#  (90, 'Boulevard Mob'),
#  (159, 'Closer Bang'),
#  (253, 'Drifter Commandments'),
#  (82, 'Blood Argonauts'),
#  (300, 'Falcon Volume'),
#  (676, 'Philadelphia Wife'),
#  (646, 'Outbreak Divine'),
#  (539, 'Luck Opus'),
#  (869, 'Suspects Quills'),
#  (963, 'Watch Tracy'),
#  (706, 'Queen Luke'),
#  (670, 'Pelican Comforts'),
#  (55, 'Barbarella Streetcar'),
#  (971, 'Whale Bikini'),
#  (870, 'Swarm Gold'),
#  (442, 'Hunting Musketeers'),
#  (174, 'Confidential Interview'),
#  (496, 'Kick Savannah'),
#  (588, 'Model Fish'),
#  (268, 'Early Home'),
#  (287, 'Entrapment Satisfaction'),
#  (484, 'Jerk Paycheck'),
#  (854, 'Strangers Graffiti'),
#  (220, 'Deer Virginian'),
#  (309, 'Feud Frogmen'),
#  (18, 'Alter Victory'),
#  (573, 'Microcosmos Paradise'),
#  (600, 'Motions Details'),
#  (174, 'Confidential Interview'),
#  (646, 'Outbreak Divine'),
#  (571, 'Metal Armageddon'),
#  (667, 'Peach Innocent'),
#  (489, 'Juggler Hardly'),
#  (973, 'Wife Turn'),
#  (285, 'English Bulworth'),
#  (680, 'Pinocchio Simon'),
#  (1000, 'Zorro Ark'),
#  (273, 'Effect Gladiator'),
#  (870, 'Swarm Gold'),
#  (533, 'Lost Bird'),
#  (702, 'Pulp Beverly'),
#  (23, 'Anaconda Confessions'),
#  (838, 'Stagecoach Armageddon'),
#  (75, 'Bird Independence'),
#  (48, 'Backlash Undefeated'),
#  (82, 'Blood Argonauts'),
#  (346, 'Galaxy Sweethearts'),
#  (417, 'Hills Neighbors'),
#  (768, 'Scarface Bang'),
#  (741, 'Roman Punk'),
#  (543, 'Madigan Dorado'),
#  (631, 'Novocaine Flight'),
#  (488, 'Joon Northwest'),
#  (834, 'Spoilers Hellfighters'),
#  (397, 'Hanky October'),
#  (416, 'Highball Potter'),
#  (285, 'English Bulworth'),
#  (39, 'Armageddon Lost'),
#  (873, 'Sweethearts Suspects'),
#  (746, 'Rouge Squad'),
#  (166, 'Color Philadelphia'),
#  (31, 'Apache Divine'),
#  (439, 'Hunchback Impossible'),
#  (378, 'Greatest North'),
#  (373, 'Graduate Lord'),
#  (865, 'Sunrise League'),
#  (117, 'Candles Grapes'),
#  (734, 'Road Roxanne'),
#  (915, 'Truman Crazy'),
#  (334, 'Freddy Storm'),
#  (104, 'Bugsy Song'),
#  (179, 'Conquerer Nuts'),
#  (356, 'Giant Troopers'),
#  (927, 'Uprising Uptown'),
#  (745, 'Roses Treasure'),
#  (630, 'Notting Speakeasy'),
#  (685, 'Platoon Instinct'),
#  (174, 'Confidential Interview'),
#  (450, 'Idols Snatchers'),
#  (126, 'Casualties Encino'),
#  (370, 'Gorgeous Bingo'),
#  (249, 'Dracula Crystal'),
#  (708, 'Quills Bull'),
#  (458, 'Indian Love'),
#  (979, 'Witches Panic'),
#  (870, 'Swarm Gold'),
#  (583, 'Mission Zoolander'),
#  (255, 'Driving Polish'),
#  (471, 'Island Exorcist'),
#  (309, 'Feud Frogmen'),
#  (1000, 'Zorro Ark'),
#  (252, 'Dream Pickup'),
#  (80, 'Blanket Beverly'),
#  (738, 'Rocketeer Mother'),
#  (696, 'Pride Alamo'),
#  (450, 'Idols Snatchers'),
#  (803, 'Slacker Liaisons'),
#  (703, 'Punk Divorce'),
#  (504, 'Kwai Homeward'),
#  (693, 'Potter Connecticut'),
#  (303, 'Fantasy Troopers'),
#  (329, 'Forrest Sons'),
#  (998, 'Zhivago Core'),
#  (83, 'Blues Instinct'),
#  (555, 'Mallrats United'),
#  (273, 'Effect Gladiator'),
#  (577, 'Mile Mulan'),
#  (483, 'Jericho Mulan'),
#  (595, 'Moon Bunch'),
#  (403, 'Harry Idaho'),
#  (394, 'Hamlet Wisdom'),
#  (979, 'Witches Panic'),
#  (367, 'Goldmine Tycoon'),
#  (406, 'Haunting Pianist'),
#  (234, 'Disturbing Scarface'),
#  (756, 'Saddle Antitrust'),
#  (347, 'Games Bowfinger'),
#  (109, 'Butterfly Chocolat'),
#  (330, 'Forrester Comancheros'),
#  (762, 'Sassy Packer'),
#  (96, 'Breaking Home'),
#  (452, 'Illusion Amelie'),
#  (184, 'Core Suit'),
#  (479, 'Jedi Beneath'),
#  (650, 'Pacific Amistad'),
#  (864, 'Sundance Invasion'),
#  (849, 'Storm Happiness'),
#  (602, 'Mourning Purple'),
#  (966, 'Wedding Apollo'),
#  (510, 'Lawless Vision'),
#  (344, 'Fury Murder'),
#  (61, 'Beauty Grease'),
#  (16, 'Alley Evolution'),
#  (373, 'Graduate Lord'),
#  (989, 'Working Microcosmos'),
#  (271, 'Easy Gladiator'),
#  (759, 'Salute Apollo'),
#  (822, 'Soup Wisdom'),
#  (966, 'Wedding Apollo'),
#  (759, 'Salute Apollo'),
#  (255, 'Driving Polish'),
#  (941, 'Videotape Arsenic'),
#  (232, 'Dirty Ace'),
#  (51, 'Balloon Homeward'),
#  (522, 'Life Twisted'),
#  (21, 'American Circus'),
#  (640, 'Opus Ice'),
#  (176, 'Congeniality Quest'),
#  (306, 'Feathers Metal'),
#  (412, 'Heavyweights Beast'),
#  (100, 'Brooklyn Desert'),
#  (845, 'Stepmom Dream'),
#  (596, 'Moonshine Cabin'),
#  (745, 'Roses Treasure'),
#  (5, 'African Egg'),
#  (284, 'Enemy Odds'),
#  (812, 'Smoking Barbarella'),
#  (260, 'Dude Blindness'),
#  (299, 'Factory Dragon'),
#  (579, 'Minds Truman'),
#  (556, 'Maltese Hope'),
#  (942, 'Vietnam Smoochy'),
#  (110, 'Cabin Flash'),
#  (305, 'Fatal Haunted'),
#  (995, 'Yentl Idaho'),
#  (240, 'Dolls Rage'),
#  (893, 'Titans Jerk'),
#  (242, 'Doom Dancing'),
#  (949, 'Volcano Texas'),
#  (205, 'Dances None'),
#  (348, 'Gandhi Kwai'),
#  (18, 'Alter Victory'),
#  (169, 'Comforts Rush'),
#  (532, 'Loser Hustler'),
#  (209, 'Darkness War'),
#  (436, 'Hours Rage'),
#  (131, 'Center Dinosaur'),
#  (576, 'Mighty Luck'),
#  (83, 'Blues Instinct'),
#  (206, 'Dancing Fever'),
#  (862, 'Summer Scarface'),
#  (786, 'Shepherd Midsummer'),
#  (726, 'Reservoir Adaptation'),
#  (639, 'Opposite Necklace'),
#  (23, 'Anaconda Confessions'),
#  (526, 'Lock Rear'),
#  (912, 'Trojan Tomorrow'),
#  (850, 'Story Side'),
#  (806, 'Sleepy Japanese'),
#  (551, 'Maiden Home'),
#  (958, 'Wardrobe Phantom'),
#  (424, 'Holocaust Highball'),
#  (462, 'Insider Arizona'),
#  (260, 'Dude Blindness'),
#  (59, 'Bear Graceland'),
#  (504, 'Kwai Homeward'),
#  (451, 'Igby Maker'),
#  (663, 'Patient Sister'),
#  (930, 'Vacation Boondock'),
#  (608, 'Murder Antitrust'),
#  (202, 'Daddy Pittsburgh'),
#  (910, 'Treatment Jekyll'),
#  (728, 'Reunion Witches'),
#  (305, 'Fatal Haunted'),
#  (286, 'Enough Raging'),
#  (770, 'Scissorhands Slums'),
#  (637, 'Open African'),
#  (8, 'Airport Pollock'),
#  (228, 'Detective Vision'),
#  (307, 'Fellowship Autumn'),
#  (414, 'Hellfighters Sierra'),
#  (65, 'Behavior Runaway'),
#  (211, 'Darling Breaking'),
#  (295, 'Expendable Stallion'),
#  (28, 'Anthem Luke'),
#  (29, 'Antitrust Tomatoes'),
#  (103, 'Bucket Brotherhood'),
#  (760, 'Samurai Lion'),
#  (21, 'American Circus'),
#  (15, 'Alien Center'),
#  (563, 'Massacre Usual'),
#  (284, 'Enemy Odds'),
#  (975, 'Willow Tracy'),
#  (617, 'Natural Stock'),
#  (313, 'Fidelity Devil'),
#  (958, 'Wardrobe Phantom'),
#  (563, 'Massacre Usual'),
#  (58, 'Beach Heartbreakers'),
#  (599, 'Mother Oleander'),
#  (159, 'Closer Bang'),
#  (109, 'Butterfly Chocolat'),
#  (578, 'Million Ace'),
#  (593, 'Monterey Labyrinth'),
#  (748, 'Rugrats Shakespeare'),
#  (111, 'Caddyshack Jedi'),
#  (447, 'Ice Crossing'),
#  (724, 'Remember Diary'),
#  (101, 'Brotherhood Blanket'),
#  (226, 'Destiny Saturday'),
#  (767, 'Scalawag Duck'),
#  (999, 'Zoolander Fiction'),
#  (149, 'Christmas Moonshine'),
#  (476, 'Jason Trap'),
#  (57, 'Basic Easy'),
#  (678, 'Pickup Driving'),
#  (496, 'Kick Savannah'),
#  (535, 'Love Suicides'),
#  (89, 'Borrowers Bedazzled'),
#  (588, 'Model Fish'),
#  (645, 'Others Soup'),
#  (634, 'Odds Boogie'),
#  (273, 'Effect Gladiator'),
#  (474, 'Jade Bunch'),
#  (554, 'Malkovich Pet'),
#  (179, 'Conquerer Nuts'),
#  (772, 'Sea Virgin'),
#  (67, 'Berets Agent'),
#  (764, 'Saturday Lambs'),
#  (287, 'Entrapment Satisfaction'),
#  (767, 'Scalawag Duck'),
#  (624, 'Nightmare Chill'),
#  (694, 'Prejudice Oleander'),
#  (244, 'Dorado Notting'),
#  (702, 'Pulp Beverly'),
#  (394, 'Hamlet Wisdom'),
#  (817, 'Soldiers Evolution'),
#  (428, 'Homicide Peach'),
#  (56, 'Barefoot Manchurian'),
#  (317, 'Fireball Philadelphia'),
#  (71, 'Bilko Anonymous'),
#  (692, 'Potluck Mixed'),
#  (810, 'Slums Duck'),
#  (953, 'Wait Cider'),
#  (879, 'Telegraph Voyage'),
#  (738, 'Rocketeer Mother'),
#  (698, 'Princess Giant'),
#  (544, 'Madison Trap'),
#  (46, 'Autumn Crow'),
#  (505, 'Labyrinth League'),
#  (331, 'Forward Temple'),
#  (353, 'Gentlemen Stage'),
#  (598, 'Mosquito Armageddon'),
#  (55, 'Barbarella Streetcar'),
#  (545, 'Madness Attacks'),
#  (603, 'Movie Shakespeare'),
#  (740, 'Rollercoaster Bringing'),
#  (749, 'Rules Human'),
#  (308, 'Ferris Mother'),
#  (878, 'Teen Apollo'),
#  (791, 'Show Lord'),
#  (447, 'Ice Crossing'),
#  (848, 'Stone Fire'),
#  (375, 'Grail Frankenstein'),
#  (50, 'Baked Cleopatra'),
#  (166, 'Color Philadelphia'),
#  (728, 'Reunion Witches'),
#  (132, 'Chainsaw Uptown'),
#  (571, 'Metal Armageddon'),
#  (673, 'Personal Ladybugs'),
#  (279, 'Elizabeth Shane'),
#  (543, 'Madigan Dorado'),
#  (3, 'Adaptation Holes'),
#  (964, 'Waterfront Deliverance'),
#  (719, 'Records Zorro'),
#  (949, 'Volcano Texas'),
#  (933, 'Vampire Whale'),
#  (31, 'Apache Divine'),
#  (285, 'English Bulworth'),
#  (551, 'Maiden Home'),
#  (915, 'Truman Crazy'),
#  (756, 'Saddle Antitrust'),
#  (947, 'Vision Torque'),
#  (239, 'Dogma Family'),
#  (624, 'Nightmare Chill'),
#  (878, 'Teen Apollo'),
#  (241, 'Donnie Alley'),
#  (494, 'Karate Moon'),
#  (912, 'Trojan Tomorrow'),
#  (984, 'Wonderful Drop'),
#  (690, 'Pond Seattle'),
#  (284, 'Enemy Odds'),
#  (502, 'Knock Warlock'),
#  (186, 'Craft Outfield'),
#  (524, 'Lion Uncut'),
#  (290, 'Everyone Craft'),
#  (861, 'Suit Walls'),
#  (810, 'Slums Duck'),
#  (730, 'Ridgemont Submarine'),
#  (505, 'Labyrinth League'),
#  (869, 'Suspects Quills'),
#  (363, 'Go Purple'),
#  (557, 'Manchurian Curtain'),
#  (145, 'Chisum Behavior'),
#  (253, 'Drifter Commandments'),
#  (533, 'Lost Bird'),
#  (413, 'Hedwig Alter'),
#  (687, 'Pocus Pulp'),
#  (727, 'Resurrection Silverado'),
#  (788, 'Ship Wonderland'),
#  (26, 'Annie Identity'),
#  (382, 'Grit Clockwork'),
#  (54, 'Banger Pinocchio'),
#  (560, 'Mars Roman'),
#  (228, 'Detective Vision'),
#  (140, 'Cheaper Clyde'),
#  (582, 'Miracle Virtual'),
#  (684, 'Pizza Jumanji'),
#  (528, 'Lolita World'),
#  (134, 'Champion Flatliners'),
#  (646, 'Outbreak Divine'),
#  (928, 'Uptown Young'),
#  (580, 'Mine Titans'),
#  (521, 'Lies Treatment'),
#  (70, 'Bikini Borrowers'),
#  (130, 'Celebrity Horn'),
#  (374, 'Graffiti Love'),
#  (827, 'Spice Sorority'),
#  (506, 'Lady Stage'),
#  (159, 'Closer Bang'),
#  (103, 'Bucket Brotherhood'),
#  (645, 'Others Soup'),
#  (319, 'Fish Opus'),
#  (212, 'Darn Forrester'),
#  (247, 'Downhill Enough'),
#  (158, 'Clones Pinocchio'),
#  (905, 'Trainspotting Strangers'),
#  (68, 'Betrayed Rear'),
#  (251, 'Dragonfly Strangers'),
#  (805, 'Sleepless Monsoon'),
#  (944, 'Virgin Daisy'),
#  (704, 'Pure Runner'),
#  (68, 'Betrayed Rear'),
#  (346, 'Galaxy Sweethearts'),
#  (410, 'Heaven Freedom'),
#  (897, 'Torque Bound'),
#  (249, 'Dracula Crystal'),
#  (245, 'Double Wrath'),
#  (772, 'Sea Virgin'),
#  (395, 'Handicap Boondock'),
#  (775, 'Seattle Expecations'),
#  (162, 'Clueless Bucket'),
#  (117, 'Candles Grapes'),
#  (751, 'Runaway Tenenbaums'),
#  (356, 'Giant Troopers'),
#  (190, 'Creepers Kane'),
#  (59, 'Bear Graceland'),
#  (449, 'Identity Lover'),
#  (525, 'Loathing Legally'),
#  (375, 'Grail Frankenstein'),
#  (895, 'Tomorrow Hustler'),
#  (747, 'Roxanne Rebel'),
#  (489, 'Juggler Hardly'),
#  (708, 'Quills Bull'),
#  (434, 'Horror Reign'),
#  (406, 'Haunting Pianist'),
#  (941, 'Videotape Arsenic'),
#  (936, 'Vanishing Rocky'),
#  (676, 'Philadelphia Wife'),
#  (152, 'Circus Youth'),
#  (382, 'Grit Clockwork'),
#  (953, 'Wait Cider'),
#  (120, 'Caribbean Liberty'),
#  (973, 'Wife Turn'),
#  (628, 'Northwest Polish'),
#  (42, 'Artist Coldblooded'),
#  (585, 'Mob Duffel'),
#  (732, 'Rings Heartbreakers'),
#  (113, 'California Birds'),
#  (25, 'Angels Life'),
#  (561, 'Mask Peach'),
#  (452, 'Illusion Amelie'),
#  (926, 'Untouchables Sunrise'),
#  (979, 'Witches Panic'),
#  (920, 'Unbreakable Karate'),
#  (315, 'Finding Anaconda'),
#  (493, 'Kane Exorcist'),
#  (922, 'Undefeated Dalmations'),
#  (360, 'Glass Dying'),
#  (985, 'Wonderland Christmas'),
#  (368, 'Gone Trouble'),
#  (448, 'Idaho Love'),
#  (715, 'Range Moonwalker'),
#  (1, 'Academy Dinosaur'),
#  (616, 'National Story'),
#  (623, 'Newton Labyrinth'),
#  (759, 'Salute Apollo'),
#  (792, 'Shrek License'),
#  (167, 'Coma Head'),
#  (875, 'Talented Homicide'),
#  (790, 'Shootist Superfly'),
#  (989, 'Working Microcosmos'),
#  (353, 'Gentlemen Stage'),
#  (872, 'Sweet Brotherhood'),
#  (552, 'Majestic Floats'),
#  (578, 'Million Ace'),
#  (852, 'Strangelove Desire'),
#  (825, 'Speakeasy Date'),
#  (619, 'Neighbors Charade'),
#  (322, 'Flatliners Killer'),
#  (247, 'Downhill Enough'),
#  (227, 'Details Packer'),
#  (574, 'Midnight Westward'),
#  (761, 'Santa Paris'),
#  (79, 'Blade Polish'),
#  (377, 'Grease Youth'),
#  (233, 'Disciple Mother'),
#  (510, 'Lawless Vision'),
#  (610, 'Music Boondock'),
#  (320, 'Flamingos Connecticut'),
#  (278, 'Elf Murder'),
#  (95, 'Breakfast Goldfinger'),
#  (930, 'Vacation Boondock'),
#  (702, 'Pulp Beverly'),
#  (771, 'Scorpion Apollo'),
#  (723, 'Reign Gentlemen'),
#  (980, 'Wizard Coldblooded'),
#  (775, 'Seattle Expecations'),
#  (368, 'Gone Trouble'),
#  (650, 'Pacific Amistad'),
#  (987, 'Words Hunter'),
#  (109, 'Butterfly Chocolat'),
#  (201, 'Cyclone Family'),
#  (397, 'Hanky October'),
#  (204, 'Dalmations Sweden'),
#  (887, 'Thief Pelican'),
#  (388, 'Gunfight Moon'),
#  (48, 'Backlash Undefeated'),
#  (842, 'State Wasteland'),
#  (111, 'Caddyshack Jedi'),
#  (100, 'Brooklyn Desert'),
#  (776, 'Secret Groundhog'),
#  (770, 'Scissorhands Slums'),
#  (408, 'Head Stranger'),
#  (48, 'Backlash Undefeated'),
#  (629, 'Notorious Reunion'),
#  (462, 'Insider Arizona'),
#  (693, 'Potter Connecticut'),
#  (239, 'Dogma Family'),
#  (956, 'Wanda Chamber'),
#  (911, 'Trip Newton'),
#  (583, 'Mission Zoolander'),
#  (889, 'Ties Hunger'),
#  (303, 'Fantasy Troopers'),
#  (282, 'Encounters Curtain'),
#  (480, 'Jeepers Wedding'),
#  (327, 'Fool Mockingbird'),
#  (907, 'Translation Summer'),
#  (439, 'Hunchback Impossible'),
#  (385, 'Groundhog Uncut'),
#  (177, 'Connecticut Tramp'),
#  (891, 'Timberland Sky'),
#  (345, 'Gables Metropolis'),
#  (727, 'Resurrection Silverado'),
#  (374, 'Graffiti Love'),
#  (103, 'Bucket Brotherhood'),
#  (242, 'Doom Dancing'),
#  (608, 'Murder Antitrust'),
#  (379, 'Greedy Roots'),
#  (793, 'Shrunk Divine'),
#  (855, 'Streak Ridgemont'),
#  (93, 'Brannigan Sunrise'),
#  (858, 'Submarine Bed'),
#  (717, 'Rear Trading'),
#  (540, 'Lucky Flying'),
#  (271, 'Easy Gladiator'),
#  (603, 'Movie Shakespeare'),
#  (672, 'Perfect Groove'),
#  (344, 'Fury Murder'),
#  (465, 'Interview Liaisons'),
#  (852, 'Strangelove Desire'),
#  (869, 'Suspects Quills'),
#  (892, 'Titanic Boondock'),
#  (872, 'Sweet Brotherhood'),
#  (150, 'Cider Desire'),
#  (850, 'Story Side'),
#  (403, 'Harry Idaho'),
#  (806, 'Sleepy Japanese'),
#  (814, 'Snatch Slipper'),
#  (300, 'Falcon Volume'),
#  (567, 'Meet Chocolate'),
#  (397, 'Hanky October'),
#  (868, 'Superfly Trip'),
#  (839, 'Stallion Sundance'),
#  (117, 'Candles Grapes'),
#  (129, 'Cause Date'),
#  (143, 'Chill Luck'),
#  (292, 'Excitement Eve'),
#  (971, 'Whale Bikini'),
#  (924, 'Unforgiven Zoolander'),
#  (537, 'Lover Truman'),
#  (178, 'Connection Microcosmos'),
#  (828, 'Spiking Element'),
#  (352, 'Gathering Calendar'),
#  (450, 'Idols Snatchers'),
#  (493, 'Kane Exorcist'),
#  (391, 'Half Outfield'),
#  (319, 'Fish Opus'),
#  (138, 'Chariots Conspiracy'),
#  (8, 'Airport Pollock'),
#  (748, 'Rugrats Shakespeare'),
#  (296, 'Express Lonely'),
#  (925, 'United Pilot'),
#  (539, 'Luck Opus'),
#  (422, 'Hollow Jeopardy'),
#  (569, 'Menagerie Rushmore'),
#  (859, 'Sugar Wonka'),
#  (396, 'Hanging Deep'),
#  (387, 'Gun Bonnie'),
#  (25, 'Angels Life'),
#  (396, 'Hanging Deep'),
#  (418, 'Hobbit Alien'),
#  (651, 'Packer Madigan'),
#  (735, 'Robbers Joon'),
#  (437, 'House Dynamite'),
#  (135, 'Chance Resurrection'),
#  (349, 'Gangs Pride'),
#  (135, 'Chance Resurrection'),
#  (941, 'Videotape Arsenic'),
#  (615, 'Nash Chocolat'),
#  (155, 'Cleopatra Devil'),
#  (621, 'Network Peak'),
#  (79, 'Blade Polish'),
#  (137, 'Charade Duffel'),
#  (602, 'Mourning Purple'),
#  (502, 'Knock Warlock'),
#  (733, 'River Outlaw'),
#  (992, 'Wrath Mile'),
#  (540, 'Lucky Flying'),
#  (418, 'Hobbit Alien'),
#  (237, 'Divorce Shining'),
#  (880, 'Telemark Heartbreakers'),
#  (275, 'Egypt Tenenbaums'),
#  (213, 'Date Speed'),
#  (101, 'Brotherhood Blanket'),
#  (97, 'Bride Intrigue'),
#  (86, 'Boogie Amelie'),
#  (715, 'Range Moonwalker'),
#  (969, 'West Lion'),
#  (77, 'Birds Perdition'),
#  (466, 'Intolerable Intentions'),
#  (921, 'Uncut Suicides'),
#  (450, 'Idols Snatchers'),
#  (246, 'Doubtfire Labyrinth'),
#  (349, 'Gangs Pride'),
#  (735, 'Robbers Joon'),
#  (521, 'Lies Treatment'),
#  (961, 'Wash Heavenly'),
#  (800, 'Sinners Atlantis'),
#  (613, 'Mystic Truman'),
#  (610, 'Music Boondock'),
#  (819, 'Song Hedwig'),
#  (773, 'Seabiscuit Punk'),
#  (244, 'Dorado Notting'),
#  (11, 'Alamo Videotape'),
#  (145, 'Chisum Behavior'),
#  (855, 'Streak Ridgemont'),
#  (298, 'Eyes Driving'),
#  (396, 'Hanging Deep'),
#  (853, 'Stranger Strangers'),
#  (901, 'Tracy Cider'),
#  (792, 'Shrek License'),
#  (73, 'Bingo Talented'),
#  (234, 'Disturbing Scarface'),
#  (103, 'Bucket Brotherhood'),
#  (646, 'Outbreak Divine'),
#  (809, 'Slipper Fidelity'),
#  (838, 'Stagecoach Armageddon'),
#  (871, 'Sweden Shining'),
#  (200, 'Curtain Videotape'),
#  (577, 'Mile Mulan'),
#  (800, 'Sinners Atlantis'),
#  (112, 'Calendar Gunfight'),
#  (293, 'Exorcist Sting'),
#  (73, 'Bingo Talented'),
#  (256, 'Drop Waterfront'),
#  (242, 'Doom Dancing'),
#  (902, 'Trading Pinocchio'),
#  (641, 'Orange Grapes'),
#  (385, 'Groundhog Uncut'),
#  (248, 'Dozen Lion'),
#  (795, 'Siege Madre'),
#  (391, 'Half Outfield'),
#  (683, 'Pity Bound'),
#  (197, 'Crusade Honey'),
#  (730, 'Ridgemont Submarine'),
#  (501, 'Kissing Dolls'),
#  (137, 'Charade Duffel'),
#  (932, 'Valley Packer'),
#  (191, 'Crooked Frogmen'),
#  (31, 'Apache Divine'),
#  (204, 'Dalmations Sweden'),
#  (60, 'Beast Hunchback'),
#  (277, 'Elephant Trojan'),
#  (805, 'Sleepless Monsoon'),
#  (700, 'Prix Undefeated'),
#  (172, 'Coneheads Smoochy'),
#  (563, 'Massacre Usual'),
#  (875, 'Talented Homicide'),
#  (941, 'Videotape Arsenic'),
#  (138, 'Chariots Conspiracy'),
#  (265, 'Dying Maker'),
#  (326, 'Flying Hook'),
#  (545, 'Madness Attacks'),
#  (468, 'Invasion Cyclone'),
#  (861, 'Suit Walls'),
#  (164, 'Coast Rainbow'),
#  (628, 'Northwest Polish'),
#  (147, 'Chocolat Harry'),
#  (938, 'Velvet Terminator'),
#  (467, 'Intrigue Worst'),
#  (931, 'Valentine Vanishing'),
#  (301, 'Family Sweet'),
#  (30, 'Anything Savannah'),
#  (586, 'Mockingbird Hollywood'),
#  (42, 'Artist Coldblooded'),
#  (530, 'Lord Arizona'),
#  (159, 'Closer Bang'),
#  (196, 'Cruelty Unforgiven'),
#  (649, 'Oz Liaisons'),
#  (875, 'Talented Homicide'),
#  (739, 'Rocky War'),
#  (267, 'Eagles Panky'),
#  (210, 'Darko Dorado'),
#  (309, 'Feud Frogmen'),
#  (688, 'Polish Brooklyn'),
#  (702, 'Pulp Beverly'),
#  (626, 'Noon Papi'),
#  (627, 'North Tequila'),
#  (597, 'Moonwalker Fool'),
#  (626, 'Noon Papi'),
#  (450, 'Idols Snatchers'),
#  (1000, 'Zorro Ark'),
#  (575, 'Midsummer Groundhog'),
#  (721, 'Reds Pocus'),
#  (370, 'Gorgeous Bingo'),
#  (502, 'Knock Warlock'),
#  (953, 'Wait Cider'),
#  (131, 'Center Dinosaur'),
#  (418, 'Hobbit Alien'),
#  (96, 'Breaking Home'),
#  (770, 'Scissorhands Slums'),
#  (422, 'Hollow Jeopardy'),
#  (17, 'Alone Trip'),
#  (303, 'Fantasy Troopers'),
#  (434, 'Horror Reign'),
#  (633, 'October Submarine'),
#  (350, 'Garden Island'),
#  (98, 'Bright Encounters'),
#  (40, 'Army Flintstones'),
#  (358, 'Gilmore Boiled'),
#  (280, 'Empire Malkovich'),
#  (523, 'Lights Deer'),
#  (333, 'Freaky Pocus'),
#  (563, 'Massacre Usual'),
#  (6, 'Agent Truman'),
#  (349, 'Gangs Pride'),
#  (786, 'Shepherd Midsummer'),
#  (127, 'Cat Coneheads'),
#  (745, 'Roses Treasure'),
#  (613, 'Mystic Truman'),
#  (654, 'Panky Submarine'),
#  (432, 'Hope Tootsie'),
#  (535, 'Love Suicides'),
#  (470, 'Ishtar Rocketeer'),
#  (735, 'Robbers Joon'),
#  (730, 'Ridgemont Submarine'),
#  (517, 'Lesson Cleopatra'),
#  (816, 'Snowman Rollercoaster'),
#  (85, 'Bonnie Holocaust'),
#  (454, 'Impact Aladdin'),
#  (309, 'Feud Frogmen'),
#  (181, 'Contact Anonymous'),
#  (358, 'Gilmore Boiled'),
#  (783, 'Shane Darkness'),
#  (305, 'Fatal Haunted'),
#  (650, 'Pacific Amistad'),
#  (914, 'Trouble Date'),
#  (865, 'Sunrise League'),
#  (637, 'Open African'),
#  (86, 'Boogie Amelie'),
#  (181, 'Contact Anonymous'),
#  (698, 'Princess Giant'),
#  (374, 'Graffiti Love'),
#  (898, 'Tourist Pelican'),
#  (283, 'Ending Crowds'),
#  (598, 'Mosquito Armageddon'),
#  (982, 'Women Dorado'),
#  (686, 'Pluto Oleander'),
#  (654, 'Panky Submarine'),
#  (875, 'Talented Homicide'),
#  (491, 'Jumping Wrath'),
#  (526, 'Lock Rear'),
#  (11, 'Alamo Videotape'),
#  (348, 'Gandhi Kwai'),
#  (445, 'Hyde Doctor'),
#  (592, 'Monster Spartacus'),
#  (307, 'Fellowship Autumn'),
#  (682, 'Pittsburgh Hunchback'),
#  (670, 'Pelican Comforts'),
#  (879, 'Telegraph Voyage'),
#  (93, 'Brannigan Sunrise'),
#  (689, 'Pollock Deliverance'),
#  (429, 'Honey Ties'),
#  (407, 'Hawk Chill'),
#  (374, 'Graffiti Love'),
#  (322, 'Flatliners Killer'),
#  (130, 'Celebrity Horn'),
#  (294, 'Expecations Natural'),
#  (491, 'Jumping Wrath'),
#  (305, 'Fatal Haunted'),
#  (679, 'Pilot Hoosiers'),
#  (906, 'Tramp Others'),
#  ...]

# %%
# %%sql
# SELECT * FROM film LIMIT 1
# Out:
# 1 rows affected.
# [(133, 'Chamber Italian', 'A Fateful Reflection of a Moose And a Husband who must Overcome a Monkey in Nigeria', 2006, 1, 7, Decimal('4.99'), 117, Decimal('14.99'), 'NC-17', datetime.datetime(2013, 5, 26, 14, 50, 58, 951000), ['Trailers'], "'chamber':1 'fate':4 'husband':11 'italian':2 'monkey':16 'moos':8 'must':13 'nigeria':18 'overcom':14 'reflect':5")]

# %%
# %%sql
# SELECT * FROM inventory LIMIT 1
# Out:
# 1 rows affected.
# [(1, 1, 1, datetime.datetime(2006, 2, 15, 10, 9, 17))]

# %%
# %%sql
# SELECT * FROM rental LIMIT 1
# Out:
# 1 rows affected.
# [(2, datetime.datetime(2005, 5, 24, 22, 54, 33), 1525, 459, datetime.datetime(2005, 5, 28, 19, 40, 33), 1, datetime.datetime(2006, 2, 16, 2, 30, 53))]

# %% [markdown]
# ### Example 3
#
# What is the average rental time and number of rentals for the renters that have checked our more than 200 days worth of films?

# %%
# %%sql
# EXPLAIN
# SELECT AVG(top_renters.rental_time), AVG(top_renters.cnt)
# FROM customer c
# INNER JOIN (
#         SELECT customer_id
#         , SUM(return_date - rental_date) as rental_time
#         , COUNT(*) as cnt
#         FROM rental
#         GROUP BY customer_id
#         HAVING SUM(return_date - rental_date) > '200 days'::interval
#     ) as top_renters
# USING (customer_id)
# ;
# Out:
# 9 rows affected.
# [('Aggregate  (cost=598.29..598.30 rows=1 width=24)',),
#  ('  ->  Hash Join  (cost=573.58..595.29 rows=599 width=24)',),
#  ('        Hash Cond: (rental.customer_id = c.customer_id)',),
#  ('        ->  HashAggregate  (cost=551.10..558.59 rows=599 width=18)',),
#  ('              Group Key: rental.customer_id',),
#  ("              Filter: (sum((rental.return_date - rental.rental_date)) > '200 days'::interval)",),
#  ('              ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=18)',),
#  ('        ->  Hash  (cost=14.99..14.99 rows=599 width=4)',),
#  ('              ->  Seq Scan on customer c  (cost=0.00..14.99 rows=599 width=4)',)]

# %%
# %%sql
# SELECT customer_id
#         , SUM(return_date - rental_date) as rental_time
#         , COUNT(*) as cnt
#         FROM rental
#         GROUP BY customer_id
#         HAVING SUM(return_date - rental_date) > '200 days'::interval
# Out:
# 10 rows affected.
# [(137, datetime.timedelta(229, 16200), 39),
#  (295, datetime.timedelta(221, 26460), 38),
#  (526, datetime.timedelta(264, 13080), 45),
#  (178, datetime.timedelta(214, 24120), 39),
#  (468, datetime.timedelta(218, 5400), 39),
#  (236, datetime.timedelta(205, 69480), 42),
#  (148, datetime.timedelta(243, 8220), 46),
#  (469, datetime.timedelta(221, 6360), 40),
#  (176, datetime.timedelta(210, 33900), 37),
#  (144, datetime.timedelta(235, 3480), 42)]

# %%
# %%sql
#
# SELECT AVG(top_renters.rental_time), AVG(top_renters.cnt)
# FROM customer c
# INNER JOIN (
#         SELECT customer_id
#         , SUM(return_date - rental_date) as rental_time
#         , COUNT(*) as cnt
#         FROM rental
#         GROUP BY customer_id
#         HAVING SUM(return_date - rental_date) > '200 days'::interval
#     ) as top_renters
# USING (customer_id)
# ;
# Out:
# 1 rows affected.
# [(datetime.timedelta(226, 20670), Decimal('40.7000000000000000'))]

# %% [markdown]
# ## <span style="background:yellow">Your Turn</span>
#
# Write a query to find the number of actors who have appeared in more than 35 movies

# %%
 # %%sql
SELECT COUNT(*)
FROM (
    SELECT actor_id, COUNT(*)
    FROM film_actor
    GROUP BY actor_id
    HAVING COUNT(*) > 35
    ) as rent_counts;
# Out:
# 1 rows affected.
# [(6,)]

# %% [markdown]
# Write a query to find the number of rentals made by those renters who have checked out over 170 days of films

# %%
# %%sql
# SELECT customer_id
#         , SUM(return_date - rental_date) as rental_time
#         , COUNT(*) as cnt
#         FROM rental
#         GROUP BY customer_id
#         HAVING SUM(return_date - rental_date) > '170 days'::interval
# Out:
# 61 rows affected.
# [(209, datetime.timedelta(172, 60180), 32),
#  (119, datetime.timedelta(179, 18960), 34),
#  (26, datetime.timedelta(180, 35220), 34),
#  (137, datetime.timedelta(229, 16200), 39),
#  (168, datetime.timedelta(185, 2340), 34),
#  (373, datetime.timedelta(193, 73800), 35),
#  (295, datetime.timedelta(221, 26460), 38),
#  (526, datetime.timedelta(264, 13080), 45),
#  (178, datetime.timedelta(214, 24120), 39),
#  (66, datetime.timedelta(177, 45840), 34),
#  (89, datetime.timedelta(175, 15840), 32),
#  (102, datetime.timedelta(182, 2280), 33),
#  (459, datetime.timedelta(190, 54720), 38),
#  (274, datetime.timedelta(176, 34440), 35),
#  (211, datetime.timedelta(179, 44340), 34),
#  (348, datetime.timedelta(187, 82980), 36),
#  (468, datetime.timedelta(218, 5400), 39),
#  (566, datetime.timedelta(174, 70140), 34),
#  (91, datetime.timedelta(178, 5940), 35),
#  (293, datetime.timedelta(175, 1140), 31),
#  (532, datetime.timedelta(195, 2820), 32),
#  (21, datetime.timedelta(189, 4980), 35),
#  (462, datetime.timedelta(174, 51180), 33),
#  (5, datetime.timedelta(187, 49680), 38),
#  (181, datetime.timedelta(198, 8520), 34),
#  (366, datetime.timedelta(199, 85560), 37),
#  (78, datetime.timedelta(177, 13020), 31),
#  (172, datetime.timedelta(179, 53100), 33),
#  (244, datetime.timedelta(173, 29820), 32),
#  (38, datetime.timedelta(172, 43560), 34),
#  (129, datetime.timedelta(170, 60), 34),
#  (30, datetime.timedelta(177, 52380), 34),
#  (439, datetime.timedelta(178, 58920), 36),
#  (197, datetime.timedelta(196, 3300), 40),
#  (187, datetime.timedelta(180, 69720), 28),
#  (506, datetime.timedelta(185, 57840), 35),
#  (520, datetime.timedelta(175, 42360), 32),
#  (50, datetime.timedelta(191, 37620), 35),
#  (393, datetime.timedelta(175, 44220), 31),
#  (273, datetime.timedelta(183, 27240), 35),
#  (207, datetime.timedelta(199, 1800), 34),
#  (267, datetime.timedelta(176, 58080), 36),
#  (354, datetime.timedelta(170, 72240), 36),
#  (380, datetime.timedelta(188, 76740), 36),
#  (410, datetime.timedelta(197, 61320), 38),
#  (242, datetime.timedelta(173, 76080), 32),
#  (236, datetime.timedelta(205, 69480), 42),
#  (148, datetime.timedelta(243, 8220), 46),
#  (257, datetime.timedelta(181, 71820), 37),
#  (371, datetime.timedelta(173, 66360), 35),
#  (237, datetime.timedelta(178, 48840), 33),
#  (360, datetime.timedelta(178, 46200), 34),
#  (469, datetime.timedelta(221, 6360), 40),
#  (75, datetime.timedelta(189, 81600), 41),
#  (259, datetime.timedelta(189, 24060), 32),
#  (522, datetime.timedelta(194, 73800), 33),
#  (176, datetime.timedelta(210, 33900), 37),
#  (147, datetime.timedelta(170, 6120), 34),
#  (436, datetime.timedelta(188, 82380), 30),
#  (144, datetime.timedelta(235, 3480), 42),
#  (7, datetime.timedelta(185, 24840), 33)]

# %%
# %%sql
# SELECT COUNT(*)
# FROM rental
# INNER JOIN (
#         SELECT
#             SUM(return_date - rental_date) as rental_time,
#             MAX(return_date-rental_date), customer_id
#         , COUNT(*) as cnt
#         FROM rental
#         GROUP BY customer_id
#         HAVING SUM(return_date - rental_date) > '170 days'::interval
#     ) as top_renters
# USING (customer_id)
# Out:
# 1 rows affected.
# [(2151,)]
