# %% [markdown]
# # Graph Analytics - Links

# %% [markdown]
# In this notebook, we continue with our Wikipedia graph database.
# Now, the focus will shift to link analysis.

# %%
from py2neo import Graph

#################################################
# Update UPDATE-ME in the connection code with 
# The server you were assigned (see the schedule 
# notebook) to connect to using the 
# Links below.
#################################################
# Server 0 - neo4j.dsa.missouri.edu
# Server 1 - neo4j-1.dsa.missouri.edu
# Server 2 - neo4j-2.dsa.missouri.edu
# Server 3 - neo4j-3.dsa.missouri.edu
#################################################

graph = Graph("bolt://wikiread:wikireader@neo4j-1.dsa.missouri.edu:9000")

# %% [markdown]
# ### Reminder of the scale of our database

# %%
# How many nodes are in our graph?
#  This line pulls the first row and column from the graph, the page count
page_total = graph.run("MATCH (a) RETURN COUNT(a) as pages").to_table()[0][0]

# How many edges?
outgoing_links = graph.run("MATCH (a)-[r]->(b) RETURN COUNT(r) as links").to_table()[0][0]

print(page_total, "pages with", outgoing_links, "page links.")
# Out:
# 13835767 pages with 146045322 page links.

# %% [markdown]
# ##### Looks like we have around 13M articles and 146M page links.

# %% [markdown]
# # Link Analysis
#
# Let's start analyzing our pages and their links.
# So far we've only been looking at pages directly connected to another.
# Let's branch out and look at the links of the links.
#
# The number of nodes between things in a graph is referred to as degrees of separation, where the number of degrees is the number of intermediary nodes.
# Edges themselves can be referred to as hops.
# For example, with `a->b->c`, `c` is one degree separated, and two hops away, from `a`.
#
# Let's look at all the pages two hops away Neo4j,
# but let's remind ourselves of what we're working with first.

# %%
data = graph.run("MATCH (a:Page {title: 'Neo4j'})-[r:Link]-(b:Page) RETURN a.title,"
                 "CASE startnode(r) WHEN a THEN 'to' ELSE 'From' END as dir, b.title").to_table()
print(data)
# Out:
#  a.title | dir  | b.title
# ---------|------|---------------------------------------------------
#  Neo4j   | to   | Apache Giraph
#  Neo4j   | to   | Nikolaj Nyholm
#  Neo4j   | to   | United States
#  Neo4j   | to   | Remote backup service
#  Neo4j   | to   | Gremlin (programming language)
#  Neo4j   | to   | Malmö
#  Neo4j   | to   | North America
#  Neo4j   | to   | GPLv3
#  Neo4j   | to   | Neo Technology
#  Neo4j   | to   | OrientDB
#  Neo4j   | to   | Sweden
#  Neo4j   | to   | Java (programming language)
#  Neo4j   | to   | ArangoDB
#  Neo4j   | to   | San Francisco Bay Area
#  Neo4j   | to   | Cypher Query Language
#  Neo4j   | to   | ACID
#  Neo4j   | to   | AGPLv3
#  Neo4j   | to   | Europe
#  Neo4j   | to   | Graph database
#  Neo4j   | to   | Affero General Public License
#  Neo4j   | to   | GNU General Public License
#  Neo4j   | to   | Intentional Software
#  Neo4j   | to   | CODASYL
#  Neo4j   | to   | Freemium
#  Neo4j   | to   | AllegroGraph
#  Neo4j   | to   | Spring Framework
#  Neo4j   | to   | DB-Engines ranking
#  Neo4j   | From | Paradise Papers
#  Neo4j   | From | Linkurious
#  Neo4j   | From | List of TCP and UDP port numbers
#  Neo4j   | From | Query language
#  Neo4j   | From | Connection pool
#  Neo4j   | From | Spatial database
#  Neo4j   | From | Paxos (computer science)
#  Neo4j   | From | Well-known text
#  Neo4j   | From | List of JVM languages
#  Neo4j   | From | List of software under the GNU AGPL
#  Neo4j   | From | DataNucleus
#  Neo4j   | From | NoSQL
#  Neo4j   | From | Graph database
#  Neo4j   | From | Comparison of structured storage software
#  Neo4j   | From | Neo Technology
#  Neo4j   | From | Neo4J
#  Neo4j   | From | FlockDB
#  Neo4j   | From | OrientDB
#  Neo4j   | From | GameDuell
#  Neo4j   | From | Gremlin (programming language)
#  Neo4j   | From | Rod Johnson (programmer)
#  Neo4j   | From | Jelastic
#  Neo4j   | From | Cypher Query Language
#  Neo4j   | From | Hybrid transactional/analytical processing (HTAP)
#  Neo4j   | From | Bolt (network protocol)

# %% [markdown]
# The Neo4j page seems innocuous, but there are some pretty big sounding pages adjacent to it, such as "United States", "Europe", or even "List of software under the GNU AGPL".
# Graphs can explode very quickly.
# Countries or lists are a little intimidating given what we've been doing so far.
#
# You may notice a curious connection from `Neo4J` to `Neo4j`.
# Wikipedia articles are case-sensitive, and `Neo4J` is a page that redirects to `Neo4j`.
# Some pages even link to `Neo4J` when they should really link to `Neo4j`.
# Let's make a quick detour to see who the offending pages are.

# %%
data = graph.run("MATCH (a:Page {title: 'Neo4J'})<--(b:Page) RETURN b.title").to_table()
print(data)
# Out:
#  b.title
# --------------------------------
#  Panama Papers
#  Pornhub
#  List of SPARQL implementations
#  Cloud database
#  AllegroGraph
#  NoSQL
#  IBM Storage

# %% [markdown]
# Ok lets get back to the task at hand. Identify all pages two hops away from Neo4j (outgoing) and print their titles.
# Also, print the number of results you received.

# %%
data = graph.run("MATCH (a:Page {title: 'Neo4j'})-->(b)-->(c) RETURN c.title").to_table()
print(len(data))
data
# Out:
# 5144
#  c.title
# --------------------------------------------------------------------------
#  Apache Hadoop
#  PC World
#  Facebook
#  Gigaom
#  Cross-platform
#  Apache License
#  Java (programming language)
#  Apache Software Foundation
#  Graph (computer science)
#  Polar Rose (facial recognition)
#  Denmark
#  World Economic Forum
#  Vodafone
#  Copenhagen
#  Minecraft
#  Apple Inc.
#  Fon (company)
#  OpenWrt
#  Mojang
#  O'Reilly Media
#  Iroquois Confederacy
#  Orrin Hatch
#  United States Department of the Navy
#  Agnosticism
#  USS Ronald Reagan (CVN-76)
#  North Korea–United States relations
#  Nikola Tesla
#  Peter Feaver
#  Kilowatt hour
#  John Marshall
#  William Tyler Page
#  United States–Cuban Thaw
#  Moby-Dick
#  Chihuahuan Desert
#  Spanish colonization of the Americas
#  Redeemers
#  The Heritage Foundation
#  Invention of the telephone
#  Chicago
#  National wealth
#  Citizen Kane
#  Drinking water quality in the United States
#  Rhode Island
#  Japanese Americans
#  Containment
#  DC Comics
#  The McClatchy Company
#  History of the steel industry
#  Silicon Valley
#  Hawaiian Islands
#  Index of United States-related articles
#  Amazon.com
#  United States Constitution
#  Computer hardware
#  White American
#  James Brown
#  Human Rights Watch
#  Culture of the United States
#  Greenwood Publishing Group
#  Wright Flyer
#  Illinois and Michigan Canal
#  Yuquot, British Columbia
#  Marilyn Monroe
#  Population history of indigenous peoples of the Americas
#  Hudson River School
#  Province of Georgia
#  Oregon
#  Indian American
#  Nancy Pelosi
#  Scientologist
#  Cajun French
#  Economic Policy Institute
#  Thomas Sowell
#  Race and ethnicity in the United States Census
#  Americans
#  Japan
#  National debt of the United States
#  Basic Books
#  List of Christian denominations
#  Multiculturalism
#  Cantonese
#  Facebook
#  United States Environmental Protection Agency
#  United States antitrust law
#  Second Great Awakening
#  Electoral College (United States)
#  Kalaniʻōpuʻu
#  List of countries by imports
#  Harper Lee
#  Lutherans
#  List of national animals
#  National Guard of the United States
#  Federal Reserve System
#  Pacific Islands Americans
#  Tony Atkinson
#  Germany–United States relations
#  Martin Luther King Jr.
#  Great Lakes
#  Continental Army
#  French language
#  Major League Baseball
#  George H.W. Bush
#  Waimea, Kauai County, Hawaii
#  War in Afghanistan (2001–present)
#  Outline of the United States
#  Saddam Hussein
#  Novus ordo seclorum
#  Plea bargaining in the United States
#  Islamic State of Iraq and the Levant
#  List of statutory minimum employment leave by country
#  Spanish language in the United States
#  Louisiana
#  Military history of the United States during World War II
#  Clovis culture
#  National language
#  Liberia
#  French language in the United States
#  Mississippi River
#  Thirteenth Amendment to the United States Constitution
#  White House
#  The Village Voice
#  Thomas Eakins
#  Alaska Natives
#  Iraq War troop surge of 2007
#  Katy Perry
#  Politics of the Western United States
#  American frontier
#  United States territorial acquisitions
#  Massachusetts
#  BBC News
#  Second Party System
#  Republican Party (United States)
#  Golden Globe Awards
#  Reuters
#  Nuclear weapons and the United States
#  Reconstruction (United States)
#  Manifest destiny
#  Show business
#  Thure de Thulstrup
#  Health insurance marketplace
#  Los Angeles Times
#  List of Protestant churches
#  Nuclear program of Iran
#  Neo-Druidism
#  2008 financial crisis
#  Average Joe
#  American's Creed
#  Quakers
#  Trail of Tears
#  Articles of Confederation
#  YouTube
#  LGBT
#  Apple Inc.
#  Center-right politics
#  Northeast Megalopolis
#  Nuclear power in the United States
#  Second Amendment to the United States Constitution
#  Traditional pop music
#  Arizona
#  United States House of Representatives
#  Herman Melville
#  Energy in the United States
#  List of countries by average wage
#  United States urban area
#  United States free trade agreements
#  Johnston Atoll
#  Gulf War
#  Iran
#  Democracy Index
#  People's Party (United States)
#  Homelessness in the United States
#  North Korea
#  Corruption Perceptions Index
#  List of Nobel laureates in Physiology or Medicine
#  Italy–United States relations
#  Rowman Altamira
#  Moon
#  Siege of Yorktown
#  Second Continental Congress
#  United States Supreme Court Building
#  Financial Crisis Inquiry Commission
#  Oneness Pentecostals
#  Tennessee Williams
#  North American Numbering Plan
#  Jazz
#  Foreign Policy
#  Federal Reserve Bank of New York
#  Politics of the Southern United States
#  The Hindu Group
#  On the Waterfront
#  Beyoncé
#  HarperCollins
#  Philippines
#  Missouri River
#  Irish Americans
#  John L. Hess
#  Presidential system
#  P. T. Barnum
#  Milton Friedman
#  Great Depression in the United States
#  The News-Star
#  Initiative on Global Markets
#  Endangered Species Act
#  Oxford University Press
#  Group of Seven
#  Gun politics in the United States
#  China
#  LA Weekly
#  NPR
#  Juan Ponce de León
#  U.S. state
#  Nebraska
#  Samoan language
#  Russia
#  Democratic Party (United States)
#  Emancipation Proclamation
#  Twitter
#  Health care in the United States
#  Taos Pueblo
#  Cornelius Vanderbilt
#  UNESCO
#  Ransom E. Olds
#  Chinese American
#  Prince (singer)
#  Internet
#  Fox Broadcasting Company
#  Latin
#  Tertiary sector of the economy
#  Party leaders of the United States Senate
#  Settlement of the Americas
#  ARPANET
#  High-speed rail in the United States
#  American ancestry
#  Foreign relations of Bhutan
#  Korean language
#  Restorationists
#  English overseas possessions
#  Alexander Archipelago
#  Permanent members of the United Nations Security Council
#  Lists of U.S. state topics
#  Music of the United States
#  Economy of the United States
#  Rights of Englishmen
#  List of countries and dependencies by area
#  Iran–United States relations
#  Stephen Moylan
#  Northwestern United States
#  Treaty of Versailles
#  Luxembourg
#  Henry Cowell
#  Vice President of the United States
#  Marine expeditionary unit
#  American Revolution
#  Atomic Age
#  Chinese language
#  Oregon Treaty
#  American (word)
#  Bahá'í Faith
#  Constitutional Convention (United States)
#  Chuck Berry
#  France–United States relations
#  Six Assurances
#  Chief Justice of the United States
#  Sierra Nevada (U.S.)
#  Canada–United States relations
#  Francis Ford Coppola
#  Sport utility vehicle
#  Metallica
#  Hawaii Island
#  Tear down this wall!
#  Methodists
#  Hawaii
#  Gannett Company
#  Social Security (United States)
#  NASCAR
#  Yellowstone National Park
#  The American Journal of Medicine
#  Casablanca (film)
#  The Atlantic
#  Missouri
#  Siberia
#  Student debt
#  United States Pacific Fleet
#  United States Bill of Rights
#  Carolinian language
#  List of most commonly learned foreign languages in the United States
#  United States women's national soccer team
#  United States Federal Sentencing Guidelines
#  Henry Ford
#  The Stars and Stripes Forever
#  United States presidential election, 2008
#  LGBT adoption in the United States
#  Pilgrims (Plymouth Colony)
#  Northwest Passage
#  Donald Trump
#  Courier Corporation
#  Idaho
#  War of 1812
#  Wheat
#  Standard & Poor's
#  John Cage
#  Britney Spears
#  Russian Alaska
#  Routledge
#  Academy Awards
#  Columbus's second voyage
#  Michael Jackson
#  Ratification of the United States Constitution
#  Ernest Hemingway
#  Latin American culture
#  Midtown Manhattan
#  United States Census Bureau
#  Alexander Graham Bell
#  Overthrow of the Kingdom of Hawaii
#  Roy Lichtenstein
#  Hinduism in the United States
#  Comedy
#  Abortion in the United States
#  Marshall Islands
#  Household income
#  Non-voting members of the United States House of Representatives
#  United States Armed Forces
#  National Highway System (United States)
#  September 11 attack
#  National Public Radio
#  Incandescent light bulb
#  American bison
#  Cabinet of the United States
#  Ansel Adams
#  Western culture
#  Russian Empire
#  Southern Baptist Convention
#  Rockies
#  Organisation for Economic Co-operation and Development
#  Suriname
#  American Airlines
#  The Great Gatsby
#  First Great Awakening
#  Norway
#  Desert climate
#  Dissolution of the Soviet Union
#  Indigenous peoples of the Americas
#  Executive (government)
#  Gallup (company)
#  Irving Berlin
#  Isadora Duncan
#  Theater of the United States
#  Shinto
#  Human Development Index
#  Roe v. Wade
#  San Bernardino, California
#  New Hollywood
#  Gross domestic product
#  John Barth
#  List of the world's busiest airports by passenger traffic
#  Al-Qaeda
#  Thirteen Colonies
#  Treaty of Paris (1783)
#  Fitch Ratings
#  Tennessee
#  Indentured servitude
#  Maine
#  Coalition of the Gulf War
#  American Sign Language
#  Cuba–United States relations
#  Kingdom of Hawaii
#  Axis powers
#  Native Americans in the United States
#  College football
#  Major League Soccer
#  Great Lakes Megalopolis
#  Tagalog language
#  Paleo-Indians
#  Federal Bureau of Investigation
#  United States Declaration of Independence
#  A People's History of the United States
#  Country music
#  2028 Summer Olympics
#  Spanish Navy
#  Islam in the United States
#  Europe
#  Berlin
#  National bird of the United States
#  Patient Protection and Affordable Care Act
#  Federalism in the United States
#  Medicaid
#  English Dissenters
#  Consumer spending
#  Arabic language
#  Winter Olympic Games
#  Consumer confidence index
#  Obesity in the United States
#  Iraqi insurgency (2011–13)
#  Water pollution in the United States
#  Permanent residence (United States)
#  African-American music
#  Duke Ellington
#  New York City
#  United States Capitol
#  Howland Island
#  UNESCO World Heritage Sites
#  American Civil War
#  Andrew Carnegie
#  Australia–United States relations
#  League of Nations
#  Super Bowl
#  State of Scott
#  Naturalized citizen of the United States
#  Buddhism in the United States
#  Palau
#  Cherokee language
#  United States Department of Homeland Security
#  South Korea–United States relations
#  Aleutian Islands
#  Term limits in the United States
#  Semi-arid climate
#  Massachusetts Institute of Technology
#  Barack Obama
#  Edward Albee
#  Great Plains
#  AFI 100
#  Death Penalty Information Center
#  Islamic terrorism
#  Stephen Sondheim
#  Reserve components of the United States Armed Forces
#  D. W. Griffith
#  Bajo Nuevo Bank
#  Lend-Lease
#  Protestantism
#  Scotch-Irish American
#  NBC News
#  Washington (state)
#  Natural and legal rights
#  Archaeology
#  Edward Steichen
#  U.S. Census Bureau
#  Wright brothers
#  Serranilla Bank
#  Erie Canal
#  New Deal
#  Advanced Micro Devices
#  Service (economics)
#  CNN
#  Airline Deregulation Act
#  World War II
#  Germany
#  Makahiki
#  Roaring Twenties
#  Edgar Allan Poe
#  Encounter Books
#  Henry David Thoreau
#  Habeas corpus in the United States
#  Baseball
#  Canada
#  India
#  Harvard University Press
#  Florida
#  Cahokia
#  French colonization of the Americas
#  Amerigo Vespucci
#  Midway Atoll
#  Multiracial Americans
#  Taoism
#  Ronald Reagan
#  Civil Rights Movement
#  Kevin McCarthy (California politician)
#  1994 FIFA World Cup
#  Furman v. Georgia
#  Aaron Copland
#  Mexican–American War
#  Reaganomics
#  Post–World War II economic expansion
#  Federalism
#  Federal Bureau of Prisons
#  United Kingdom–United States relations
#  Fertility
#  Hyperglycemia
#  Larry Bartels
#  Protestantism in the United States
#  The Economist
#  NBC
#  List of countries by energy consumption per capita
#  Portugal
#  Christian revival
#  Spanish expeditions to the Pacific Northwest
#  To Kill a Mockingbird
#  Theater District, Manhattan
#  American football
#  United States House of Representatives elections, 2010
#  Fourteenth Amendment to the United States Constitution
#  Nootka Sound
#  Catholic Church in the United States
#  FiveThirtyEight
#  List of countries by military expenditures
#  Adventists
#  Yalta Conference
#  Three Mile Island accident
#  Encyclopædia Britannica
#  Woodrow Wilson
#  Southern United States
#  Republic of Texas
#  District of Columbia
#  Richard Rorty
#  Poverty Point
#  Subway (restaurant)
#  United States dollar
#  Gulf of Mexico
#  CliffsNotes
#  Apollo 11
#  United States Senate elections, 2014
#  Christian Scientists
#  Apollo 15
#  List of countries by exports
#  German Americans
#  Tropical climate
#  Appalachian Mountains
#  Prohibition in the United States
#  United States Department of Agriculture
#  Kingdom of Great Britain
#  African Americans
#  Progressive Party (United States, 1912)
#  Anarchism in the United States
#  Navassa Island
#  John Rawls
#  The Star-Spangled Banner
#  Orson Welles
#  History of the socialist movement in the United States
#  USA Today
#  Red states and blue states
#  Italy
#  Compromise of 1877
#  Socio-economic mobility in the United States
#  Nazism
#  Space Race
#  French and Indian War
#  Conscription in the United States
#  Vostok 1
#  Central Powers
#  National Basketball Association
#  Centre-left politics
#  Polygamy
#  Weill Cornell Graduate School of Medical Sciences
#  Extreme points of the United States
#  PBS
#  Incarceration in the United States
#  Party leaders of the United States House of Representatives
#  University of Nebraska Press
#  Nobel Prize in Literature
#  Federal judiciary of the United States
#  Territory of Hawaii
#  Aerosmith
#  United States incarceration rate
#  Northern Mariana Islands
#  Wyoming
#  Mass transit in the United States
#  George Washington
#  American Jews
#  Warsaw Pact
#  Soviet Union
#  Western United States
#  Lacrosse
#  Mesa Verde National Park
#  Civil Rights Act of 1968
#  American Dream
#  Indiana University Press
#  It's a Wonderful Life
#  Terrorism
#  Japanese language education in the United States
#  American philosophy
#  Kingman Reef
#  Phoenix, Arizona
#  United States National Research Council
#  The New York Times Company
#  Medicare (United States)
#  Westminster, Maryland
#  Headquarters of the United Nations
#  Steam engine
#  Immigration and Nationality Act of 1965
#  United States Presidential Election, 2016
#  Lower Manhattan
#  Hawaiian language
#  Robert Nozick
#  Origins of the American Civil War
#  Jainism
#  Oklahoma
#  Arteriosclerosis, Thrombosis, and Vascular Biology
#  Agriculture in the United States
#  Union (American Civil War)
#  Puerto Rico
#  Manufacturing in the United States
#  Congressional Budget Office
#  Lists of landmark court decisions
#  Food Stamp Program
#  Mississippi
#  Hollywood
#  United States presidential election, 1856
#  First Transcontinental Railroad
#  California
#  Andy Warhol
#  United States presidential election, 1860
#  Enrico Fermi
#  John Dewey
#  National Hockey League
#  Global Food Security Index
#  FIFA Women's World Cup
#  United States Marine Corps
#  First Amendment to the United States Constitution
#  Frank Gehry
#  Global Competitiveness Report
#  Manhattan Project
#  Walt Whitman
#  Selective Service System
#  Science and technology in the United States
#  Legislature
#  Association football
#  Superman
#  Holiness movement
#  Presbyterians
#  Fundamental Orders of Connecticut
#  United States Department of Defense
#  Theodore Roosevelt
#  Politics
#  Aid to Families with Dependent Children
#  Captain James Cook
#  New Hampshire
#  International Energy Agency
#  Invasion of Kuwait
#  Lynching in the United States
#  Mexican cuisine
#  Industrial Revolution
#  Seven Years' War
#  Deep South
#  Modern liberalism in the United States
#  Business magnate
#  American Community Survey
#  English Americans
#  National Football League
# ...
#  David A. Wheeler
#  Language workbench
#  Charles Simonyi
#  Microsoft
#  Bellevue, Washington
#  International Organization for Standardization
#  Univac
#  Specification (technical standard)
#  International Computers Limited
#  Navigational database
#  PL/I
#  User interface
#  IBM
#  Codicil (will)
#  T. William Olle
#  Data Base Task Group
#  Technical standard
#  CA, Inc.
#  ANSI
#  Goodrich Corporation
#  Software project management
#  Honeywell
#  Computer programming
#  American National Standards Institute
#  IDMS
#  COBOL
#  Integrated Data Store
#  Digital Equipment Corporation
#  Data processing
#  SQL
#  General Electric
#  Cullinet
#  Partnership
#  Computer industry
#  Charles Babbage Institute
#  Charles Bachman
#  Organic search
#  Free (book)
#  SQL Server Express
#  Angry Birds
#  Steam (software)
#  IGN
#  Capcom
#  The New York Times
#  Problem gambling
#  Pay2Win
#  Freemium Isn't Free
#  Pay to play
#  Early Access
#  App Store (iOS)
#  ABC News
#  Wired (magazine)
#  CCleaner
#  Badoo
#  Chris Anderson (writer)
#  501(c) organization
#  Venture Beat
#  Techcrunch
#  Crippleware
#  Business models for open-source software
#  Fred Wilson (financier)
#  LinkedIn
#  Online Armor Personal Firewall
#  Tiered service
#  Comodo Group
#  Chris Anderson (The Long Tail)
#  Free to play
#  Christian Leaders Institute
#  Valve Corporation
#  Alacra
#  Threshold pledge system
#  The Smurfs (film)
#  Web 2.0
#  Nintendo
#  Pokémon
#  South Park
#  Pay what you want
#  PC World (magazine)
#  Cannibalization (marketing)
#  Paywall
#  Microsoft Imagine
#  Ruby (programming language)
#  Semantic triple
#  Linked Data
#  Neo4J
#  Linux
#  Microsoft Windows
#  Semantic Web
#  SQL
#  Proprietary software
#  Virtuoso Universal Server
#  RDF Database
#  Franz Inc
#  Perl
#  Prolog
#  C Sharp (programming language)
#  Mark Watson
#  Mac OS X
#  Clojure
#  Resource Description Framework
#  Open source
#  Allegro Common Lisp
#  Java (programming language)
#  Python (programming language)
#  OrientDB
#  Lisp (programming language)
#  Peter Norvig
#  Twitter
#  Common Lisp
#  W3C
#  SPARQL
#  Hypertext Transfer Protocol
#  XML
#  Model–view–controller
#  REST
#  CORBA
#  WebSocket
#  Enterprise JavaBeans
#  Manning
#  Apress
#  Factory method pattern
#  Cache (computing)
#  Apache License
#  Java Management Extensions
#  Jetty (web server)
#  Convention over configuration
#  Jolt Awards
#  AspectJ
#  Spring Security
#  Java remote method invocation
#  Java annotation
#  Property (programming)
#  Spring Roo
#  Java Data Objects
#  Hibernate (framework)
#  Stateless Session Bean
#  Apache Axis
#  Ojb
#  Software testing
#  Template method pattern
#  Addison-Wesley Professional
#  Enterprise application integration
#  Apache CXF
#  Web services
#  Inversion of control
#  WAR (file format)
#  Enterprise JavaBean
#  Data access
#  Transaction processing
#  SOAP (protocol)
#  HTTP
#  Distributed transaction
#  Marshalling (computer science)
#  XMPP
#  Reactive Streams
#  Apache Tapestry
#  RMI-IIOP
#  Eclipse (software)
#  TopLink
#  Advice (computer science)
#  Groovy (programming language)
#  Java EE
#  Java Persistence API
#  Servlet container
#  Spring Web Flow
#  Authentication
#  Pivotal Software
#  IMAP
#  SMTP
#  Java Virtual Machine
#  SpringSource
#  Google Guice
#  Cross-platform
#  IBATIS
#  Spring Integration
#  Spring Batch
#  Aspect-oriented programming
#  Hibernate (Java)
#  Apache Cayenne
#  AMQP
#  RDBMS
#  NoSQL
#  Java Message Service
#  Aspect (computer science)
#  Hessian (Web service protocol)
#  Object lifetime
#  Java (programming language)
#  Java Servlet API
#  Wrox Press
#  Self-published
#  MyBatis
#  Rod Johnson (programmer)
#  Datasource
#  Jakarta Struts
#  Java platform
#  Java Database Connectivity
#  Reflection (computer science)
#  Java Servlet
#  JavaBeans
#  Common Object Request Broker Architecture
#  EJB
#  FTP
#  Proxy pattern
#  Project Object Model
#  O'Reilly
#  Java Transaction API
#  Stack Overflow
#  MongoDB
#  Twitter
#  PostgreSQL
#  Microsoft SQL Server
#  Oracle Database
#  LinkedIn
#  Google Trends

# %% [markdown]
# That's quite a few pages.
# This dataset experiences a lot of [combinatorial explosion](https://en.wikipedia.org/wiki/Combinatorial_explosion) due to the large amount of page interconnections.
# It can be difficult to keep combinatorial explosion at bay with large graphs.
#
# When you start branching out from a node,
# you need to start considering the layout of your data and how it impacts routing and path lengths.
# There may be different paths to the same destination,
# and you can bet that's the case with Wikipedia.
#
# Neo4j iterates through paths,
# and since there may be multiple paths to the same destination,
# you may receive the same end node multiple times.
# For example, there are eight paths from `Neo4j` to `SQL`

# %%
data = graph.run("MATCH (a:Page {title: 'Neo4j'})-->(b)-->(c:Page {title:'SQL'}) "
                 "RETURN a.title,b.title,c.title").to_table()
data
# Out:
#  a.title | b.title                        | c.title
# ---------|--------------------------------|---------
#  Neo4j   | ArangoDB                       | SQL
#  Neo4j   | Cypher Query Language          | SQL
#  Neo4j   | Gremlin (programming language) | SQL
#  Neo4j   | OrientDB                       | SQL
#  Neo4j   | AllegroGraph                   | SQL
#  Neo4j   | Graph database                 | SQL
#  Neo4j   | CODASYL                        | SQL
#  Neo4j   | ACID                           | SQL

# %% [markdown]
# You can **deduplicate** returned rows with `RETURN DISTINCT` or by returning a count. You can either count your rows, `COUNT(*)`, or an individual column, `COUNT(c.title)`.
#
# This can be tricky, however. `RETURN DISTINCT` won't actually work with the last query since we're asking for the names of the intermediary pages. Each row is distinct, so nothing happens. If we omit `b.title`, we can deduplicate our results.

# %%
# Notice that we recieve the same results. Each row was already distinct!
data = graph.run("MATCH (a:Page {title: 'Neo4j'})-->(b)-->(c:Page {title:'SQL'}) "
                 "RETURN DISTINCT a.title,b.title,c.title").to_table()
data
# Out:
#  a.title | b.title                        | c.title
# ---------|--------------------------------|---------
#  Neo4j   | Cypher Query Language          | SQL
#  Neo4j   | Gremlin (programming language) | SQL
#  Neo4j   | ArangoDB                       | SQL
#  Neo4j   | ACID                           | SQL
#  Neo4j   | CODASYL                        | SQL
#  Neo4j   | Graph database                 | SQL
#  Neo4j   | AllegroGraph                   | SQL
#  Neo4j   | OrientDB                       | SQL

# %%
# But, when we remove the title of our intermediary page, our results are no longer distinct!
# We can return only the distinct results...
data = graph.run("MATCH (a:Page {title: 'Neo4j'})-->(b)-->(c:Page {title:'SQL'}) "
                 "RETURN DISTINCT a.title,c.title").to_table()
data
# Out:
#  a.title | c.title
# ---------|---------
#  Neo4j   | SQL

# %%
# Or count them!
data = graph.run(
    "MATCH (a:Page {title: 'Neo4j'})-->(b)-->(c:Page {title:'SQL'}) "
    "RETURN a.title,c.title, count(*)"
).to_table()
data
# Out:
#  a.title | c.title | count(*)
# ---------|---------|----------
#  Neo4j   | SQL     |        8

# %% [markdown]
# ----------
# The `WITH` clause lets you separate different sections of a query, only forwarding along the variables you explicitly ask for.
# Not only does this let you rename or get rid of extra variables, but you can perform intermediary operations that you can't call directly in other clauses.
# You can even use the results of one `MATCH` statement in another.
#
# **Important**: This is one of the most powerful aspects of Cypher query construction, please move slowly through this portion to solidify your understanding.
#
# Note that the variables created by the `WITH` clause cannot be used until after the `WITH` clause is complete, e.g. instead of
#
# `WITH COLLECT(DISTINCT b) as b_list, COLLECT(DISTINCT c) as c_list, SIZE(b_list)+SIZE(c_list) as total_size`
#
# you would need to use
#
# `WITH COLLECT(DISTINCT b) as b_list, COLLECT(DISTINCT c) as c_list
# WITH SIZE(b_list)+SIZE(c_list) as total_size, b_list as b_list, c_list as c_list`
#
# in order to use `total_size`, `b_list`, and `c_list` in your following clauses.

# %%
# Splitting your query up as shown above can introduce tricky errors if you're not careful.
# It's very easy to forget spaces at the ends of lines and accidentally run bad queries.
# Error messages from the server will often not display properly, either.

# You may want to use multiline strings for long queries.
# These strings will contain line breaks, so you don't have to worry about proper spacing)
query="""
MATCH (a:Page {title: 'Neo4j'})-->(b)-->(c:Page {title:'SQL'})
WITH a.title AS a, c.title AS b, COUNT(*) AS total
RETURN a,b,total
"""
data = graph.run(query).to_table()
data
# Out:
#  a     | b   | total
# -------|-----|-------
#  Neo4j | SQL |     8

# %%
# testing
query="""
MATCH (a:Page {title: 'Neo4j'})-->(b)-->(c:Page {title:'SQL'})
WITH a.title AS a ,b.title AS b,c.title AS c, COUNT(*) AS total
RETURN a,b,c,total
"""
data = graph.run(query).to_table()
data
# Out:
#  a     | b                              | c   | total
# -------|--------------------------------|-----|-------
#  Neo4j | AllegroGraph                   | SQL |     1
#  Neo4j | ACID                           | SQL |     1
#  Neo4j | ArangoDB                       | SQL |     1
#  Neo4j | OrientDB                       | SQL |     1
#  Neo4j | Cypher Query Language          | SQL |     1
#  Neo4j | Graph database                 | SQL |     1
#  Neo4j | CODASYL                        | SQL |     1
#  Neo4j | Gremlin (programming language) | SQL |     1

# %% [markdown]
# ### <span style="background:yellow">Your Turn</span>
#
# Modify your previous query to return the titles of pages two hops away from Neo4j (outgoing) and the number of paths to that page (descending). Sort the results by the number of paths, only returning pages with multiple paths.
#
# You will most likely need to use the `WITH` clause to organize your results before sorting and filtering them.

# %%
# M4:P2:Q1

# Modify your previous query to return the page title and number of paths to the page.
#  Sort the results by descending path count, 
#  omitting any pages with only one path from Neo4j to it.
# You will most likely need to use the WITH clause to organize your intermediary results
# ----------------------------


query="""
MATCH (a:Page {title: 'Neo4j'})-->()-->(c)
WITH  a.title AS a,c.title AS c, COUNT(*) AS total
WHERE total > 1
RETURN c,total
ORDER BY total DESC
    
"""

data = graph.run(query).to_table()
print(data)
# Out:
#  c                                                                | total
# ------------------------------------------------------------------|-------
#  SQL                                                              |     8
#  Java (programming language)                                      |     6
#  Neo4j                                                            |     5
#  Association football                                             |     5
#  European Union                                                   |     5
#  Denmark                                                          |     5
#  United Nations                                                   |     5
#  United States Census Bureau                                      |     4
#  International Monetary Fund                                      |     4
#  Twitter                                                          |     4
#  The New York Times                                               |     4
#  Encyclopædia Britannica                                          |     4
#  Linux                                                            |     4
#  Norway                                                           |     4
#  Italy                                                            |     4
#  SPARQL                                                           |     4
#  United States                                                    |     4
#  BBC News                                                         |     4
#  Allies of World War II                                           |     4
#  Apache License                                                   |     4
#  Copenhagen                                                       |     4
#  Spain                                                            |     4
#  Apple Inc.                                                       |     4
#  NoSQL                                                            |     4
#  World War II                                                     |     4
#  Microsoft                                                        |     4
#  GNU General Public License                                       |     3
#  NATO                                                             |     3
#  Groovy (programming language)                                    |     3
#  National Hockey League                                           |     3
#  Warsaw Pact                                                      |     3
#  Los Angeles                                                      |     3
#  Protestantism                                                    |     3
#  National Football League                                         |     3
#  Latin                                                            |     3
#  Cross-platform                                                   |     3
#  C Sharp (programming language)                                   |     3
#  United Nations Development Programme                             |     3
#  IBM                                                              |     3
#  JSON                                                             |     3
#  Sun Microsystems                                                 |     3
#  Romania                                                          |     3
#  New World                                                        |     3
#  Christopher Columbus                                             |     3
#  Major League Soccer                                              |     3
#  Soviet Union                                                     |     3
#  Oracle Corporation                                               |     3
#  Hypertext Transfer Protocol                                      |     3
#  American football                                                |     3
#  Objective-C                                                      |     3
#  Portugal                                                         |     3
#  Routledge                                                        |     3
#  Arctic Ocean                                                     |     3
#  National Basketball Association                                  |     3
#  Pacific Ocean                                                    |     3
#  Poland                                                           |     3
#  Java virtual machine                                             |     3
#  Facebook                                                         |     3
#  Prehistoric migration and settlement of the Americas from Asia   |     3
#  Stockholm                                                        |     3
#  Oxford University Press                                          |     3
#  Alaska                                                           |     3
#  Midwestern United States                                         |     3
#  Microsoft SQL Server                                             |     3
#  Bosnia and Herzegovina                                           |     3
#  Africa                                                           |     3
#  Russia                                                           |     3
#  Microsoft Windows                                                |     3
#  Turkey                                                           |     3
#  World War I                                                      |     3
#  Netherlands                                                      |     3
#  Apache Software Foundation                                       |     3
#  Java Database Connectivity                                       |     3
#  Industrial Revolution                                            |     3
#  Python (programming language)                                    |     3
#  California                                                       |     3
#  GNU Affero General Public License                                |     3
#  North American Numbering Plan                                    |     3
#  Russian Empire                                                   |     3
#  Wall Street Crash of 1929                                        |     3
#  Google                                                           |     3
#  JavaScript                                                       |     3
#  Protestant Reformation                                           |     3
#  English language                                                 |     3
#  Eurasia                                                          |     3
#  Serbia                                                           |     3
#  Cold War                                                         |     3
#  Gulf Stream                                                      |     3
#  Mexico                                                           |     3
#  Document-oriented database                                       |     3
#  Americas                                                         |     3
#  Atlantic Ocean                                                   |     3
#  Major League Baseball                                            |     3
#  United Kingdom                                                   |     3
#  Berlin                                                           |     3
#  O'Reilly Media                                                   |     3
#  French language                                                  |     3
#  Iran                                                             |     3
#  C++                                                              |     3
#  Asia                                                             |     3
#  OrientDB                                                         |     3
#  Spanish language                                                 |     3
#  GraphQL                                                          |     2
#  Indian American                                                  |     2
#  Native Americans in the United States                            |     2
#  Free Software Foundation                                         |     2
#  Louisiana                                                        |     2
#  Non-Hispanic whites                                              |     2
#  Nuuk                                                             |     2
#  Muslims                                                          |     2
#  Wired (magazine)                                                 |     2
#  Helsingør                                                        |     2
#  Skanska                                                          |     2
#  Four Corners                                                     |     2
#  Join (SQL)                                                       |     2
#  Alta California                                                  |     2
#  List of U.S. states by date of admission to the Union            |     2
#  Great Lakes                                                      |     2
#  Nobel Prize in Literature                                        |     2
#  The Guardian                                                     |     2
#  Canada                                                           |     2
#  Scandinavian Mountains                                           |     2
#  Ontotext                                                         |     2
#  Affero General Public License                                    |     2
#  Yalta Conference                                                 |     2
#  Enterprise JavaBeans                                             |     2
#  RDF Database                                                     |     2
#  List of countries by GDP (PPP) per capita                        |     2
#  Belgium                                                          |     2
#  Legislature                                                      |     2
#  Harvard University                                               |     2
#  American bison                                                   |     2
#  Clojure                                                          |     2
#  Baku                                                             |     2
#  List of countries by population                                  |     2
#  Luxembourg                                                       |     2
#  Cambridge University Press                                       |     2
#  European colonization of the Americas                            |     2
#  United Nations Conference on International Organization          |     2
#  Parliamentary system                                             |     2
#  Western civilization                                             |     2
#  Filipino American                                                |     2
#  Southern Europe                                                  |     2
#  University of California, Berkeley                               |     2
#  San Francisco                                                    |     2
#  Programming language                                             |     2
#  Norrköping                                                       |     2
#  Black Sea                                                        |     2
#  Alaska Natives                                                   |     2
#  World Health Organization                                        |     2
#  AQL (ArangoDB Query Language)                                    |     2
#  The Cardigans                                                    |     2
#  Third World                                                      |     2
#  Karlskrona                                                       |     2
#  Charles XII of Sweden                                            |     2
#  Massachusetts Institute of Technology                            |     2
#  Laurentia                                                        |     2
#  Russians                                                         |     2
#  Mississippian culture                                            |     2
#  Great Depression                                                 |     2
#  World Economic Forum                                             |     2
#  Aruba                                                            |     2
#  Oracle Database                                                  |     2
#  Black Death                                                      |     2
#  Eurozone                                                         |     2
#  Baptists                                                         |     2
#  Nordic Council                                                   |     2
#  Kingdom of Great Britain                                         |     2
#  Middle Ages                                                      |     2
#  Latin language                                                   |     2
#  Beringia                                                         |     2
#  IBM Information Management System                                |     2
#  Ingmar Bergman                                                   |     2
#  Martin Luther                                                    |     2
#  Europe                                                           |     2
#  CNNMoney                                                         |     2
#  Organisation for Economic Co-operation and Development           |     2
#  International dollar                                             |     2
#  Islam                                                            |     2
#  List of continents by population                                 |     2
#  Clojure (programming language)                                   |     2
#  Roman Catholic Church                                            |     2
#  Baltic Sea                                                       |     2
#  Graph database                                                   |     2
#  Common Object Request Broker Architecture                        |     2
#  Chicago metropolitan area                                        |     2
#  Java Management Extensions                                       |     2
#  Dissolution of the Soviet Union                                  |     2
#  Cypher Query Language                                            |     2
#  Latin America                                                    |     2
#  Amerigo Vespucci                                                 |     2
#  Gothenburg                                                       |     2
#  Polish–Lithuanian Commonwealth                                   |     2
#  Curaçao                                                          |     2
#  West Coast of the United States                                  |     2
#  Age of Discovery                                                 |     2
#  List of continents by GDP (nominal)                              |     2
#  Northern California                                              |     2
#  HTTP                                                             |     2
#  Holy Roman Empire                                                |     2
#  British Empire                                                   |     2
#  Aleutian Islands                                                 |     2
#  Paleo-Indians                                                    |     2
#  Ronald Reagan                                                    |     2
#  Lund University                                                  |     2
#  Gigaom                                                           |     2
#  Multiracial Americans                                            |     2
#  Multi-model database                                             |     2
#  Washington, D.C.                                                 |     2
#  Functional programming                                           |     2
#  Hyllie railway station                                           |     2
#  Greenland                                                        |     2
#  Germany                                                          |     2
#  Copenhagen Malmö Port                                            |     2
#  2010 United States Census                                        |     2
#  Surrender of Japan                                               |     2
#  Nationalencyklopedin                                             |     2
#  New York metropolitan area                                       |     2
#  France                                                           |     2
#  Wicca                                                            |     2
#  Santa Cruz, California                                           |     2
#  Global Competitiveness Report                                    |     2
#  Copenhagen Airport                                               |     2
#  Area and population of European countries                        |     2
#  Modern liberalism in the United States                           |     2
#  LinkedIn                                                         |     2
#  Cyprus                                                           |     2
#  Puerto Rico                                                      |     2
#  Norwegian language                                               |     2
#  Øresund                                                          |     2
#  New England                                                      |     2
#  Asian American                                                   |     2
#  Appalachian Mountains                                            |     2
#  Western Europe                                                   |     2
#  The Economist                                                    |     2
#  Immigration to the United States                                 |     2
#  List of best-selling music artists                               |     2
#  Martin Waldseemüller                                             |     2
#  Proprietary software                                             |     2
#  Million Programme                                                |     2
#  United Nations Charter                                           |     2
#  Germanic languages                                               |     2
#  XML                                                              |     2
#  Corruption Perceptions Index                                     |     2
#  Basketball                                                       |     2
#  Marshall Plan                                                    |     2
#  Provinces of Sweden                                              |     2
#  List of IMF ranked countries by past and projected GDP (nominal) |     2
#  Spanish colonization of the Americas                             |     2
#  Scala (programming language)                                     |     2
#  North Africa                                                     |     2
#  The Linux Foundation                                             |     2
#  Napoleonic Wars                                                  |     2
#  National Public Radio                                            |     2
#  Democratic Party (United States)                                 |     2
#  Richard Stallman                                                 |     2
#  Finnish language                                                 |     2
#  First Transcontinental Railroad                                  |     2
#  Lutheranism                                                      |     2
#  Axis powers                                                      |     2
#  FIFA World Cup                                                   |     2
#  New Mexico                                                       |     2
#  PDF                                                              |     2
#  African Americans                                                |     2
#  Laurasia                                                         |     2
#  Eastern Orthodox Church                                          |     2
#  1994 FIFA World Cup                                              |     2
#  Caribbean Sea                                                    |     2
#  CNN                                                              |     2
#  ArangoDB                                                         |     2
#  African American                                                 |     2
#  Nordic countries                                                 |     2
#  Estonia                                                          |     2
#  The World Factbook                                               |     2
#  Pacific Plate                                                    |     2
#  Holy Roman Emperor                                               |     2
#  United States Virgin Islands                                     |     2
#  Riga                                                             |     2
#  Resource Description Framework                                   |     2
#  Council of Europe                                                |     2
#  Apache Cassandra                                                 |     2
#  MongoDB                                                          |     2
#  User interface                                                   |     2
#  Los Angeles metropolitan area                                    |     2
#  Norsemen                                                         |     2
#  Population history of indigenous peoples of the Americas         |     2
#  New York City                                                    |     2
#  Java annotation                                                  |     2
#  Sint Maarten                                                     |     2
#  Greece                                                           |     2
#  Executive (government)                                           |     2
#  Common Lisp                                                      |     2
#  Swedish Meteorological and Hydrological Institute                |     2
#  Sweden                                                           |     2
#  Central European Time                                            |     2
#  Mississippi River                                                |     2
#  North America                                                    |     2
#  Öresund Bridge                                                   |     2
#  Suriname                                                         |     2
#  Fennoscandia                                                     |     2
#  Swedish krona                                                    |     2
#  Zlatan Ibrahimović                                               |     2
#  Britney Spears                                                   |     2
#  Academy Awards                                                   |     2
#  Anabaptists                                                      |     2
#  World Bank                                                       |     2
#  Irreligion                                                       |     2
#  Catholic Church                                                  |     2
#  Great Plains                                                     |     2
#  Software relicensing                                             |     2
#  Phoenix, Arizona                                                 |     2
#  Germanic peoples                                                 |     2
#  Clovis culture                                                   |     2
#  Hinduism                                                         |     2
#  Statistics Sweden                                                |     2
#  Helsingborg                                                      |     2
#  DataStax                                                         |     2
#  Amazon.com                                                       |     2
#  Lithuania                                                        |     2
#  Computer Weekly                                                  |     2
#  List of countries by area                                        |     2
#  Katy Perry                                                       |     2
#  Virtuoso Universal Server                                        |     2
#  Indigenous peoples of the Americas                               |     2
#  Arabic language                                                  |     2
#  Vietnam War                                                      |     2
#  Philippines                                                      |     2
#  Denali                                                           |     2
#  Swedish Social Democratic Party                                  |     2
#  George Lucas                                                     |     2
#  RDBMS                                                            |     2
#  C (programming language)                                         |     2
#  Houston                                                          |     2
#  Hungary                                                          |     2
#  Navassa Island                                                   |     2
#  International Futures                                            |     2
#  Gremlin (programming language)                                   |     2
#  Thirty Years War                                                 |     2
#  Java platform                                                    |     2
#  American Jews                                                    |     2
#  Ystad                                                            |     2
#  Hanseatic League                                                 |     2
#  ABC News                                                         |     2
#  Franklin D. Roosevelt                                            |     2
#  Max von Sydow                                                    |     2
#  California Gold Rush                                             |     2
#  Christianity                                                     |     2
#  List of countries by GDP (PPP)                                   |     2
#  Java Transaction API                                             |     2
#  Caribbean                                                        |     2
#  Central European Summer Time                                     |     2
#  Latvia                                                           |     2
#  Alexander Archipelago                                            |     2
#  Florida                                                          |     2
#  Kristianstad                                                     |     2
#  North American Plate                                             |     2
#  Mariehamn                                                        |     2
#  Oceania                                                          |     2
#  Chicago                                                          |     2
#  List of countries by past and projected GDP (PPP)                |     2
#  ACID                                                             |     2
#  New York City metropolitan area                                  |     2
#  Endangered Species Act                                           |     2
#  Caspian Sea                                                      |     2
#  Culture of the United States                                     |     2
#  Kosovo                                                           |     2
#  GitHub                                                           |     2
#  List of continents by area                                       |     2
#  San Andreas fault                                                |     2
#  Mexican Americans                                                |     2
#  Flag                                                             |     2
#  List of countries by GDP (nominal) per capita                    |     2
#  Amtrak                                                           |     2
#  Central Powers                                                   |     2
#  InfiniteGraph                                                    |     2
#  Los Angeles Times                                                |     2
#  Oregon                                                           |     2
#  White Americans                                                  |     2
#  Barents Sea                                                      |     2
#  Object database                                                  |     2
#  Swedish-Norwegian Union                                          |     2
#  Pacific Islands Americans                                        |     2
#  Pew Research Center                                              |     2
#  COBOL                                                            |     2
#  Eurostat                                                         |     2
#  Cuba                                                             |     2
#  Apache Hadoop                                                    |     2
#  Pacific Northwest                                                |     2
#  Middle East                                                      |     2
#  European Economic Community                                      |     2
#  Arctic Circle                                                    |     2
#  Object-oriented programming                                      |     2
#  Atlanta                                                          |     2
#  North American Free Trade Agreement                              |     2
#  Super Bowl                                                       |     2
#  Finland                                                          |     2
#  Internet                                                         |     2
#  Rome                                                             |     2
#  Intel                                                            |     2
#  Lund                                                             |     2
#  Stack Overflow                                                   |     2
#  Baseball                                                         |     2
#  Gulf of Mexico                                                   |     2
#  United States Environmental Protection Agency                    |     2
#  License compatibility                                            |     2
#  Eastern Hemisphere                                               |     2
#  Treaty of Versailles                                             |     2
#  Estonian language                                                |     2
#  Rocky Mountains                                                  |     2
#  Central Europe                                                   |     2
#  Municipalities of Sweden                                         |     2
#  Java remote method invocation                                    |     2
#  Metallica                                                        |     2
#  Tatars                                                           |     2
#  Federal Bureau of Investigation                                  |     2
#  Hawaii                                                           |     2
#  UEFA Euro 1992                                                   |     2
#  Empire of Japan                                                  |     2
#  Kalmar                                                           |     2
#  Great Basin                                                      |     2
#  Scandinavia                                                      |     2
#  Ruby (programming language)                                      |     2
#  Republican Party (United States)                                 |     2
#  BBC                                                              |     2
#  Øresund Region                                                   |     2
#  Asian Americans                                                  |     2
#  Scania                                                           |     2
#  Skåneland                                                        |     2
#  Navigational database                                            |     2
#  List of countries by GDP (nominal)                               |     2
#  Southern California                                              |     2
#  Key-value database                                               |     2
#  European Parliament                                              |     2
#  Northern Hemisphere                                              |     2
#  Øresund Bridge                                                   |     2
#  U.S. state                                                       |     2
#  Eastern Orthodox                                                 |     2
#  Bering Strait                                                    |     2
#  Coca-Cola                                                        |     2
#  Alfred A. Knopf                                                  |     2
#  Eclipse (software)                                               |     2
#  President of the United States                                   |     2
#  Mexican–American War                                             |     2
#  Constantinople                                                   |     2
#  Azerbaijan                                                       |     2
#  Nikola Tesla                                                     |     2
#  Linux kernel                                                     |     2
#  Opposition to United States involvement in the Vietnam War       |     2
#  Human Development Index                                          |     2
#  UNESCO                                                           |     2
#  Washington (state)                                               |     2
#  Brazil                                                           |     2
#  Silicon Valley                                                   |     2
#  Hispanic and Latino Americans                                    |     2
#  Eben Moglen                                                      |     2
#  Helsinki                                                         |     2
#  San Jose, California                                             |     2

# %% [markdown]
# We've mostly focused on single hops in a single direction. Let's observe the combinatorial  explosion of results in both directions from Neo4j. The second query uses the variable length path syntax.

# %%
data = graph.run("MATCH (a:Page {title: 'Neo4j'})<-->(b) RETURN COUNT(DISTINCT b)").to_table()
print(data[0][0], "pages one hop from Neo4j")

data = graph.run("MATCH (a:Page {title: 'Neo4j'})<-[*2]->(b) RETURN COUNT(DISTINCT b)").to_table()
print(data[0][0], "pages two hops from
      Neo4j")
# Out:
# 47 pages one hop from Neo4j
# 436479 pages two hops from Neo4j

# %% [markdown]
# That's 3% of Wikipedia within two hops of Neo4j!
# But, once again, we have some routing ambiguities hidden away in those queries.
#
# Neo4j, for example, links to the pages for Sweden and its capital, Malmö. Malmö and Sweden, as you may expect, link to each other.
# At one hop, this is fine.
# We receive `Neo4j->Malmö` and `Neo4j->Sweden`.
# At two hops, we receive `Neo4j->Sweden->Malmö` and `Neo4j->Malmö->Sweden`,
# so our second query contains some of the same pages from our first.
#
# Let's take a look at which pages overlap by collecting our one and two hop node lists and returning a titles that overlap.
#
# To do this, we're going to have to do some list trickery:
# 1. First, we use `COLLECT` and `DISTINCT` to build lists out of our rows of `b` and `c` nodes.
# 1. Then, we use a combined list filter and property extraction to create a list of nodes in `one_hop` that are also in `two_hop`. If a node passes the check, we add its title to the list.
#     * Take a look at the List Expressions section of the [Cypher Reference Card](https://neo4j.com/docs/cypher-refcard/3.3/)
# 1. Finally, we `UNWIND` the list to return the titles as individual rows.
#     * If we didn't do this, we would receive one row containing a list of all our titles, which won't display nicely without more effort.

# %%
data = graph.run("MATCH (a:Page {title: 'Neo4j'})<-->(b)<-->(c) "
                 "WITH COLLECT(DISTINCT b) AS one_hop, COLLECT(DISTINCT c) AS two_hop "
                 "WITH [x IN one_hop WHERE x IN two_hop | x.title] AS shared_title_list "
                 "UNWIND shared_title_list AS shared "
                 "RETURN shared").to_table()
data
# Out:
#  shared
# ---------------------------------------------------
#  Apache Giraph
#  United States
#  Gremlin (programming language)
#  Malmö
#  North America
#  OrientDB
#  Sweden
#  Java (programming language)
#  ArangoDB
#  San Francisco Bay Area
#  Cypher Query Language
#  ACID
#  Europe
#  Graph database
#  Affero General Public License
#  GNU General Public License
#  CODASYL
#  AllegroGraph
#  Spring Framework
#  DB-Engines ranking
#  Paradise Papers
#  Linkurious
#  List of TCP and UDP port numbers
#  Query language
#  Spatial database
#  List of JVM languages
#  DataNucleus
#  NoSQL
#  Comparison of structured storage software
#  Neo4J
#  FlockDB
#  GameDuell
#  Rod Johnson (programmer)
#  Jelastic
#  Hybrid transactional/analytical processing (HTAP)
#  Bolt (network protocol)

# %% [markdown]
# Lets now modify the previous query to return:
#  1. the count of distinct nodes one hop away from Neo4j
#  2. the count of distinct nodes two hops away from Neo4j
#  3. the number of nodes shared between 1 and 2
#  4. the number of nodes in 2 but not 1

# %%
# Using the previous query, we construct a query to get the counts of the following:
#  A) nodes one hop away
#  B) nodes two hops away
#  C) nodes shared between A and B
#  D) nodes in B but not A
# ----------------------------

data = graph.run("MATCH (a:Page {title: 'Neo4j'})<-->(b)<-->(c) "
                 "WITH COLLECT(DISTINCT b) as one_hop, COLLECT(DISTINCT c) as two_hop "
                 "WITH LENGTH(one_hop) as A, LENGTH(two_hop) as B, "
                 " LENGTH(FILTER(x IN one_hop WHERE x IN two_hop)) as C "
                 "RETURN A,B,C,B - C as in_B_not_A").to_table()
data
# Out:
#   A |      B |  C | in_B_not_A
# ----|--------|----|------------
#  47 | 436479 | 36 |     436443

# %% [markdown]
# ----------
# Let's do one last round of analysis.
# Some pages have an incredible number of links.
# Let's look at the pages with the most incoming and outgoing links.
#
# ### <span style="background:yellow">Your Turn</span>
#
# Identify the top 200 pages with the highest number of outgoing links. Return the page title and number of links.
# Repeat this with incoming links.
#
# **NOTE: These queries naturally take some significant time (up to 5 minutes!) as we must count and sort large amounts of data**

# %%
# M4:P2:Q2

# Construct a query to tabulate the number of 
#  outgoing links from a page.
# Use this to query the top 200 pages with 
#  the most outgoing links and return the 
#  title and link count.
# Repeat with incoming links in the following cell.
# ----------------------------

query = """
MATCH (a:Page)-[r]->()
WITH DISTINCT a AS page, COUNT(r) AS outcoming_links
RETURN page.title,outcoming_links

ORDER BY outcoming_links DESC
LIMIT 200
"""

top_outgoing = graph.run(query).to_table()
print(top_outgoing)
# Out:
#  page.title                                                                     | outcoming_links
# --------------------------------------------------------------------------------|-----------------
#  List of current U.S. state legislators                                         |            8069
#  List of least concern birds                                                    |            8029
#  List of people from Illinois                                                   |            7773
#  List of birds of the world                                                     |            6917
#  List of stage names                                                            |            6530
#  List of cities, towns and villages in Kerman Province                          |            5839
#  List of film director and actor collaborations                                 |            5780
#  Index of Telangana-related articles                                            |            5743
#  Index of Andhra Pradesh-related articles                                       |            5679
#  List of municipalities of Brazil                                               |            5584
#  List of years in jazz                                                          |            5522
#  Alphabetical list of comunes of Italy                                          |            5475
#  List of least concern fishes                                                   |            5352
#  Index of India-related articles                                                |            5300
#  Index of philosophy articles (I–Q)                                             |            5107
#  Index of Italy-related articles                                                |            5066
#  List of United States television markets                                       |            5030
#  List of people from Texas                                                      |            4974
#  List of dialling codes in Germany                                              |            4938
#  Coverage of Google Street View                                                 |            4826
#  List of biographical films                                                     |            4825
#  IUCN Red List vulnerable species (Animalia)                                    |            4751
#  Timeline of heavy metal and hard rock music                                    |            4738
#  List of populated places in Serbia                                             |            4711
#  List of places named after people                                              |            4686
#  List of performances on Top of the Pops                                        |            4658
#  List of populated places in Serbia (alphabetic)                                |            4652
#  List of composers by name                                                      |            4627
#  List of birds by common name                                                   |            4616
#  List of film director and composer collaborations                              |            4610
#  List of American television programs by debut date                             |            4447
#  List of vulnerable plants                                                      |            4374
#  List of United States counties and county equivalents                          |            4311
#  List of cities, towns and villages in Fars Province                            |            4224
#  List of cities, towns and villages in Khuzestan Province                       |            4164
#  List of populated places in Bosnia and Herzegovina                             |            4083
#  Index of Byzantine Empire-related articles                                     |            3929
#  List of reality television show franchises                                     |            3854
#  List of film director and cinematographer collaborations                       |            3850
#  List of Paramount Pictures films                                               |            3833
#  List of film score composers                                                   |            3823
#  List of village development committees of Nepal                                |            3759
#  List of directorial debuts                                                     |            3757
#  List of Catholic dioceses (structured view)                                    |            3742
#  List of Hillary Clinton presidential campaign non-political endorsements, 2016 |            3693
#  List of cities, towns and villages in Razavi Khorasan Province                 |            3588
#  List of birds of South America                                                 |            3563
#  List of state leaders in the 20th century (1951–2000)                          |            3547
#  Index of U.S. counties                                                         |            3521
#  List of indoor arenas                                                          |            3505
#  Index of World War II articles (U)                                             |            3504
#  IUCN Red List data deficient species (Chordata)                                |            3494
#  List of 2017 albums                                                            |            3475
#  2015 in film                                                                   |            3461
#  List of Turkish exonyms                                                        |            3439
#  List of Cornell University alumni                                              |            3437
#  Google Street View in the United States                                        |            3426
#  List of college towns                                                          |            3421
#  Index of Sri Lanka-related articles (S)                                        |            3386
#  List of least concern plants                                                   |            3376
#  List of Lepidoptera of Romania                                                 |            3371
#  List of children's television series by country                                |            3351
#  2013 in film                                                                   |            3322
#  List of Lepidoptera of Germany                                                 |            3301
#  Index of law articles                                                          |            3294
#  Index of philosophy articles (R–Z)                                             |            3289
#  List of Gothic brick buildings                                                 |            3289
#  List of districts in Russia                                                    |            3288
#  List of aircraft by date and usage category                                    |            3285
#  List of counties by U.S. state                                                 |            3276
#  2018 in sports                                                                 |            3259
#  Timeline of London                                                             |            3256
#  List of Lepidoptera of Slovakia                                                |            3248
#  List of local administrative units of Romania                                  |            3236
#  2017 in film                                                                   |            3227
#  List of birds of Asia                                                          |            3226
#  List of Lepidoptera of Switzerland                                             |            3216
#  List of least concern mammals                                                  |            3214
#  List of postal codes in Germany                                                |            3201
#  List of United States counties by per capita income                            |            3195
#  List of University of Pennsylvania people                                      |            3189
#  List of entries in the Eurovision Song Contest                                 |            3167
#  List of Lepidoptera of Hungary                                                 |            3162
#  List of college sports team nicknames                                          |            3127
#  List of Lepidoptera of the Czech Republic                                      |            3121
#  List of cities, towns and villages in Mazandaran Province                      |            3115
#  2014 in film                                                                   |            3113
#  List of women writers                                                          |            3112
#  List of Christian Brothers school alumni                                       |            3106
#  List of Catholic dioceses (alphabetical)                                       |            3101
#  2009 in film                                                                   |            3101
#  Index of Singapore-related articles                                            |            3082
#  List of Hillary Clinton presidential campaign political endorsements, 2016     |            3080
#  List of people with surname Williams                                           |            3080
#  List of special routes of the United States Numbered Highway System            |            3071
#  2017 in American television                                                    |            3052
#  List of sports films                                                           |            3050
#  List of rodents                                                                |            3047
#  List of years                                                                  |            3037
#  Timeline of United States history                                              |            3037
#  List of 2016 albums                                                            |            3022
#  List of deaths in rock and roll                                                |            3017
#  Index of philosophy articles (D–H)                                             |            3003
#  IUCN Red List endangered species (Animalia)                                    |            2987
#  Timeline of historical geopolitical changes                                    |            2974
#  List of country houses in the United Kingdom                                   |            2973
#  List of places named after people in the United States                         |            2954
#  List of association football stadiums by country                               |            2943
#  List of 21st-century classical composers                                       |            2941
#  List of Lepidoptera of Poland                                                  |            2936
#  List of cities, towns and villages in West Azerbaijan Province                 |            2936
#  List of association football families                                          |            2934
#  List of Pennsylvania locations by per capita income                            |            2932
#  List of Test cricketers                                                        |            2919
#  List of Columbia College people                                                |            2917
#  Index of philosophy articles (A–C)                                             |            2916
#  List of operas by composer                                                     |            2911
#  List of counties in the People's Republic of China                             |            2899
#  IUCN Red List near threatened species (Animalia)                               |            2898
#  List of guitarists                                                             |            2893
#  Index of ancient Egypt-related articles                                        |            2890
#  List of auxiliaries of the United States Navy                                  |            2886
#  List of coupled cousins                                                        |            2866
#  2012 in film                                                                   |            2860
#  List of cities, towns and villages in Lorestan Province                        |            2855
#  Records of members of parliament of the United Kingdom                         |            2843
#  List of musical supergroups                                                    |            2838
#  List of Warner Bros. films                                                     |            2834
#  List of Lepidoptera of Greece                                                  |            2808
#  List of Russian people                                                         |            2804
#  Index of Chile-related articles                                                |            2795
#  List of cities, towns and villages in East Azerbaijan Province                 |            2775
#  List of Harvard University people                                              |            2774
#  List of communities in Ontario                                                 |            2773
#  Reading and Leeds Festivals line-ups                                           |            2770
#  List of courthouses in the United States                                       |            2766
#  List of war films and TV specials                                              |            2751
#  List of one-word stage names                                                   |            2750
#  List of statistics articles                                                    |            2749
#  Timeline of musical events                                                     |            2746
#  Culture of the United Kingdom                                                  |            2745
#  List of cities, towns and villages in Gilan Province                           |            2739
#  List of Universal Pictures films                                               |            2726
#  1987 in film                                                                   |            2710
#  List of municipalities and towns in Slovakia                                   |            2709
#  2006 in film                                                                   |            2683
#  2016 in film                                                                   |            2678
#  List of political families                                                     |            2675
#  List of show business families                                                 |            2661
#  List of moths of North America (MONA 8322-11233)                               |            2655
#  2016 in the United States                                                      |            2652
#  1998 in film                                                                   |            2643
#  Index of fashion articles                                                      |            2634
#  List of cities, towns and villages in Kermanshah Province                      |            2618
#  2010 in film                                                                   |            2609
#  List of Lepidoptera of Bulgaria                                                |            2606
#  Index of Fiji-related articles                                                 |            2580
#  List of 2014 albums                                                            |            2579
#  October 2011 in sports                                                         |            2565
#  List of music venues                                                           |            2557
#  List of municipalities of Switzerland                                          |            2552
#  List of endangered plants                                                      |            2551
#  List of Malaysia-related topics                                                |            2550
#  List of 2006 albums                                                            |            2549
#  List of minor planets named after people                                       |            2547
#  2017 in sports                                                                 |            2546
#  List of postal codes in China                                                  |            2536
#  List of Lepidoptera of Ukraine                                                 |            2536
#  2004 in music                                                                  |            2536
#  List of birds of Africa                                                        |            2526
#  Index of Sri Lanka-related articles (M)                                        |            2524
#  2003 in music                                                                  |            2512
#  List of 2015 albums                                                            |            2510
#  2017 in the United States                                                      |            2506
#  List of international airports by country                                      |            2506
#  List of OMIM disorder codes                                                    |            2496
#  List of songs about New York City                                              |            2490
#  List of moths of Sweden                                                        |            2478
#  List of aircraft engines                                                       |            2477
#  List of American novelists                                                     |            2472
#  List of Columbia Pictures films                                                |            2471
#  List of cutaneous conditions                                                   |            2460
#  List of male golfers                                                           |            2458
#  2001 in music                                                                  |            2444
#  List of One Day International cricketers                                       |            2442
#  List of assassinations in fiction                                              |            2441
#  Chronological summary of the 2016 Summer Olympics                              |            2434
#  List of Pro Bowl players                                                       |            2433
#  Index of Bangladesh-related articles                                           |            2432
#  List of lead vocalists                                                         |            2422
#  List of United States Congress members who died in office (1900–49)            |            2419
#  List of Metro-Goldwyn-Mayer films                                              |            2413
#  List of bass guitarists                                                        |            2403
#  List of Lepidoptera of Denmark                                                 |            2403
#  List of concert halls                                                          |            2402
#  List of films based on actual events                                           |            2400
#  List of singer-songwriters                                                     |            2392
#  2003 in film                                                                   |            2388
#  July 2011 in sports                                                            |            2384
#  List of comedy films of the 2000s                                              |            2384

# %%
# M4:P2:Q3

# Construct a query to tabulate the number of 
#  incoming links from a page.
# Use this to query the top 200 pages with 
# the most incoming links and return the title and link count.
# ----------------------------

# EDIT THIS

query = """
MATCH (a:Page)<-[r]-()
WITH DISTINCT a AS page, COUNT(r) AS incoming_links
RETURN page.title,incoming_links

ORDER BY incoming_links DESC
LIMIT 200

"""

top_incoming = graph.run(query).to_table()
print(top_incoming)
# Out:
#  page.title                              | incoming_links
# -----------------------------------------|----------------
#  United States                           |         331597
#  Animal                                  |         159059
#  France                                  |         144828
#  India                                   |         127492
#  World War II                            |         125771
#  Germany                                 |         122335
#  Arthropod                               |         119766
#  Insect                                  |         112641
#  New York City                           |         108355
#  United Kingdom                          |         107240
#  Canada                                  |         106777
#  England                                 |         104468
#  London                                  |          98024
#  List of sovereign states                |          94731
#  U.S. state                              |          94178
#  Australia                               |          93697
#  Italy                                   |          91665
#  Iran                                    |          88716
#  Japan                                   |          86937
#  The New York Times                      |          78767
#  Association football                    |          77959
#  California                              |          77517
#  Poland                                  |          74829
#  Lepidoptera                             |          74768
#  National Register of Historic Places    |          73820
#  Russia                                  |          71234
#  Countries of the world                  |          68122
#  Spain                                   |          66673
#  China                                   |          64254
#  List of countries                       |          63260
#  Provinces of Iran                       |          62803
#  Counties of Iran                        |          62725
#  Bakhsh                                  |          62435
#  Rural Districts of Iran                 |          61784
#  World War I                             |          61567
#  Allmusic                                |          61429
#  Geographic Names Information System     |          60698
#  Iran Standard Time                      |          60377
#  Iran Daylight Time                      |          60240
#  Brazil                                  |          60077
#  English language                        |          59075
#  Voivodeships of Poland                  |          55589
#  Powiat                                  |          55543
#  Gmina                                   |          55333
#  Romanize                                |          55197
#  Paris                                   |          54376
#  Netherlands                             |          52444
#  Mexico                                  |          51812
#  Sweden                                  |          51615
#  New York (state)                        |          49752
#  Los Angeles                             |          49172
#  The Guardian                            |          48405
#  Soviet Union                            |          46304
#  Billboard (magazine)                    |          46137
#  United States Census Bureau             |          45772
#  Scotland                                |          44706
#  BBC                                     |          43681
#  Turkey                                  |          42540
#  Democratic Party (United States)        |          42301
#  Republican Party (United States)        |          41906
#  Switzerland                             |          41832
#  South Africa                            |          41790
#  Europe                                  |          41656
#  ZIP code                                |          41473
#  Norway                                  |          41410
#  American football                       |          41368
#  Texas                                   |          39979
#  Central European Time                   |          39955
#  Departments of France                   |          39924
#  Communes of France                      |          39750
#  New Zealand                             |          39410
#  Federal Information Processing Standard |          39277
#  Chicago                                 |          37613
#  Romania                                 |          37555
#  Ontario                                 |          37123
#  Washington, D.C.                        |          37029
#  New York Times                          |          36998
#  2010 United States Census               |          36792
#  Philippines                             |          36599
#  Central European Summer Time            |          36516
#  AllMusic                                |          36423
#  Austria                                 |          35839
#  United States Geological Survey         |          35795
#  Argentina                               |          35770
#  Midfielder                              |          35007
#  Pennsylvania                            |          34973
#  Marriage                                |          34069
#  Belgium                                 |          33860
#  Beetle                                  |          33231
#  Florida                                 |          32580
#  American Civil War                      |          32315
#  White (U.S. Census)                     |          32198
#  Angiosperms                             |          32127
#  South Korea                             |          32072
#  Toronto                                 |          32005
#  Member of Parliament                    |          31683
#  Los Angeles Times                       |          31518
#  Berlin                                  |          31467
#  Defender (association football)         |          31280
#  Rome                                    |          31212
#  Greece                                  |          30921
#  Denmark                                 |          30324
#  Pakistan                                |          30217
#  Israel                                  |          30111
#  States and territories of India         |          29465
#  Ireland                                 |          29345
#  Indian Standard Time                    |          29165
#  Hispanic (U.S. Census)                  |          29045
#  YouTube                                 |          28953
#  Latino (U.S. Census)                    |          28887
#  Illinois                                |          28857
#  Finland                                 |          28817
#  Indonesia                               |          28739
#  Sydney                                  |          28679
#  Pop music                               |          28668
#  Moscow                                  |          28651
#  Roman Catholic                          |          28133
#  Philadelphia                            |          27947
#  Ukraine                                 |          27360
#  Hungary                                 |          27360
#  Animalia                                |          27313
#  Rock music                              |          27213
#  Associated Press                        |          27186
#  Major League Baseball                   |          27078
#  Forward (association football)          |          26845
#  Ohio                                    |          26842
#  Race (United States Census)             |          26756
#  Polyphaga                               |          26664
#  Postal Index Number                     |          26574
#  National Football League                |          26363
#  New South Wales                         |          26251
#  Second World War                        |          26198
#  Portugal                                |          26163
#  United States Navy                      |          26081
#  Malaysia                                |          26033
#  Native American (U.S. Census)           |          25806
#  Thailand                                |          25741
#  Billboard Hot 100                       |          25713
#  Melbourne                               |          25669
#  List of districts of India              |          25272
#  Quebec                                  |          25266
#  Eastern Time Zone                       |          25042
#  French language                         |          24950
#  African American (U.S. Census)          |          24744
#  New Jersey                              |          24680
#  Virginia                                |          24507
#  Peru                                    |          24391
#  Harvard University                      |          24041
#  Asian (U.S. Census)                     |          24039
#  Egypt                                   |          23962
#  Vienna                                  |          23841
#  Czech Republic                          |          23829
#  North America                           |          23810
#  Hong Kong                               |          23765
#  Massachusetts                           |          23680
#  Colombia                                |          23672
#  San Francisco                           |          23672
#  British Columbia                        |          23650
#  Bachelor of Arts                        |          23646
#  United States Army                      |          23549
#  Montreal                                |          23414
#  Latin                                   |          23328
#  Cerambycidae                            |          23299
#  Eudicots                                |          23133
#  Mollusca                                |          23119
#  Boston                                  |          23033
#  Wales                                   |          22977
#  Plantae                                 |          22942
#  Singapore                               |          22866
#  Queensland                              |          22819
#  Spanish language                        |          22775
#  Music download                          |          22741
#  Royal Navy                              |          22607
#  Tokyo                                   |          22542
#  Sri Lanka                               |          22486
#  Endemism                                |          22401
#  Rolling Stone                           |          22352
#  Taiwan                                  |          22316
#  Eastern European Time                   |          22258
#  UK Singles Chart                        |          22184
#  German language                         |          21929
#  Michigan                                |          21699
#  Gastropoda                              |          21483
#  Serbia                                  |          21473
#  United States House of Representatives  |          21459
#  Unincorporated area                     |          21417
#  The Times                               |          21416
#  Bulgaria                                |          21264
#  Eastern European Summer Time            |          21216
#  Dublin                                  |          21161
#  Billboard 200                           |          21140
#  NBC                                     |          21072
#  The Independent                         |          20994
#  IUCN                                    |          20759
#  Chile                                   |          20569
#  Beijing                                 |          20537
#  The Daily Telegraph                     |          20361
#  Ottoman Empire                          |          20154
#  Republic of Ireland                     |          20065
#  The Washington Post                     |          20057

# %% [markdown]
# Most of the top outgoing pages are lists or indices,
# which aren't necessarily interesting.
# Let's try filtering those out and see what we get.
# Neo4j supports Java [regex](https://en.wikipedia.org/wiki/Regular_expression) (Neo4j is Scala, which is a JVM language),
# as well as `BEGINS WITH` and `ENDS WITH`, and other standard string operations.
#
# "`(?i)^(Alphabetical )?(List|Index|Timeline)? of.*`" will let us remove quite a few of these results.
# 1. `(?i)` is a control statement that makes our matches case insensitive.
#     * This lets us catch "Alphabetical list" as well as "List", and any capitalization errors.
# 1. `^` matches the start of a string.
#     * This allows titles with "list" or other keywords, so long as it's not at the start.
#     * This also prevents accidental matches to any article that contains " of", as most of this regex is optional
# 1. `Alphabetical ` matches titles starting with "Alphabetical "
#     *  `(Alphabetical )` turns the "Alphabetical " match into a single object
#     * `?` makes the object optional.
# 1. `(List|Index|Timeline)?` optionally matches `List`, `Index`, or `Timeline`.
#     * By putting the space inside the "Alphabetical " match, we match "List" and "Alphabetical List"
#
# This won't get rid of the "X in Y" pages, but certainly covers a lot for its size!
#
# **NOTE: This query slows down a lot, as we have to apply the regular expression tests to a lot of the strings in the database**

# %%
query="""
MATCH (n) WHERE NOT n.title =~ '(?i)^(Alphabetical )?(List|Index|Timeline)? of.*'
MATCH (n)-[r]->()
RETURN n.title, count(r) AS rel_count
ORDER BY rel_count DESC LIMIT 200
"""
data = graph.run(query)
print(data.to_table())
# Out:
#  n.title                                                                       | rel_count
# -------------------------------------------------------------------------------|-----------
#  Coverage of Google Street View                                                |      4826
#  IUCN Red List vulnerable species (Animalia)                                   |      4751
#  IUCN Red List data deficient species (Chordata)                               |      3494
#  2015 in film                                                                  |      3461
#  Google Street View in the United States                                       |      3426
#  2013 in film                                                                  |      3322
#  2018 in sports                                                                |      3259
#  2017 in film                                                                  |      3227
#  2014 in film                                                                  |      3113
#  2009 in film                                                                  |      3101
#  2017 in American television                                                   |      3052
#  IUCN Red List endangered species (Animalia)                                   |      2987
#  IUCN Red List near threatened species (Animalia)                              |      2898
#  2012 in film                                                                  |      2860
#  Records of members of parliament of the United Kingdom                        |      2843
#  Reading and Leeds Festivals line-ups                                          |      2770
#  Culture of the United Kingdom                                                 |      2745
#  1987 in film                                                                  |      2710
#  2006 in film                                                                  |      2683
#  2016 in film                                                                  |      2678
#  2016 in the United States                                                     |      2652
#  1998 in film                                                                  |      2643
#  2010 in film                                                                  |      2609
#  October 2011 in sports                                                        |      2565
#  2017 in sports                                                                |      2546
#  2004 in music                                                                 |      2536
#  2003 in music                                                                 |      2512
#  2017 in the United States                                                     |      2506
#  2001 in music                                                                 |      2444
#  Chronological summary of the 2016 Summer Olympics                             |      2434
#  2003 in film                                                                  |      2388
#  July 2011 in sports                                                           |      2384
#  Rosters of the top basketball teams in European club competitions             |      2339
#  1999 in film                                                                  |      2332
#  Google Street View in Europe                                                  |      2308
#  2018 in film                                                                  |      2288
#  2011 in film                                                                  |      2287
#  2002 in music                                                                 |      2240
#  IUCN Red List critically endangered species (Animalia)                        |      2234
#  1989 in film                                                                  |      2218
#  October 2010 in sports                                                        |      2210
#  1986 in film                                                                  |      2202
#  2015 in American television                                                   |      2195
#  2014 in home video                                                            |      2191
#  Endorsements in the United Kingdom European Union membership referendum, 2016 |      2181
#  Google Street View in South America                                           |      2162
#  2001 in film                                                                  |      2158
#  1995 in film                                                                  |      2140
#  Historical list of the Catholic bishops of the United States                  |      2134
#  1996 in film                                                                  |      2113
#  2018 in American television                                                   |      2101
#  2016 in American television                                                   |      2096
#  2000 in film                                                                  |      2091
#  Chicago Cubs all-time roster                                                  |      2086
#  St. Louis Cardinals all-time roster                                           |      2079
#  2002 in film                                                                  |      2075
#  Athletics at the 2016 Summer Olympics – Qualification                         |      2062
#  1999 in music                                                                 |      2037
#  March 2011 in sports                                                          |      2035
#  2013 in American television                                                   |      2031
#  1989                                                                          |      2029
#  2008 in film                                                                  |      2022
#  2005 in film                                                                  |      1998
#  2017 in association football                                                  |      1994
#  1994 in film                                                                  |      1976
#  2000 in music                                                                 |      1972
#  2007 in film                                                                  |      1957
#  September 2011 in sports                                                      |      1953
#  1988 in film                                                                  |      1953
#  1993 in film                                                                  |      1950
#  Athletics at the 2012 Summer Olympics – Qualification                         |      1945
#  Private Passions                                                              |      1939
#  1979                                                                          |      1921
#  2004 in film                                                                  |      1914
#  1997 in music                                                                 |      1903
#  Scottish Singles and Albums Charts                                            |      1898
#  Voivodeship road                                                              |      1897
#  Pittsburgh Pirates all-time roster                                            |      1896
#  August 2011 in sports                                                         |      1894
#  National Academy of Video Game Trade Reviewers                                |      1892
#  Cincinnati Reds all-time roster                                               |      1892
#  1997 in film                                                                  |      1891
#  Scientific phenomena named after people                                       |      1890
#  Table of stars with Flamsteed designations                                    |      1889
#  South East England                                                            |      1876
#  March 2010 in sports                                                          |      1873
#  Double (association football)                                                 |      1872
#  1945                                                                          |      1864
#  Oakland Athletics all-time roster                                             |      1861
#  1998 in music                                                                 |      1860
#  2012 in American television                                                   |      1858
#  2014 in American television                                                   |      1855
#  Table of stars with Bayer designations                                        |      1842
#  2016 in sports                                                                |      1833
#  Los Angeles Dodgers all-time roster                                           |      1826
#  Atlanta Braves all-time roster                                                |      1826
#  Cleveland Indians all-time roster                                             |      1812
#  Boston Red Sox all-time roster                                                |      1809
#  2016 in the United Kingdom                                                    |      1808
#  1992 in film                                                                  |      1805
#  2015 in the United Kingdom                                                    |      1797
#  1991                                                                          |      1789
#  Coachella Festival line-ups                                                   |      1789
#  1990                                                                          |      1787
#  1971 in music                                                                 |      1780
#  Academy Award for Best Adapted Screenplay                                     |      1774
#  1996 in music                                                                 |      1772
#  1973                                                                          |      1772
#  1988                                                                          |      1761
#  Glastonbury Festival line-ups                                                 |      1760
#  1995 in music                                                                 |      1760
#  1983                                                                          |      1760
#  2014 in the United Kingdom                                                    |      1758
#  San Francisco Giants all-time roster                                          |      1756
#  2010s                                                                         |      1750
#  2016 in association football                                                  |      1748
#  Results of the United Kingdom European Union membership referendum, 2016      |      1748
#  Italian exonyms                                                               |      1745
#  Baltimore Orioles all-time roster                                             |      1737
#  1980                                                                          |      1735
#  Chicago White Sox all-time roster                                             |      1731
#  1994 in music                                                                 |      1731
#  1977                                                                          |      1730
#  1991 in film                                                                  |      1730
#  Outline of the United Nations                                                 |      1729
#  1967                                                                          |      1722
#  1944                                                                          |      1718
#  1970                                                                          |      1718
#  1972                                                                          |      1715
#  1966                                                                          |      1714
#  Van Gelder Studio                                                             |      1702
#  1981                                                                          |      1702
#  1981 in music                                                                 |      1701
#  1990 in music                                                                 |      1699
#  1964                                                                          |      1697
#  New York Yankees all-time roster                                              |      1686
#  Burial sites of European monarchs and consorts                                |      1678
#  Detroit Tigers all-time roster                                                |      1677
#  November 2010 in sports                                                       |      1668
#  1986                                                                          |      1667
#  1990 in film                                                                  |      1664
#  Minnesota Twins all-time roster                                               |      1662
#  1984                                                                          |      1655
#  2015 in British television                                                    |      1652
#  2015 in sports                                                                |      1650
#  2014 in sports                                                                |      1648
#  1987                                                                          |      1644
#  1976                                                                          |      1639
#  1985                                                                          |      1636
#  2011 in the United States                                                     |      1635
#  1991 in music                                                                 |      1619
#  1977 in music                                                                 |      1616
#  Thomas (surname)                                                              |      1613
#  Aircraft in fiction                                                           |      1613
#  1001 Movies You Must See Before You Die                                       |      1611
#  1980 in music                                                                 |      1611
#  2017 in the United Kingdom                                                    |      1609
#  1942                                                                          |      1608
#  1965                                                                          |      1608
#  2015 in association football                                                  |      1605
#  North West England                                                            |      1604
#  1982                                                                          |      1601
#  Asimov's Biographical Encyclopedia of Science and Technology                  |      1600
#  Ted Jensen discography                                                        |      1599
#  Classification of indigenous peoples of the Americas                          |      1599
#  1993 in music                                                                 |      1599
#  1971                                                                          |      1596
#  1946                                                                          |      1594
#  2015 in the United States                                                     |      1593
#  May 2010 in sports                                                            |      1591
#  1969                                                                          |      1590
#  November 2009 in sports                                                       |      1583
#  2000s (decade)                                                                |      1580
#  California locations by race                                                  |      1580
#  1943                                                                          |      1579
#  1963                                                                          |      1578
#  1982 in music                                                                 |      1576
#  1992                                                                          |      1569
#  1975                                                                          |      1567
#  1970 in music                                                                 |      1566
#  1993                                                                          |      1560
#  July 2010 in sports                                                           |      1556
#  1967 in music                                                                 |      1555
#  Roush Fenway Racing                                                           |      1552
#  Hendrick Motorsports                                                          |      1547
#  Pukkelpop                                                                     |      1545
#  1972 in music                                                                 |      1544
#  1962                                                                          |      1543
#  United States congressional delegations from New York                         |      1543
#  September 2010 in sports                                                      |      1542
#  1948                                                                          |      1532
#  1978 in music                                                                 |      1530
#  1984 in music                                                                 |      1528
#  1978                                                                          |      1525
#  1974                                                                          |      1521
#  Dubbing (filmmaking)                                                          |      1508
#  1983 in music                                                                 |      1506
#  Outline of human anatomy                                                      |      1505
#  1976 in music                                                                 |      1500
#  1941                                                                          |      1493

# %%
query="""
MATCH (n)-[r]->()
RETURN n.title, count(r) AS rel_count
ORDER BY rel_count DESC LIMIT 200
"""
data = graph.run(query)
print(data.to_table())
# Out:
#  n.title                                                                        | rel_count
# --------------------------------------------------------------------------------|-----------
#  List of current U.S. state legislators                                         |      8069
#  List of least concern birds                                                    |      8029
#  List of people from Illinois                                                   |      7773
#  List of birds of the world                                                     |      6917
#  List of stage names                                                            |      6530
#  List of cities, towns and villages in Kerman Province                          |      5839
#  List of film director and actor collaborations                                 |      5780
#  Index of Telangana-related articles                                            |      5743
#  Index of Andhra Pradesh-related articles                                       |      5679
#  List of municipalities of Brazil                                               |      5584
#  List of years in jazz                                                          |      5522
#  Alphabetical list of comunes of Italy                                          |      5475
#  List of least concern fishes                                                   |      5352
#  Index of India-related articles                                                |      5300
#  Index of philosophy articles (I–Q)                                             |      5107
#  Index of Italy-related articles                                                |      5066
#  List of United States television markets                                       |      5030
#  List of people from Texas                                                      |      4974
#  List of dialling codes in Germany                                              |      4938
#  Coverage of Google Street View                                                 |      4826
#  List of biographical films                                                     |      4825
#  IUCN Red List vulnerable species (Animalia)                                    |      4751
#  Timeline of heavy metal and hard rock music                                    |      4738
#  List of populated places in Serbia                                             |      4711
#  List of places named after people                                              |      4686
#  List of performances on Top of the Pops                                        |      4658
#  List of populated places in Serbia (alphabetic)                                |      4652
#  List of composers by name                                                      |      4627
#  List of birds by common name                                                   |      4616
#  List of film director and composer collaborations                              |      4610
#  List of American television programs by debut date                             |      4447
#  List of vulnerable plants                                                      |      4374
#  List of United States counties and county equivalents                          |      4311
#  List of cities, towns and villages in Fars Province                            |      4224
#  List of cities, towns and villages in Khuzestan Province                       |      4164
#  List of populated places in Bosnia and Herzegovina                             |      4083
#  Index of Byzantine Empire-related articles                                     |      3929
#  List of reality television show franchises                                     |      3854
#  List of film director and cinematographer collaborations                       |      3850
#  List of Paramount Pictures films                                               |      3833
#  List of film score composers                                                   |      3823
#  List of village development committees of Nepal                                |      3759
#  List of directorial debuts                                                     |      3757
#  List of Catholic dioceses (structured view)                                    |      3742
#  List of Hillary Clinton presidential campaign non-political endorsements, 2016 |      3693
#  List of cities, towns and villages in Razavi Khorasan Province                 |      3588
#  List of birds of South America                                                 |      3563
#  List of state leaders in the 20th century (1951–2000)                          |      3547
#  Index of U.S. counties                                                         |      3521
#  List of indoor arenas                                                          |      3505
#  Index of World War II articles (U)                                             |      3504
#  IUCN Red List data deficient species (Chordata)                                |      3494
#  List of 2017 albums                                                            |      3475
#  2015 in film                                                                   |      3461
#  List of Turkish exonyms                                                        |      3439
#  List of Cornell University alumni                                              |      3437
#  Google Street View in the United States                                        |      3426
#  List of college towns                                                          |      3421
#  Index of Sri Lanka-related articles (S)                                        |      3386
#  List of least concern plants                                                   |      3376
#  List of Lepidoptera of Romania                                                 |      3371
#  List of children's television series by country                                |      3351
#  2013 in film                                                                   |      3322
#  List of Lepidoptera of Germany                                                 |      3301
#  Index of law articles                                                          |      3294
#  List of Gothic brick buildings                                                 |      3289
#  Index of philosophy articles (R–Z)                                             |      3289
#  List of districts in Russia                                                    |      3288
#  List of aircraft by date and usage category                                    |      3285
#  List of counties by U.S. state                                                 |      3276
#  2018 in sports                                                                 |      3259
#  Timeline of London                                                             |      3256
#  List of Lepidoptera of Slovakia                                                |      3248
#  List of local administrative units of Romania                                  |      3236
#  2017 in film                                                                   |      3227
#  List of birds of Asia                                                          |      3226
#  List of Lepidoptera of Switzerland                                             |      3216
#  List of least concern mammals                                                  |      3214
#  List of postal codes in Germany                                                |      3201
#  List of United States counties by per capita income                            |      3195
#  List of University of Pennsylvania people                                      |      3189
#  List of entries in the Eurovision Song Contest                                 |      3167
#  List of Lepidoptera of Hungary                                                 |      3162
#  List of college sports team nicknames                                          |      3127
#  List of Lepidoptera of the Czech Republic                                      |      3121
#  List of cities, towns and villages in Mazandaran Province                      |      3115
#  2014 in film                                                                   |      3113
#  List of women writers                                                          |      3112
#  List of Christian Brothers school alumni                                       |      3106
#  List of Catholic dioceses (alphabetical)                                       |      3101
#  2009 in film                                                                   |      3101
#  Index of Singapore-related articles                                            |      3082
#  List of Hillary Clinton presidential campaign political endorsements, 2016     |      3080
#  List of people with surname Williams                                           |      3080
#  List of special routes of the United States Numbered Highway System            |      3071
#  2017 in American television                                                    |      3052
#  List of sports films                                                           |      3050
#  List of rodents                                                                |      3047
#  Timeline of United States history                                              |      3037
#  List of years                                                                  |      3037
#  List of 2016 albums                                                            |      3022
#  List of deaths in rock and roll                                                |      3017
#  Index of philosophy articles (D–H)                                             |      3003
#  IUCN Red List endangered species (Animalia)                                    |      2987
#  Timeline of historical geopolitical changes                                    |      2974
#  List of country houses in the United Kingdom                                   |      2973
#  List of places named after people in the United States                         |      2954
#  List of association football stadiums by country                               |      2943
#  List of 21st-century classical composers                                       |      2941
#  List of cities, towns and villages in West Azerbaijan Province                 |      2936
#  List of Lepidoptera of Poland                                                  |      2936
#  List of association football families                                          |      2934
#  List of Pennsylvania locations by per capita income                            |      2932
#  List of Test cricketers                                                        |      2919
#  List of Columbia College people                                                |      2917
#  Index of philosophy articles (A–C)                                             |      2916
#  List of operas by composer                                                     |      2911
#  List of counties in the People's Republic of China                             |      2899
#  IUCN Red List near threatened species (Animalia)                               |      2898
#  List of guitarists                                                             |      2893
#  Index of ancient Egypt-related articles                                        |      2890
#  List of auxiliaries of the United States Navy                                  |      2886
#  List of coupled cousins                                                        |      2866
#  2012 in film                                                                   |      2860
#  List of cities, towns and villages in Lorestan Province                        |      2855
#  Records of members of parliament of the United Kingdom                         |      2843
#  List of musical supergroups                                                    |      2838
#  List of Warner Bros. films                                                     |      2834
#  List of Lepidoptera of Greece                                                  |      2808
#  List of Russian people                                                         |      2804
#  Index of Chile-related articles                                                |      2795
#  List of cities, towns and villages in East Azerbaijan Province                 |      2775
#  List of Harvard University people                                              |      2774
#  List of communities in Ontario                                                 |      2773
#  Reading and Leeds Festivals line-ups                                           |      2770
#  List of courthouses in the United States                                       |      2766
#  List of war films and TV specials                                              |      2751
#  List of one-word stage names                                                   |      2750
#  List of statistics articles                                                    |      2749
#  Timeline of musical events                                                     |      2746
#  Culture of the United Kingdom                                                  |      2745
#  List of cities, towns and villages in Gilan Province                           |      2739
#  List of Universal Pictures films                                               |      2726
#  1987 in film                                                                   |      2710
#  List of municipalities and towns in Slovakia                                   |      2709
#  2006 in film                                                                   |      2683
#  2016 in film                                                                   |      2678
#  List of political families                                                     |      2675
#  List of show business families                                                 |      2661
#  List of moths of North America (MONA 8322-11233)                               |      2655
#  2016 in the United States                                                      |      2652
#  1998 in film                                                                   |      2643
#  Index of fashion articles                                                      |      2634
#  List of cities, towns and villages in Kermanshah Province                      |      2618
#  2010 in film                                                                   |      2609
#  List of Lepidoptera of Bulgaria                                                |      2606
#  Index of Fiji-related articles                                                 |      2580
#  List of 2014 albums                                                            |      2579
#  October 2011 in sports                                                         |      2565
#  List of music venues                                                           |      2557
#  List of municipalities of Switzerland                                          |      2552
#  List of endangered plants                                                      |      2551
#  List of Malaysia-related topics                                                |      2550
#  List of 2006 albums                                                            |      2549
#  List of minor planets named after people                                       |      2547
#  2017 in sports                                                                 |      2546
#  List of Lepidoptera of Ukraine                                                 |      2536
#  2004 in music                                                                  |      2536
#  List of postal codes in China                                                  |      2536
#  List of birds of Africa                                                        |      2526
#  Index of Sri Lanka-related articles (M)                                        |      2524
#  2003 in music                                                                  |      2512
#  List of 2015 albums                                                            |      2510
#  List of international airports by country                                      |      2506
#  2017 in the United States                                                      |      2506
#  List of OMIM disorder codes                                                    |      2496
#  List of songs about New York City                                              |      2490
#  List of moths of Sweden                                                        |      2478
#  List of aircraft engines                                                       |      2477
#  List of American novelists                                                     |      2472
#  List of Columbia Pictures films                                                |      2471
#  List of cutaneous conditions                                                   |      2460
#  List of male golfers                                                           |      2458
#  2001 in music                                                                  |      2444
#  List of One Day International cricketers                                       |      2442
#  List of assassinations in fiction                                              |      2441
#  Chronological summary of the 2016 Summer Olympics                              |      2434
#  List of Pro Bowl players                                                       |      2433
#  Index of Bangladesh-related articles                                           |      2432
#  List of lead vocalists                                                         |      2422
#  List of United States Congress members who died in office (1900–49)            |      2419
#  List of Metro-Goldwyn-Mayer films                                              |      2413
#  List of bass guitarists                                                        |      2403
#  List of Lepidoptera of Denmark                                                 |      2403
#  List of concert halls                                                          |      2402
#  List of films based on actual events                                           |      2400
#  List of singer-songwriters                                                     |      2392
#  2003 in film                                                                   |      2388
#  List of comedy films of the 2000s                                              |      2384
#  July 2011 in sports                                                            |      2384

# %% [markdown]
# It looks like there's a lot of "X in Y" articles after all.
# Sports rosters and festival line-ups, too.
# Some interesting results have made it through though.

# %% [markdown]
# # Save your Notebook, then `File > Close and Halt`

# %% [markdown]
# ---
