# %% [markdown]
# # Graph Visualization
#
# To visualize our graphs, we've prepared a completely rewritten version of [neo4jupyter](https://github.com/merqurio/neo4jupyter), which you can dive into [here](../graph_plot.py) if you wish.
#
# In short, we've created two drawing functions that will configure and embed small HTML pages using [viz.js](http://visjs.org) to visualize nodes and edges.
#
# Let's start by importing our script and run through some examples.
# **Again, we are connecting to our Wikipedia database**

# %%
from py2neo import Graph

#################################################
# Update UPDATE-ME in the connection code with 
# The server you were assigned (see the schedule 
# notebook) to connect to using the 
# Links below.
#################################################
# Server 0 - neo4j.dsa.missouri.edu
# Server 1 - neo4j-1.dsa.missouri.edu
# Server 2 - neo4j-2.dsa.missouri.edu
# Server 3 - neo4j-3.dsa.missouri.edu
#################################################

graph = Graph("bolt://wikiread:wikireader@neo4j-1.dsa.missouri.edu:9000")

# %%
import sys
# Tell Python a new place it can look to import libraries
sys.path.append("..")
# The file path is ../graph_plot.py
from graph_plot import draw_r, draw_nr, small_options, large_options

# %%
# Let's dive right in and grab some data!
query="""
MATCH (a:Page {title: 'Neo4j'})-[r]->(b)
RETURN r
"""
data = graph.run(query).to_table()

# %% [markdown]
# The `draw_r` function iterates through the given relationships and draws them.
# It turns out that relationship objects contain both the start and end nodes, so nothing else is needed!
#
# The second argument maps node labels to node titles.
# This lets us select which property is printed as the node's name.
# Here, we indicate that `Page` nodes should have their `title` property used as their label in the graph.
#
# As it is, this will produce a simple graph with some physics enabled.
# When you click on a node, the associated links will be highlighted.
# Links also have _mouseover_ text indicating the pages they connect as well as their direction.

# %%
draw_r(data, {"Page": "title"})
# Out:
# <div id="ff8e9eff-0a62-4b6d-9f8e-932e78051346" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "Cypher Query Language", "group": "Page", "id": 10420416, "value": 0, "label": "Cypher Query Language"}, {"title": "ArangoDB", "group": "Page", "id": 11657601, "value": 0, "label": "ArangoDB"}, {"title": "Neo Technology", "group": "Page", "id": 6911747, "value": 0, "label": "Neo Technology"}, {"title": "North America", "group": "Page", "id": 13622, "value": 0, "label": "North America"}, {"title": "Graph database", "group": "Page", "id": 6596737, "value": 0, "label": "Graph database"}, {"title": "Intentional Software", "group": "Page", "id": 3876236, "value": 0, "label": "Intentional Software"}, {"title": "GPLv3", "group": "Page", "id": 1917072, "value": 0, "label": "GPLv3"}, {"title": "DB-Engines ranking", "group": "Page", "id": 13555986, "value": 0, "label": "DB-Engines ranking"}, {"title": "San Francisco Bay Area", "group": "Page", "id": 5292782, "value": 0, "label": "San Francisco Bay Area"}, {"title": "United States", "group": "Page", "id": 1496086, "value": 0, "label": "United States"}, {"title": "Nikolaj Nyholm", "group": "Page", "id": 7546967, "value": 0, "label": "Nikolaj Nyholm"}, {"title": "Europe", "group": "Page", "id": 5656, "value": 0, "label": "Europe"}, {"title": "Malm\u00f6", "group": "Page", "id": 12188, "value": 0, "label": "Malm\u00f6"}, {"title": "Java (programming language)", "group": "Page", "id": 10053, "value": 0, "label": "Java (programming language)"}, {"title": "CODASYL", "group": "Page", "id": 198304, "value": 0, "label": "CODASYL"}, {"title": "OrientDB", "group": "Page", "id": 8241569, "value": 0, "label": "OrientDB"}, {"title": "AllegroGraph", "group": "Page", "id": 7021627, "value": 0, "label": "AllegroGraph"}, {"title": "Spring Framework", "group": "Page", "id": 2056612, "value": 0, "label": "Spring Framework"}, {"title": "ACID", "group": "Page", "id": 40550, "value": 0, "label": "ACID"}, {"title": "Affero General Public License", "group": "Page", "id": 2438694, "value": 0, "label": "Affero General Public License"}, {"title": "Neo4j", "group": "Page", "id": 6745383, "value": 26, "label": "Neo4j"}, {"title": "Sweden", "group": "Page", "id": 1970728, "value": 0, "label": "Sweden"}, {"title": "Remote backup service", "group": "Page", "id": 881262, "value": 0, "label": "Remote backup service"}, {"title": "GNU General Public License", "group": "Page", "id": 5211633, "value": 0, "label": "GNU General Public License"}, {"title": "Gremlin (programming language)", "group": "Page", "id": 8648946, "value": 0, "label": "Gremlin (programming language)"}, {"title": "AGPLv3", "group": "Page", "id": 6919349, "value": 0, "label": "AGPLv3"}, {"title": "Apache Giraph", "group": "Page", "id": 9539638, "value": 0, "label": "Apache Giraph"}, {"title": "Freemium", "group": "Page", "id": 2611238, "value": 0, "label": "Freemium"}];
# var edges = [{"from": 6745383, "to": 10420416, "title": "Neo4j -[Link]-> Cypher Query Language"}, {"from": 6745383, "to": 40550, "title": "Neo4j -[Link]-> ACID"}, {"from": 6745383, "to": 6919349, "title": "Neo4j -[Link]-> AGPLv3"}, {"from": 6745383, "to": 5656, "title": "Neo4j -[Link]-> Europe"}, {"from": 6745383, "to": 6596737, "title": "Neo4j -[Link]-> Graph database"}, {"from": 6745383, "to": 2438694, "title": "Neo4j -[Link]-> Affero General Public License"}, {"from": 6745383, "to": 5211633, "title": "Neo4j -[Link]-> GNU General Public License"}, {"from": 6745383, "to": 3876236, "title": "Neo4j -[Link]-> Intentional Software"}, {"from": 6745383, "to": 198304, "title": "Neo4j -[Link]-> CODASYL"}, {"from": 6745383, "to": 2611238, "title": "Neo4j -[Link]-> Freemium"}, {"from": 6745383, "to": 7021627, "title": "Neo4j -[Link]-> AllegroGraph"}, {"from": 6745383, "to": 2056612, "title": "Neo4j -[Link]-> Spring Framework"}, {"from": 6745383, "to": 13555986, "title": "Neo4j -[Link]-> DB-Engines ranking"}, {"from": 6745383, "to": 9539638, "title": "Neo4j -[Link]-> Apache Giraph"}, {"from": 6745383, "to": 7546967, "title": "Neo4j -[Link]-> Nikolaj Nyholm"}, {"from": 6745383, "to": 1496086, "title": "Neo4j -[Link]-> United States"}, {"from": 6745383, "to": 881262, "title": "Neo4j -[Link]-> Remote backup service"}, {"from": 6745383, "to": 8648946, "title": "Neo4j -[Link]-> Gremlin (programming language)"}, {"from": 6745383, "to": 12188, "title": "Neo4j -[Link]-> Malm\u00f6"}, {"from": 6745383, "to": 13622, "title": "Neo4j -[Link]-> North America"}, {"from": 6745383, "to": 1917072, "title": "Neo4j -[Link]-> GPLv3"}, {"from": 6745383, "to": 6911747, "title": "Neo4j -[Link]-> Neo Technology"}, {"from": 6745383, "to": 8241569, "title": "Neo4j -[Link]-> OrientDB"}, {"from": 6745383, "to": 1970728, "title": "Neo4j -[Link]-> Sweden"}, {"from": 6745383, "to": 10053, "title": "Neo4j -[Link]-> Java (programming language)"}, {"from": 6745383, "to": 11657601, "title": "Neo4j -[Link]-> ArangoDB"}, {"from": 6745383, "to": 5292782, "title": "Neo4j -[Link]-> San Francisco Bay Area"}];
#
# var container = document.getElementById("ff8e9eff-0a62-4b6d-9f8e-932e78051346");
#
# var data = {
#     nodes: nodes,
#     edges: edges
# };
#
# var options = {"physics": {"enabled": true, "solver": "repulsion"}, "edges": {"arrows": {"to": {"enabled": true, "scaleFactor": 0.5}}, "color": {"color": "grey", "highlight": "#404040"}, "smooth": {"enabled": true, "type": "dynamic"}, "font": {"size": 14, "align": "middle"}}, "nodes": {"font": {"size": "14"}, "size": 25, "shape": "ellipse"}};
#
# var network = new vis.Network(container, data, options);
#
# </script>

# %% [markdown]
# Physics is controlled by the third argument and defaults to enabled.
# If you've got more than 200 nodes, you'll start to experience some slowdown in your browser.
# **In larger graphs, you can lock up your browser tab.**
# Make sure you have a good idea of what you're plotting before you plot it!
#
# Below is an example with Physics disabled/

# %%
draw_r(data, {'Page': 'title'}, False)
# Out:
# <div id="4ff21d23-0feb-4d5f-a07c-1f32fb084d2f" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "Cypher Query Language", "group": "Page", "id": 10420416, "value": 0, "label": "Cypher Query Language"}, {"title": "ArangoDB", "group": "Page", "id": 11657601, "value": 0, "label": "ArangoDB"}, {"title": "Neo Technology", "group": "Page", "id": 6911747, "value": 0, "label": "Neo Technology"}, {"title": "North America", "group": "Page", "id": 13622, "value": 0, "label": "North America"}, {"title": "Graph database", "group": "Page", "id": 6596737, "value": 0, "label": "Graph database"}, {"title": "Intentional Software", "group": "Page", "id": 3876236, "value": 0, "label": "Intentional Software"}, {"title": "GPLv3", "group": "Page", "id": 1917072, "value": 0, "label": "GPLv3"}, {"title": "DB-Engines ranking", "group": "Page", "id": 13555986, "value": 0, "label": "DB-Engines ranking"}, {"title": "San Francisco Bay Area", "group": "Page", "id": 5292782, "value": 0, "label": "San Francisco Bay Area"}, {"title": "United States", "group": "Page", "id": 1496086, "value": 0, "label": "United States"}, {"title": "Nikolaj Nyholm", "group": "Page", "id": 7546967, "value": 0, "label": "Nikolaj Nyholm"}, {"title": "Europe", "group": "Page", "id": 5656, "value": 0, "label": "Europe"}, {"title": "Malm\u00f6", "group": "Page", "id": 12188, "value": 0, "label": "Malm\u00f6"}, {"title": "Java (programming language)", "group": "Page", "id": 10053, "value": 0, "label": "Java (programming language)"}, {"title": "CODASYL", "group": "Page", "id": 198304, "value": 0, "label": "CODASYL"}, {"title": "OrientDB", "group": "Page", "id": 8241569, "value": 0, "label": "OrientDB"}, {"title": "AllegroGraph", "group": "Page", "id": 7021627, "value": 0, "label": "AllegroGraph"}, {"title": "Spring Framework", "group": "Page", "id": 2056612, "value": 0, "label": "Spring Framework"}, {"title": "ACID", "group": "Page", "id": 40550, "value": 0, "label": "ACID"}, {"title": "Affero General Public License", "group": "Page", "id": 2438694, "value": 0, "label": "Affero General Public License"}, {"title": "Neo4j", "group": "Page", "id": 6745383, "value": 26, "label": "Neo4j"}, {"title": "Sweden", "group": "Page", "id": 1970728, "value": 0, "label": "Sweden"}, {"title": "Remote backup service", "group": "Page", "id": 881262, "value": 0, "label": "Remote backup service"}, {"title": "GNU General Public License", "group": "Page", "id": 5211633, "value": 0, "label": "GNU General Public License"}, {"title": "Gremlin (programming language)", "group": "Page", "id": 8648946, "value": 0, "label": "Gremlin (programming language)"}, {"title": "AGPLv3", "group": "Page", "id": 6919349, "value": 0, "label": "AGPLv3"}, {"title": "Apache Giraph", "group": "Page", "id": 9539638, "value": 0, "label": "Apache Giraph"}, {"title": "Freemium", "group": "Page", "id": 2611238, "value": 0, "label": "Freemium"}];
# var edges = [{"from": 6745383, "to": 10420416, "title": "Neo4j -[Link]-> Cypher Query Language"}, {"from": 6745383, "to": 40550, "title": "Neo4j -[Link]-> ACID"}, {"from": 6745383, "to": 6919349, "title": "Neo4j -[Link]-> AGPLv3"}, {"from": 6745383, "to": 5656, "title": "Neo4j -[Link]-> Europe"}, {"from": 6745383, "to": 6596737, "title": "Neo4j -[Link]-> Graph database"}, {"from": 6745383, "to": 2438694, "title": "Neo4j -[Link]-> Affero General Public License"}, {"from": 6745383, "to": 5211633, "title": "Neo4j -[Link]-> GNU General Public License"}, {"from": 6745383, "to": 3876236, "title": "Neo4j -[Link]-> Intentional Software"}, {"from": 6745383, "to": 198304, "title": "Neo4j -[Link]-> CODASYL"}, {"from": 6745383, "to": 2611238, "title": "Neo4j -[Link]-> Freemium"}, {"from": 6745383, "to": 7021627, "title": "Neo4j -[Link]-> AllegroGraph"}, {"from": 6745383, "to": 2056612, "title": "Neo4j -[Link]-> Spring Framework"}, {"from": 6745383, "to": 13555986, "title": "Neo4j -[Link]-> DB-Engines ranking"}, {"from": 6745383, "to": 9539638, "title": "Neo4j -[Link]-> Apache Giraph"}, {"from": 6745383, "to": 7546967, "title": "Neo4j -[Link]-> Nikolaj Nyholm"}, {"from": 6745383, "to": 1496086, "title": "Neo4j -[Link]-> United States"}, {"from": 6745383, "to": 881262, "title": "Neo4j -[Link]-> Remote backup service"}, {"from": 6745383, "to": 8648946, "title": "Neo4j -[Link]-> Gremlin (programming language)"}, {"from": 6745383, "to": 12188, "title": "Neo4j -[Link]-> Malm\u00f6"}, {"from": 6745383, "to": 13622, "title": "Neo4j -[Link]-> North America"}, {"from": 6745383, "to": 1917072, "title": "Neo4j -[Link]-> GPLv3"}, {"from": 6745383, "to": 6911747, "title": "Neo4j -[Link]-> Neo Technology"}, {"from": 6745383, "to": 8241569, "title": "Neo4j -[Link]-> OrientDB"}, {"from": 6745383, "to": 1970728, "title": "Neo4j -[Link]-> Sweden"}, {"from": 6745383, "to": 10053, "title": "Neo4j -[Link]-> Java (programming language)"}, {"from": 6745383, "to": 11657601, "title": "Neo4j -[Link]-> ArangoDB"}, {"from": 6745383, "to": 5292782, "title": "Neo4j -[Link]-> San Francisco Bay Area"}];
#
# var container = document.getElementById("4ff21d23-0feb-4d5f-a07c-1f32fb084d2f");
#
# var data = {
#     nodes: nodes,
#     edges: edges
# };
#
# var options = {"physics": {"enabled": false, "solver": "repulsion"}, "edges": {"arrows": {"to": {"enabled": true, "scaleFactor": 0.5}}, "color": {"color": "grey", "highlight": "#404040"}, "smooth": {"enabled": true, "type": "dynamic"}, "font": {"size": 14, "align": "middle"}}, "nodes": {"font": {"size": "14"}, "size": 25, "shape": "ellipse"}};
#
# var network = new vis.Network(container, data, options);
#
# </script>

# %% [markdown]
# ### <span style="background:yellow">Your Turn</span>
#
# Lookup some pages and plot graphs of their connections.
# Replace the `?????` with your desired page title.

# %%
# M4:P3:Q1

# Lookup and plot two pages and the nodes they link to
# -----------------
query="""
MATCH (a:Page {title: 'ACID' })-[r]->(b)
RETURN r
"""
data = graph.run(query).to_table()

# A length check should help prevent slowdowns
if not data:
    print("Page not found!")

draw_r(data, {'Page':'title'}, len(data) <= 150)
# Out:
# <div id="4047cfa0-84b3-4f9b-8387-7c0723ecddbf" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "CRUD", "group": "Page", "id": 7970625, "value": 0, "label": "CRUD"}, {"title": "Transactional NTFS", "group": "Page", "id": 1682763, "value": 0, "label": "Transactional NTFS"}, {"title": "Theo H\u00e4rder", "group": "Page", "id": 12455624, "value": 0, "label": "Theo H\u00e4rder"}, {"title": "Isolation (database systems)", "group": "Page", "id": 207371, "value": 0, "label": "Isolation (database systems)"}, {"title": "Jim Gray (computer scientist)", "group": "Page", "id": 197708, "value": 0, "label": "Jim Gray (computer scientist)"}, {"title": "Concurrency control", "group": "Page", "id": 149774, "value": 0, "label": "Concurrency control"}, {"title": "Morgan Kaufmann", "group": "Page", "id": 4015018, "value": 0, "label": "Morgan Kaufmann"}, {"title": "Cascading rollback", "group": "Page", "id": 2103442, "value": 0, "label": "Cascading rollback"}, {"title": "Lock (computer science)", "group": "Page", "id": 164803, "value": 0, "label": "Lock (computer science)"}, {"title": "Open Systems Interconnection", "group": "Page", "id": 26454, "value": 0, "label": "Open Systems Interconnection"}, {"title": "Two-phase commit protocol", "group": "Page", "id": 455332, "value": 0, "label": "Two-phase commit protocol"}, {"title": "Java Transaction API", "group": "Page", "id": 28444, "value": 0, "label": "Java Transaction API"}, {"title": "Andreas Reuter", "group": "Page", "id": 11963363, "value": 0, "label": "Andreas Reuter"}, {"title": "Durability (database systems)", "group": "Page", "id": 165476, "value": 0, "label": "Durability (database systems)"}, {"title": "ACID", "group": "Page", "id": 40550, "value": 25, "label": "ACID"}, {"title": "CAP theorem", "group": "Page", "id": 6947868, "value": 0, "label": "CAP theorem"}, {"title": "Crash (computing)", "group": "Page", "id": 183146, "value": 0, "label": "Crash (computing)"}, {"title": "Atomicity (database systems)", "group": "Page", "id": 235052, "value": 0, "label": "Atomicity (database systems)"}, {"title": "SQL", "group": "Page", "id": 18864, "value": 0, "label": "SQL"}, {"title": "IBM Information Management System", "group": "Page", "id": 244082, "value": 0, "label": "IBM Information Management System"}, {"title": "Two phase locking", "group": "Page", "id": 5955123, "value": 0, "label": "Two phase locking"}, {"title": "Consistency (database systems)", "group": "Page", "id": 630516, "value": 0, "label": "Consistency (database systems)"}, {"title": "Durability (computer science)", "group": "Page", "id": 3705014, "value": 0, "label": "Durability (computer science)"}, {"title": "Integrity constraints", "group": "Page", "id": 3174071, "value": 0, "label": "Integrity constraints"}, {"title": "Tandem Computers", "group": "Page", "id": 140412, "value": 0, "label": "Tandem Computers"}, {"title": "Database trigger", "group": "Page", "id": 732221, "value": 0, "label": "Database trigger"}, {"title": "Eventual consistency", "group": "Page", "id": 881726, "value": 0, "label": "Eventual consistency"}];
# var edges = [{"from": 40550, "to": 207371, "title": "ACID -[Link]-> Isolation (database systems)"}, {"from": 40550, "to": 164803, "title": "ACID -[Link]-> Lock (computer science)"}, {"from": 40550, "to": 1682763, "title": "ACID -[Link]-> Transactional NTFS"}, {"from": 40550, "to": 732221, "title": "ACID -[Link]-> Database trigger"}, {"from": 40550, "to": 3174071, "title": "ACID -[Link]-> Integrity constraints"}, {"from": 40550, "to": 6947868, "title": "ACID -[Link]-> CAP theorem"}, {"from": 40550, "to": 235052, "title": "ACID -[Link]-> Atomicity (database systems)"}, {"from": 40550, "to": 140412, "title": "ACID -[Link]-> Tandem Computers"}, {"from": 40550, "to": 5955123, "title": "ACID -[Link]-> Two phase locking"}, {"from": 40550, "to": 165476, "title": "ACID -[Link]-> Durability (database systems)"}, {"from": 40550, "to": 7970625, "title": "ACID -[Link]-> CRUD"}, {"from": 40550, "to": 244082, "title": "ACID -[Link]-> IBM Information Management System"}, {"from": 40550, "to": 149774, "title": "ACID -[Link]-> Concurrency control"}, {"from": 40550, "to": 455332, "title": "ACID -[Link]-> Two-phase commit protocol"}, {"from": 40550, "to": 18864, "title": "ACID -[Link]-> SQL"}, {"from": 40550, "to": 881726, "title": "ACID -[Link]-> Eventual consistency"}, {"from": 40550, "to": 630516, "title": "ACID -[Link]-> Consistency (database systems)"}, {"from": 40550, "to": 12455624, "title": "ACID -[Link]-> Theo H\u00e4rder"}, {"from": 40550, "to": 2103442, "title": "ACID -[Link]-> Cascading rollback"}, {"from": 40550, "to": 3705014, "title": "ACID -[Link]-> Durability (computer science)"}, {"from": 40550, "to": 4015018, "title": "ACID -[Link]-> Morgan Kaufmann"}, {"from": 40550, "to": 197708, "title": "ACID -[Link]-> Jim Gray (computer scientist)"}, {"from": 40550, "to": 11963363, "title": "ACID -[Link]-> Andreas Reuter"}, {"from": 40550, "to": 183146, "title": "ACID -[Link]-> Crash (computing)"}, {"from": 40550, "to": 26454, "title": "ACID -[Link]-> Open Systems Interconnection"}, {"from": 40550, "to": 28444, "title": "ACID -[Link]-> Java Transaction API"}];
#
# var container = document.getElementById("4047cfa0-84b3-4f9b-8387-7c0723ecddbf");
#
# var data = {
#     nodes: nodes,
#     edges: edges
# };
#
# var options = {"physics": {"enabled": true, "solver": "repulsion"}, "edges": {"arrows": {"to": {"enabled": true, "scaleFactor": 0.5}}, "color": {"color": "grey", "highlight": "#404040"}, "smooth": {"enabled": true, "type": "dynamic"}, "font": {"size": 14, "align": "middle"}}, "nodes": {"font": {"size": "14"}, "size": 25, "shape": "ellipse"}};
#
# var network = new vis.Network(container, data, options);
#
# </script>

# %%
# Lookup and plot two pages and the nodes they link to
# -----------------
query="""
MATCH (a:Page {title: 'SQL' })-[r]->(b)
RETURN r
"""
data = graph.run(query).to_table()

# A length check should help prevent slowdowns
if not data:
    print("Page not found!")

draw_r(data, {'Page':'title'}, len(data) <= 150)
# Out:
# <div id="30e56bc1-c046-4a53-a582-bf3327ef743c" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "IBM Informix", "group": "Page", "id": 34038, "value": 0, "label": "IBM Informix"}, {"title": "Interbase", "group": "Page", "id": 284674, "value": 0, "label": "Interbase"}, {"title": "ISAM", "group": "Page", "id": 169220, "value": 0, "label": "ISAM"}, {"title": "SAP HANA", "group": "Page", "id": 10144517, "value": 0, "label": "SAP HANA"}, {"title": "IBM DB2", "group": "Page", "id": 13177607, "value": 0, "label": "IBM DB2"}, {"title": "SAP SE", "group": "Page", "id": 182280, "value": 0, "label": "SAP SE"}, {"title": "IBM System/38", "group": "Page", "id": 189828, "value": 0, "label": "IBM System/38"}, {"title": "QUEL query languages", "group": "Page", "id": 8620557, "value": 0, "label": "QUEL query languages"}, {"title": "MonetDB", "group": "Page", "id": 926990, "value": 0, "label": "MonetDB"}, {"title": "Oracle Corporation", "group": "Page", "id": 14611, "value": 0, "label": "Oracle Corporation"}, {"title": "ISO", "group": "Page", "id": 3023636, "value": 0, "label": "ISO"}, {"title": "SQL/MED", "group": "Page", "id": 3466521, "value": 0, "label": "SQL/MED"}, {"title": "JDBC", "group": "Page", "id": 6916890, "value": 0, "label": "JDBC"}, {"title": "Static typing", "group": "Page", "id": 66587, "value": 0, "label": "Static typing"}, {"title": "Star schema", "group": "Page", "id": 508890, "value": 0, "label": "Star schema"}, {"title": "United States Navy", "group": "Page", "id": 5559839, "value": 0, "label": "United States Navy"}, {"title": "Perl", "group": "Page", "id": 15536, "value": 0, "label": "Perl"}, {"title": "D4 (programming language)", "group": "Page", "id": 1349923, "value": 0, "label": "D4 (programming language)"}, {"title": "Cross-platform", "group": "Page", "id": 53284, "value": 0, "label": "Cross-platform"}, {"title": "C (programming language)", "group": "Page", "id": 3641, "value": 0, "label": "C (programming language)"}, {"title": "Programming language", "group": "Page", "id": 14886, "value": 0, "label": "Programming language"}, {"title": "NoSQL", "group": "Page", "id": 6400807, "value": 0, "label": "NoSQL"}, {"title": "Microsoft .NET", "group": "Page", "id": 49706, "value": 0, "label": "Microsoft .NET"}, {"title": "Java Persistence Query Language", "group": "Page", "id": 5812267, "value": 0, "label": "Java Persistence Query Language"}, {"title": "SQL/Schemata", "group": "Page", "id": 3466541, "value": 0, "label": "SQL/Schemata"}, {"title": "Declarative programming", "group": "Page", "id": 145966, "value": 0, "label": "Declarative programming"}, {"title": "SQL Server 2005", "group": "Page", "id": 2761266, "value": 0, "label": "SQL Server 2005"}, {"title": "IBM", "group": "Page", "id": 10143795, "value": 0, "label": "IBM"}, {"title": "IBM SQL/DS", "group": "Page", "id": 1253428, "value": 0, "label": "IBM SQL/DS"}, {"title": "Transact-SQL", "group": "Page", "id": 190517, "value": 0, "label": "Transact-SQL"}, {"title": "Federal Information Processing Standard", "group": "Page", "id": 10020150, "value": 0, "label": "Federal Information Processing Standard"}, {"title": "D (data language specification)", "group": "Page", "id": 1381257, "value": 0, "label": "D (data language specification)"}, {"title": "Hugh Darwen", "group": "Page", "id": 55352, "value": 0, "label": "Hugh Darwen"}, {"title": "IBM Business System 12", "group": "Page", "id": 55353, "value": 0, "label": "IBM Business System 12"}, {"title": "Database trigger", "group": "Page", "id": 732221, "value": 0, "label": "Database trigger"}, {"title": "National Institute of Standards and Technology", "group": "Page", "id": 14143, "value": 0, "label": "National Institute of Standards and Technology"}, {"title": "List of relational database management systems", "group": "Page", "id": 802624, "value": 0, "label": "List of relational database management systems"}, {"title": "SQL/XML", "group": "Page", "id": 3466561, "value": 0, "label": "SQL/XML"}, {"title": "Datalog", "group": "Page", "id": 552864, "value": 0, "label": "Datalog"}, {"title": "Cent ...

# %% [markdown]
# This is a good start, but it gets more interesting once we start to pull in the relationships of the nodes next to our own.
#
# Here, we get the pages linked to from `Neo4j` and turn them into two lists (we also insert the Neo4j node into both lists).
# We then unwind these lists and get the relationships between them.
# This lets us get all relationships between our `b` nodes as well as with our `Neo4j` node.
#
# If we ask for `(b)-[r]->(b)` without collecting and splitting it into two lists, Neo4j will iterate through `b` values and we end up asking only for self loops.

# %%
# NOTE: the COLLECT(b)+a is the part that 
#  adds (a:Page {title: 'Neo4j'}) to the list
query="""
MATCH (a:Page {title: 'Neo4j'})-->(b)
WITH COLLECT(b)+a AS left_set, COLLECT(b)+a as right_set
UNWIND left_set AS left
UNWIND right_set AS right
MATCH (left)-[r]->(right)
RETURN r
"""
data = graph.run(query).to_table()

draw_r(data, {'Page':'title'})
# Out:
# <div id="25d08abc-95b3-43ec-9759-b8dde0a14d45" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "Cypher Query Language", "group": "Page", "id": 10420416, "value": 2, "label": "Cypher Query Language"}, {"title": "ArangoDB", "group": "Page", "id": 11657601, "value": 2, "label": "ArangoDB"}, {"title": "Neo Technology", "group": "Page", "id": 6911747, "value": 1, "label": "Neo Technology"}, {"title": "Apache Giraph", "group": "Page", "id": 9539638, "value": 0, "label": "Apache Giraph"}, {"title": "Graph database", "group": "Page", "id": 6596737, "value": 19, "label": "Graph database"}, {"title": "Intentional Software", "group": "Page", "id": 3876236, "value": 0, "label": "Intentional Software"}, {"title": "GPLv3", "group": "Page", "id": 1917072, "value": 0, "label": "GPLv3"}, {"title": "DB-Engines ranking", "group": "Page", "id": 13555986, "value": 0, "label": "DB-Engines ranking"}, {"title": "Remote backup service", "group": "Page", "id": 881262, "value": 0, "label": "Remote backup service"}, {"title": "United States", "group": "Page", "id": 1496086, "value": 1, "label": "United States"}, {"title": "Nikolaj Nyholm", "group": "Page", "id": 7546967, "value": 0, "label": "Nikolaj Nyholm"}, {"title": "Europe", "group": "Page", "id": 5656, "value": 6, "label": "Europe"}, {"title": "Malm\u00f6", "group": "Page", "id": 12188, "value": 0, "label": "Malm\u00f6"}, {"title": "Freemium", "group": "Page", "id": 2611238, "value": 0, "label": "Freemium"}, {"title": "Java (programming language)", "group": "Page", "id": 10053, "value": 2, "label": "Java (programming language)"}, {"title": "CODASYL", "group": "Page", "id": 198304, "value": 0, "label": "CODASYL"}, {"title": "OrientDB", "group": "Page", "id": 8241569, "value": 11, "label": "OrientDB"}, {"title": "Spring Framework", "group": "Page", "id": 2056612, "value": 2, "label": "Spring Framework"}, {"title": "Affero General Public License", "group": "Page", "id": 2438694, "value": 2, "label": "Affero General Public License"}, {"title": "ACID", "group": "Page", "id": 40550, "value": 0, "label": "ACID"}, {"title": "Neo4j", "group": "Page", "id": 6745383, "value": 48, "label": "Neo4j"}, {"title": "Sweden", "group": "Page", "id": 1970728, "value": 2, "label": "Sweden"}, {"title": "San Francisco Bay Area", "group": "Page", "id": 5292782, "value": 2, "label": "San Francisco Bay Area"}, {"title": "GNU General Public License", "group": "Page", "id": 5211633, "value": 4, "label": "GNU General Public License"}, {"title": "Gremlin (programming language)", "group": "Page", "id": 8648946, "value": 5, "label": "Gremlin (programming language)"}, {"title": "AGPLv3", "group": "Page", "id": 6919349, "value": 0, "label": "AGPLv3"}, {"title": "North America", "group": "Page", "id": 13622, "value": 5, "label": "North America"}, {"title": "AllegroGraph", "group": "Page", "id": 7021627, "value": 4, "label": "AllegroGraph"}];
# var edges = [{"from": 5656, "to": 1496086, "title": "Europe -[Link]-> United States"}, {"from": 5656, "to": 13622, "title": "Europe -[Link]-> North America"}, {"from": 7021627, "to": 8241569, "title": "AllegroGraph -[Link]-> OrientDB"}, {"from": 6745383, "to": 40550, "title": "Neo4j -[Link]-> ACID"}, {"from": 6745383, "to": 10420416, "title": "Neo4j -[Link]-> Cypher Query Language"}, {"from": 6596737, "to": 40550, "title": "Graph database -[Link]-> ACID"}, {"from": 13622, "to": 5292782, "title": "North America -[Link]-> San Francisco Bay Area"}, {"from": 1496086, "to": 5656, "title": "United States -[Link]-> Europe"}, {"from": 13622, "to": 1496086, "title": "North America -[Link]-> United States"}, {"from": 6745383, "to": 1917072, "title": "Neo4j -[Link]-> GPLv3"}, {"from": 8241569, "to": 8648946, "title": "OrientDB -[Link]-> Gremlin (programming language)"}, {"from": 8241569, "to": 10053, "title": "OrientDB -[Link]-> Java (programming language)"}, {"from": 6745383, "to": 5292782, "title": "Neo4j -[Link]-> San Francisco Bay Area"}, {"from": 6745383, "to": 2438694, "title": "Neo4j -[Link]-> Affero General Public License"}, {"from": 8241569, "to": 40550, "title": "OrientDB -[Link]-> ACID"}, {"from": 10053, "to": 5211633, "title": "Java (programming language) -[Link]-> GNU General Public License"}, {"from": 10420416, "to": 6745383, "title": "Cypher Query Language -[Link]-> Neo4j"}, {"from": 6596737, "to": 11657601, "title": "Graph database -[Link]-> ArangoDB"}, {"from": 6596737, "to": 10420416, "title": "Graph database -[Link]-> Cypher Query Language"}, {"from": 5292782, "to": 1496086, "title": "San Francisco Bay Area -[Link]-> United States"}, {"from": 8241569, "to": 13555986, "title": "OrientDB -[Link]-> DB-Engines ranking"}, {"from": 1970728, "to": 12188, "title": "Sweden -[Link]-> Malm\u00f6"}, {"from": 11657601, "to": 6596737, "title": "ArangoDB -[Link]-> Graph database"}, {"from": 6745383, "to": 9539638, "title": "Neo4j -[Link]-> Apache Giraph"}, {"from": 6745383, "to": 7546967, "title": "Neo4j -[Link]-> Nikolaj Nyholm"}, {"from": 6745383, "to": 1496086, "title": "Neo4j -[Link]-> United States"}, {"from": 6596737, "to": 2438694, "title": "Graph database -[Link]-> Affero General Public License"}, {"from": 6596737, "to": 198304, "title": "Graph database -[Link]-> CODASYL"}, {"from": 6745383, "to": 12188, "title": "Neo4j -[Link]-> Malm\u00f6"}, {"from": 6596737, "to": 7021627, "title": "Graph database -[Link]-> AllegroGraph"}, {"from": 13622, "to": 5656, "title": "North America -[Link]-> Europe"}, {"from": 8241569, "to": 6745383, "title": "OrientDB -[Link]-> Neo4j"}, {"from": 6745383, "to": 8241569, "title": "Neo4j -[Link]-> OrientDB"}, {"from": 12188, "to": 1970728, "title": "Malm\u00f6 -[Link]-> Sweden"}, {"from": 8241569, "to": 10420416, "title": "OrientDB -[Link]-> Cypher Query Language"}, {"from": 6745383, "to": 881262, "title": "Neo4j -[Link]-> Remote backup service"}, {"from": 10053, "to": 2056612, "title": "Java (programming language) -[Link]-> Spring Framework"}, {"from": 8241569, "to": 6596737, "title": "OrientDB -[Link]-> Graph database"}, {"from": 9539638, "to": 10053, "title": "Apache Giraph -[Link]-> Java (programming language)"}, {"from": 6745383, "to": 6919349, "title": "Neo4j -[Link]-> AGPLv3"}, {"from": 6745383, "to": 5656, "title": "Neo4j -[Link]-> Europe"}, {"from": 6745383, "to": 6596737, "title": "Neo4j -[Link]-> Graph database"}, {"from": 6745383, "to": 8648946, "title": "Neo4j -[Link]-> Gremlin (programming language)"}, {"from": 6745383, "to": 5211633, "title": "Neo4j -[Link]-> GNU General Public License"}, {"from": 6745383, "to": 3876236, "title": "Neo4j -[Link]-> Intentional Software"}, {"from": 2056612, "to": 10053, "title": "Spring Framework -[Link]-> Java (programming language)"}, {"from": 6745383, "to": 2611238, "title": "Neo4j -[Link]-> Freemium"}, {"from": 6745383, "to": 7021627, "title": "Neo4j -[Link]-> AllegroGraph"}, {"from": 6745383, "to": 2056612, "title": "Neo4j -[Link]-> Spring Framework ...

# %% [markdown]
# Graphs, after all, are all about connections!
# These interconnections let us see relationships between our linked nodes we may not have known about.
#
#
# We can see that some pages we link to are related to graph databases while other pages are related to Java.
# Locations are pushed to one portion of the graph, with different connections between them.
# We can even see a hierarchy of geographical regions.
# The `North America` and `Europe` pages link to each other, and then `Europe` links to `Sweden`, which has links to and from `Malmö`.
#
# Since `Neo4j` is the basis of our query, everything tends to revolve around it.
# If we remove it from the lists we collect, our peer relationship graph looks *much* easier to understand.
# The location nodes are almost completely disjoint from our software and technology nodes!

# %%
query="""
MATCH (a:Page {title: 'Neo4j'})-->(b)
WITH COLLECT(b) AS left_set, COLLECT(b) as right_set
UNWIND left_set AS left
UNWIND right_set AS right
MATCH (left)-[r]->(right)
RETURN r
"""
data = graph.run(query).to_table()

draw_r(data, {'Page':'title'})
# Out:
# <div id="7e378ff6-bd01-4a4b-81e9-24c209352af8" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "Cypher Query Language", "group": "Page", "id": 10420416, "value": 0, "label": "Cypher Query Language"}, {"title": "ArangoDB", "group": "Page", "id": 11657601, "value": 2, "label": "ArangoDB"}, {"title": "AllegroGraph", "group": "Page", "id": 7021627, "value": 4, "label": "AllegroGraph"}, {"title": "Spring Framework", "group": "Page", "id": 2056612, "value": 2, "label": "Spring Framework"}, {"title": "United States", "group": "Page", "id": 1496086, "value": 1, "label": "United States"}, {"title": "ACID", "group": "Page", "id": 40550, "value": 0, "label": "ACID"}, {"title": "OrientDB", "group": "Page", "id": 8241569, "value": 9, "label": "OrientDB"}, {"title": "Sweden", "group": "Page", "id": 1970728, "value": 2, "label": "Sweden"}, {"title": "CODASYL", "group": "Page", "id": 198304, "value": 0, "label": "CODASYL"}, {"title": "Affero General Public License", "group": "Page", "id": 2438694, "value": 2, "label": "Affero General Public License"}, {"title": "DB-Engines ranking", "group": "Page", "id": 13555986, "value": 0, "label": "DB-Engines ranking"}, {"title": "San Francisco Bay Area", "group": "Page", "id": 5292782, "value": 2, "label": "San Francisco Bay Area"}, {"title": "GNU General Public License", "group": "Page", "id": 5211633, "value": 4, "label": "GNU General Public License"}, {"title": "Gremlin (programming language)", "group": "Page", "id": 8648946, "value": 4, "label": "Gremlin (programming language)"}, {"title": "Graph database", "group": "Page", "id": 6596737, "value": 17, "label": "Graph database"}, {"title": "North America", "group": "Page", "id": 13622, "value": 5, "label": "North America"}, {"title": "Europe", "group": "Page", "id": 5656, "value": 6, "label": "Europe"}, {"title": "Apache Giraph", "group": "Page", "id": 9539638, "value": 0, "label": "Apache Giraph"}, {"title": "Malm\u00f6", "group": "Page", "id": 12188, "value": 0, "label": "Malm\u00f6"}, {"title": "Java (programming language)", "group": "Page", "id": 10053, "value": 2, "label": "Java (programming language)"}];
# var edges = [{"from": 8241569, "to": 6596737, "title": "OrientDB -[Link]-> Graph database"}, {"from": 5656, "to": 1496086, "title": "Europe -[Link]-> United States"}, {"from": 5656, "to": 13622, "title": "Europe -[Link]-> North America"}, {"from": 7021627, "to": 8241569, "title": "AllegroGraph -[Link]-> OrientDB"}, {"from": 6596737, "to": 198304, "title": "Graph database -[Link]-> CODASYL"}, {"from": 2056612, "to": 10053, "title": "Spring Framework -[Link]-> Java (programming language)"}, {"from": 5211633, "to": 2438694, "title": "GNU General Public License -[Link]-> Affero General Public License"}, {"from": 6596737, "to": 40550, "title": "Graph database -[Link]-> ACID"}, {"from": 5292782, "to": 1496086, "title": "San Francisco Bay Area -[Link]-> United States"}, {"from": 13622, "to": 5292782, "title": "North America -[Link]-> San Francisco Bay Area"}, {"from": 6596737, "to": 2438694, "title": "Graph database -[Link]-> Affero General Public License"}, {"from": 1496086, "to": 5656, "title": "United States -[Link]-> Europe"}, {"from": 13622, "to": 1496086, "title": "North America -[Link]-> United States"}, {"from": 8241569, "to": 8648946, "title": "OrientDB -[Link]-> Gremlin (programming language)"}, {"from": 8241569, "to": 10053, "title": "OrientDB -[Link]-> Java (programming language)"}, {"from": 1496086, "to": 13622, "title": "United States -[Link]-> North America"}, {"from": 6596737, "to": 8648946, "title": "Graph database -[Link]-> Gremlin (programming language)"}, {"from": 8241569, "to": 40550, "title": "OrientDB -[Link]-> ACID"}, {"from": 6596737, "to": 10053, "title": "Graph database -[Link]-> Java (programming language)"}, {"from": 10053, "to": 5211633, "title": "Java (programming language) -[Link]-> GNU General Public License"}, {"from": 6596737, "to": 11657601, "title": "Graph database -[Link]-> ArangoDB"}, {"from": 7021627, "to": 10053, "title": "AllegroGraph -[Link]-> Java (programming language)"}, {"from": 5211633, "to": 1496086, "title": "GNU General Public License -[Link]-> United States"}, {"from": 12188, "to": 1970728, "title": "Malm\u00f6 -[Link]-> Sweden"}, {"from": 5656, "to": 1970728, "title": "Europe -[Link]-> Sweden"}, {"from": 2438694, "to": 5211633, "title": "Affero General Public License -[Link]-> GNU General Public License"}, {"from": 6596737, "to": 5211633, "title": "Graph database -[Link]-> GNU General Public License"}, {"from": 13622, "to": 5656, "title": "North America -[Link]-> Europe"}, {"from": 8241569, "to": 13555986, "title": "OrientDB -[Link]-> DB-Engines ranking"}, {"from": 8648946, "to": 10053, "title": "Gremlin (programming language) -[Link]-> Java (programming language)"}, {"from": 1970728, "to": 12188, "title": "Sweden -[Link]-> Malm\u00f6"}, {"from": 11657601, "to": 6596737, "title": "ArangoDB -[Link]-> Graph database"}, {"from": 8648946, "to": 9539638, "title": "Gremlin (programming language) -[Link]-> Apache Giraph"}, {"from": 10053, "to": 2056612, "title": "Java (programming language) -[Link]-> Spring Framework"}, {"from": 6596737, "to": 8241569, "title": "Graph database -[Link]-> OrientDB"}, {"from": 6596737, "to": 10420416, "title": "Graph database -[Link]-> Cypher Query Language"}, {"from": 6596737, "to": 7021627, "title": "Graph database -[Link]-> AllegroGraph"}, {"from": 8241569, "to": 11657601, "title": "OrientDB -[Link]-> ArangoDB"}, {"from": 8648946, "to": 8241569, "title": "Gremlin (programming language) -[Link]-> OrientDB"}, {"from": 8241569, "to": 10420416, "title": "OrientDB -[Link]-> Cypher Query Language"}, {"from": 9539638, "to": 10053, "title": "Apache Giraph -[Link]-> Java (programming language)"}];
#
# var container = document.getElementById("7e378ff6-bd01-4a4b-81e9-24c209352af8");
#
# var data = {
#     nodes: nodes,
#     edges: edges
# };
#
# var options = {"physics": {"enabled": true, "solver": "repulsion"}, "edges": {"arrows": {"to": {"enabled": true, "scaleFactor": 0.5}}, "color": {"color": "grey", "highlight": "#404040"}, "smooth": {"enabled": true, "type": "dynamic"}, "font": {"size": 14, "align": "middle"}}, "nodes": {"font": {"size": "14"}, "size": 25, "shape": "ellipse"}};
#
# var network = new vis.Network(container, data, options);
#
# </script>

# %% [markdown]
# But, since we removed our central node and are only plotting relationships, any pages that only linked to/from `Neo4j` disappear!
#
# We can tweak this with more list shenanigans and another drawing function.
# `draw_nr` will let your draw a list of nodes and a list of relationships.

# %%
query="""
MATCH (a:Page {title: 'Neo4j'})-->(b)
WITH COLLECT(b) AS left_set, COLLECT(b) as right_set
UNWIND left_set AS left
UNWIND right_set AS right
MATCH (left)-[r]->(right)
RETURN left_set, collect(r)
"""
data = graph.run(query).to_table()

# We only get one row back from our query
# The first element is a list of nodes, the second is our relationships
draw_nr(data[0][0], data[0][1], {'Page':'title'})
# Out:
# <div id="792edcc1-6baf-487f-97c1-25ce63829a14" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "Cypher Query Language", "group": "Page", "id": 10420416, "value": 2, "label": "Cypher Query Language"}, {"title": "ArangoDB", "group": "Page", "id": 11657601, "value": 3, "label": "ArangoDB"}, {"title": "Neo Technology", "group": "Page", "id": 6911747, "value": 0, "label": "Neo Technology"}, {"title": "North America", "group": "Page", "id": 13622, "value": 5, "label": "North America"}, {"title": "Graph database", "group": "Page", "id": 6596737, "value": 12, "label": "Graph database"}, {"title": "Intentional Software", "group": "Page", "id": 3876236, "value": 0, "label": "Intentional Software"}, {"title": "GPLv3", "group": "Page", "id": 1917072, "value": 0, "label": "GPLv3"}, {"title": "DB-Engines ranking", "group": "Page", "id": 13555986, "value": 1, "label": "DB-Engines ranking"}, {"title": "San Francisco Bay Area", "group": "Page", "id": 5292782, "value": 2, "label": "San Francisco Bay Area"}, {"title": "United States", "group": "Page", "id": 1496086, "value": 6, "label": "United States"}, {"title": "Nikolaj Nyholm", "group": "Page", "id": 7546967, "value": 0, "label": "Nikolaj Nyholm"}, {"title": "Europe", "group": "Page", "id": 5656, "value": 5, "label": "Europe"}, {"title": "Malm\u00f6", "group": "Page", "id": 12188, "value": 2, "label": "Malm\u00f6"}, {"title": "Java (programming language)", "group": "Page", "id": 10053, "value": 8, "label": "Java (programming language)"}, {"title": "CODASYL", "group": "Page", "id": 198304, "value": 1, "label": "CODASYL"}, {"title": "OrientDB", "group": "Page", "id": 8241569, "value": 10, "label": "OrientDB"}, {"title": "AllegroGraph", "group": "Page", "id": 7021627, "value": 3, "label": "AllegroGraph"}, {"title": "Spring Framework", "group": "Page", "id": 2056612, "value": 2, "label": "Spring Framework"}, {"title": "ACID", "group": "Page", "id": 40550, "value": 2, "label": "ACID"}, {"title": "Affero General Public License", "group": "Page", "id": 2438694, "value": 3, "label": "Affero General Public License"}, {"title": "Sweden", "group": "Page", "id": 1970728, "value": 3, "label": "Sweden"}, {"title": "Remote backup service", "group": "Page", "id": 881262, "value": 0, "label": "Remote backup service"}, {"title": "GNU General Public License", "group": "Page", "id": 5211633, "value": 5, "label": "GNU General Public License"}, {"title": "Gremlin (programming language)", "group": "Page", "id": 8648946, "value": 5, "label": "Gremlin (programming language)"}, {"title": "AGPLv3", "group": "Page", "id": 6919349, "value": 0, "label": "AGPLv3"}, {"title": "Apache Giraph", "group": "Page", "id": 9539638, "value": 2, "label": "Apache Giraph"}, {"title": "Freemium", "group": "Page", "id": 2611238, "value": 0, "label": "Freemium"}];
# var edges = [{"from": 8241569, "to": 6596737, "title": "OrientDB -[Link]-> Graph database"}, {"from": 5656, "to": 1496086, "title": "Europe -[Link]-> United States"}, {"from": 5656, "to": 13622, "title": "Europe -[Link]-> North America"}, {"from": 7021627, "to": 8241569, "title": "AllegroGraph -[Link]-> OrientDB"}, {"from": 6596737, "to": 198304, "title": "Graph database -[Link]-> CODASYL"}, {"from": 2056612, "to": 10053, "title": "Spring Framework -[Link]-> Java (programming language)"}, {"from": 5211633, "to": 2438694, "title": "GNU General Public License -[Link]-> Affero General Public License"}, {"from": 6596737, "to": 40550, "title": "Graph database -[Link]-> ACID"}, {"from": 5292782, "to": 1496086, "title": "San Francisco Bay Area -[Link]-> United States"}, {"from": 13622, "to": 5292782, "title": "North America -[Link]-> San Francisco Bay Area"}, {"from": 6596737, "to": 2438694, "title": "Graph database -[Link]-> Affero General Public License"}, {"from": 1496086, "to": 5656, "title": "United States -[Link]-> Europe"}, {"from": 13622, "to": 1496086, "title": "North America -[Link]-> United States"}, {"from": 8241569, "to": 8648946, "title": "OrientDB -[Link]-> Gremlin (programming language)"}, {"from": 8241569, "to": 10053, "title": "OrientDB -[Link]-> Java (programming language)"}, {"from": 1496086, "to": 13622, "title": "United States -[Link]-> North America"}, {"from": 6596737, "to": 8648946, "title": "Graph database -[Link]-> Gremlin (programming language)"}, {"from": 8241569, "to": 40550, "title": "OrientDB -[Link]-> ACID"}, {"from": 6596737, "to": 10053, "title": "Graph database -[Link]-> Java (programming language)"}, {"from": 10053, "to": 5211633, "title": "Java (programming language) -[Link]-> GNU General Public License"}, {"from": 6596737, "to": 11657601, "title": "Graph database -[Link]-> ArangoDB"}, {"from": 7021627, "to": 10053, "title": "AllegroGraph -[Link]-> Java (programming language)"}, {"from": 5211633, "to": 1496086, "title": "GNU General Public License -[Link]-> United States"}, {"from": 12188, "to": 1970728, "title": "Malm\u00f6 -[Link]-> Sweden"}, {"from": 5656, "to": 1970728, "title": "Europe -[Link]-> Sweden"}, {"from": 2438694, "to": 5211633, "title": "Affero General Public License -[Link]-> GNU General Public License"}, {"from": 6596737, "to": 5211633, "title": "Graph database -[Link]-> GNU General Public License"}, {"from": 13622, "to": 5656, "title": "North America -[Link]-> Europe"}, {"from": 8241569, "to": 13555986, "title": "OrientDB -[Link]-> DB-Engines ranking"}, {"from": 8648946, "to": 10053, "title": "Gremlin (programming language) -[Link]-> Java (programming language)"}, {"from": 1970728, "to": 12188, "title": "Sweden -[Link]-> Malm\u00f6"}, {"from": 11657601, "to": 6596737, "title": "ArangoDB -[Link]-> Graph database"}, {"from": 8648946, "to": 9539638, "title": "Gremlin (programming language) -[Link]-> Apache Giraph"}, {"from": 10053, "to": 2056612, "title": "Java (programming language) -[Link]-> Spring Framework"}, {"from": 6596737, "to": 8241569, "title": "Graph database -[Link]-> OrientDB"}, {"from": 6596737, "to": 10420416, "title": "Graph database -[Link]-> Cypher Query Language"}, {"from": 6596737, "to": 7021627, "title": "Graph database -[Link]-> AllegroGraph"}, {"from": 8241569, "to": 11657601, "title": "OrientDB -[Link]-> ArangoDB"}, {"from": 8648946, "to": 8241569, "title": "Gremlin (programming language) -[Link]-> OrientDB"}, {"from": 8241569, "to": 10420416, "title": "OrientDB -[Link]-> Cypher Query Language"}, {"from": 9539638, "to": 10053, "title": "Apache Giraph -[Link]-> Java (programming language)"}];
#
# var container = document.getElementById("792edcc1-6baf-487f-97c1-25ce63829a14");
#
# var data = {
#     nodes: nodes,
#     edges: edges
# };
#
# var options = {"physics": {"enabled": true, "solver": "repulsion"}, "edges": {"arrows": {"to": {"enabled": true, "scaleFactor": 0.5}}, "color": {"color": "grey", "highlight": "#404040"}, "smooth": {"enabled": true, "type": "dynamic"}, "font": {"size": 14, "align": "middle"}}, "nodes": {"font": {"size": "14"}, "size": 25, "shape": "ellipse"}};
#
# var network = new vis.Network(container, data, options);
#
# </script>

# %% [markdown]
# Now we can see those lonely pages as well!
#
# Once again, we've only been looking at outgoing nodes. Let's branch out a little more and plot the relationships between pages one hop away from Neo4j in either direction.

# %%
query="""
MATCH (a:Page {title: 'Neo4j'})<-->(b)
WITH COLLECT(b) AS left_set, COLLECT(b) as right_set
UNWIND left_set AS left
UNWIND right_set AS right
MATCH (left)-[r]->(right)
RETURN left_set, collect(r)
"""
data = graph.run(query).to_table()

# We only get one row back from our query
# The first element is a list of nodes, the second is our relationships
draw_nr(data[0][0], data[0][1], {'Page':'title'})
# Out:
# <div id="6baafc1a-6095-4b05-9e43-e0d226ad29a1" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "ArangoDB", "group": "Page", "id": 11657601, "value": 10, "label": "ArangoDB"}, {"title": "Neo Technology", "group": "Page", "id": 6911747, "value": 0, "label": "Neo Technology"}, {"title": "Europe", "group": "Page", "id": 5656, "value": 5, "label": "Europe"}, {"title": "Graph database", "group": "Page", "id": 6596737, "value": 38, "label": "Graph database"}, {"title": "Intentional Software", "group": "Page", "id": 3876236, "value": 0, "label": "Intentional Software"}, {"title": "GPLv3", "group": "Page", "id": 1917072, "value": 0, "label": "GPLv3"}, {"title": "Linkurious", "group": "Page", "id": 12956440, "value": 2, "label": "Linkurious"}, {"title": "DB-Engines ranking", "group": "Page", "id": 13555986, "value": 2, "label": "DB-Engines ranking"}, {"title": "Connection pool", "group": "Page", "id": 1080067, "value": 0, "label": "Connection pool"}, {"title": "Remote backup service", "group": "Page", "id": 881262, "value": 0, "label": "Remote backup service"}, {"title": "United States", "group": "Page", "id": 1496086, "value": 7, "label": "United States"}, {"title": "Neo4J", "group": "Page", "id": 6911768, "value": 2, "label": "Neo4J"}, {"title": "Malm\u00f6", "group": "Page", "id": 12188, "value": 2, "label": "Malm\u00f6"}, {"title": "Java (programming language)", "group": "Page", "id": 10053, "value": 18, "label": "Java (programming language)"}, {"title": "Well-known text", "group": "Page", "id": 2283552, "value": 0, "label": "Well-known text"}, {"title": "OrientDB", "group": "Page", "id": 8241569, "value": 40, "label": "OrientDB"}, {"title": "Spring Framework", "group": "Page", "id": 2056612, "value": 5, "label": "Spring Framework"}, {"title": "Affero General Public License", "group": "Page", "id": 2438694, "value": 6, "label": "Affero General Public License"}, {"title": "NoSQL", "group": "Page", "id": 6400807, "value": 22, "label": "NoSQL"}, {"title": "Sweden", "group": "Page", "id": 1970728, "value": 3, "label": "Sweden"}, {"title": "FlockDB", "group": "Page", "id": 7059740, "value": 2, "label": "FlockDB"}, {"title": "AGPLv3", "group": "Page", "id": 6919349, "value": 0, "label": "AGPLv3"}, {"title": "North America", "group": "Page", "id": 13622, "value": 5, "label": "North America"}, {"title": "DataNucleus", "group": "Page", "id": 6247659, "value": 1, "label": "DataNucleus"}, {"title": "Hybrid transactional/analytical processing (HTAP)", "group": "Page", "id": 10861625, "value": 3, "label": "Hybrid transactional/analytical processing (HTAP)"}, {"title": "AllegroGraph", "group": "Page", "id": 7021627, "value": 10, "label": "AllegroGraph"}, {"title": "List of TCP and UDP port numbers", "group": "Page", "id": 219839, "value": 3, "label": "List of TCP and UDP port numbers"}, {"title": "Cypher Query Language", "group": "Page", "id": 10420416, "value": 14, "label": "Cypher Query Language"}, {"title": "CODASYL", "group": "Page", "id": 198304, "value": 3, "label": "CODASYL"}, {"title": "Query language", "group": "Page", "id": 302405, "value": 6, "label": "Query language"}, {"title": "Bolt (network protocol)", "group": "Page", "id": 12555532, "value": 1, "label": "Bolt (network protocol)"}, {"title": "List of JVM languages", "group": "Page", "id": 4350162, "value": 4, "label": "List of JVM languages"}, {"title": "Nikolaj Nyholm", "group": "Page", "id": 7546967, "value": 0, "label": "Nikolaj Nyholm"}, {"title": "Apache Giraph", "group": "Page", "id": 9539638, "value": 4, "label": "Apache Giraph"}, {"title": "Paradise Papers", "group": "Page", "id": 13418333, "value": 1, "label": "Paradise Papers"}, {"title": "Jelastic", "group": "Page", "id": 9836773, "value": 1, "label": "Jelastic"}, {"title": "Freemium", "group": "Page", "id": 2611238, "value": 0, "label": "Freemium"}, {"title": "ACID", "group": "Page", "id": 40550, "value": 5, "label": "ACID"}, {"title": "Comparison of structured storage software", "group": "Page", "id": 6630632, "value": 10, "label": "Comparison of structured storage software"}, {"title": " ...
# var edges = [{"from": 5656, "to": 13622, "title": "Europe -[Link]-> North America"}, {"from": 10053, "to": 4350162, "title": "Java (programming language) -[Link]-> List of JVM languages"}, {"from": 219839, "to": 8241569, "title": "List of TCP and UDP port numbers -[Link]-> OrientDB"}, {"from": 1826599, "to": 2438694, "title": "Spatial database -[Link]-> Affero General Public License"}, {"from": 1496086, "to": 5656, "title": "United States -[Link]-> Europe"}, {"from": 1826599, "to": 7021627, "title": "Spatial database -[Link]-> AllegroGraph"}, {"from": 13622, "to": 1496086, "title": "North America -[Link]-> United States"}, {"from": 8241569, "to": 8648946, "title": "OrientDB -[Link]-> Gremlin (programming language)"}, {"from": 8241569, "to": 10053, "title": "OrientDB -[Link]-> Java (programming language)"}, {"from": 9836773, "to": 10053, "title": "Jelastic -[Link]-> Java (programming language)"}, {"from": 8241569, "to": 40550, "title": "OrientDB -[Link]-> ACID"}, {"from": 4350162, "to": 10420416, "title": "List of JVM languages -[Link]-> Cypher Query Language"}, {"from": 5292782, "to": 1496086, "title": "San Francisco Bay Area -[Link]-> United States"}, {"from": 8241569, "to": 13555986, "title": "OrientDB -[Link]-> DB-Engines ranking"}, {"from": 1970728, "to": 12188, "title": "Sweden -[Link]-> Malm\u00f6"}, {"from": 11657601, "to": 6596737, "title": "ArangoDB -[Link]-> Graph database"}, {"from": 11657601, "to": 6400807, "title": "ArangoDB -[Link]-> NoSQL"}, {"from": 10053, "to": 2056612, "title": "Java (programming language) -[Link]-> Spring Framework"}, {"from": 8241569, "to": 6400807, "title": "OrientDB -[Link]-> NoSQL"}, {"from": 13622, "to": 5656, "title": "North America -[Link]-> Europe"}, {"from": 8241569, "to": 10420416, "title": "OrientDB -[Link]-> Cypher Query Language"}, {"from": 6247659, "to": 10053, "title": "DataNucleus -[Link]-> Java (programming language)"}, {"from": 9539638, "to": 10053, "title": "Apache Giraph -[Link]-> Java (programming language)"}, {"from": 8241569, "to": 6596737, "title": "OrientDB -[Link]-> Graph database"}, {"from": 302405, "to": 8648946, "title": "Query language -[Link]-> Gremlin (programming language)"}, {"from": 8379411, "to": 1496086, "title": "GameDuell -[Link]-> United States"}, {"from": 8241569, "to": 11657601, "title": "OrientDB -[Link]-> ArangoDB"}, {"from": 6400807, "to": 10420416, "title": "NoSQL -[Link]-> Cypher Query Language"}, {"from": 1496086, "to": 13622, "title": "United States -[Link]-> North America"}, {"from": 6596737, "to": 8648946, "title": "Graph database -[Link]-> Gremlin (programming language)"}, {"from": 219839, "to": 12555532, "title": "List of TCP and UDP port numbers -[Link]-> Bolt (network protocol)"}, {"from": 6596737, "to": 10053, "title": "Graph database -[Link]-> Java (programming language)"}, {"from": 7021627, "to": 8241569, "title": "AllegroGraph -[Link]-> OrientDB"}, {"from": 7059740, "to": 10053, "title": "FlockDB -[Link]-

# %% [markdown]
# ## <span style="background:yellow">Your Turn</span>
#
# Lookup two more pages and plot the relationships between nodes zero degrees (1 hop) away from it.
# Make note of any interesting relationships or clusters of pages you observe.

# %%
# M4:P3:Q2

# Lookup another  page and plot the relationships between
#  the nodes zero degrees away from it
# Note any interesting relationships or clusers of nodes you observe
#
# Note that this query can take awhile on very large pages.
# -----------------
query="""
MATCH (a:Page {title: 'SQL'})<-->(b)
WITH COLLECT(b) AS left_set, COLLECT(b) as right_set
UNWIND left_set AS left
UNWIND right_set AS right
MATCH (left)-[r]->(right)
RETURN left_set, collect(r)
"""
data = graph.run(query).to_table()

if not data:
    print("Page not found!")
draw_nr(data[0][0], data[0][1], {'Page':'title'}, len(data[0][0]) <= 150)
# Out:
# <div id="8bd11e93-96ae-4fc3-819c-5e7c8463d987" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "List of collaborative software", "group": "Page", "id": 890881, "value": 25, "label": "List of collaborative software"}, {"title": "Interbase", "group": "Page", "id": 284674, "value": 3, "label": "Interbase"}, {"title": "VAX", "group": "Page", "id": 21163, "value": 16, "label": "VAX"}, {"title": "Bluefish (software)", "group": "Page", "id": 129030, "value": 11, "label": "Bluefish (software)"}, {"title": "SAP SE", "group": "Page", "id": 182280, "value": 23, "label": "SAP SE"}, {"title": "Data cube", "group": "Page", "id": 885043, "value": 8, "label": "Data cube"}, {"title": "Db2 for Linux, UNIX and Windows", "group": "Page", "id": 1683466, "value": 16, "label": "Db2 for Linux, UNIX and Windows"}, {"title": "XPath", "group": "Page", "id": 5253131, "value": 54, "label": "XPath"}, {"title": "WebMethods Integration Server", "group": "Page", "id": 3084300, "value": 5, "label": "WebMethods Integration Server"}, {"title": "Remote Data Services", "group": "Page", "id": 1248941, "value": 8, "label": "Remote Data Services"}, {"title": "South West England", "group": "Page", "id": 34832, "value": 3, "label": "South West England"}, {"title": "Exasol", "group": "Page", "id": 5326865, "value": 7, "label": "Exasol"}, {"title": "Payara Server", "group": "Page", "id": 12288025, "value": 5, "label": "Payara Server"}, {"title": "Enterprise Objects Framework", "group": "Page", "id": 39599, "value": 5, "label": "Enterprise Objects Framework"}, {"title": "Logical conjunction", "group": "Page", "id": 11610, "value": 4, "label": "Logical conjunction"}, {"title": "Parameter (computer programming)", "group": "Page", "id": 206878, "value": 11, "label": "Parameter (computer programming)"}, {"title": "Oracle Spatial and Graph", "group": "Page", "id": 2170911, "value": 11, "label": "Oracle Spatial and Graph"}, {"title": "App Academy", "group": "Page", "id": 9916448, "value": 1, "label": "App Academy"}, {"title": "AS/400 library", "group": "Page", "id": 268635, "value": 0, "label": "AS/400 library"}, {"title": "Cross-platform", "group": "Page", "id": 53284, "value": 146, "label": "Cross-platform"}, {"title": "SQ1", "group": "Page", "id": 8779711, "value": 0, "label": "SQ1"}, {"title": "DocPoint", "group": "Page", "id": 4818983, "value": 1, "label": "DocPoint"}, {"title": "Transitive closure", "group": "Page", "id": 188456, "value": 11, "label": "Transitive closure"}, {"title": "DBeaver", "group": "Page", "id": 12818473, "value": 23, "label": "DBeaver"}, {"title": "Java Persistence Query Language", "group": "Page", "id": 5812267, "value": 14, "label": "Java Persistence Query Language"}, {"title": "JetBrains", "group": "Page", "id": 10026333, "value": 12, "label": "JetBrains"}, {"title": "Application server", "group": "Page", "id": 118832, "value": 18, "label": "Application server"}, {"title": "Actian", "group": "Page", "id": 10355720, "value": 14, "label": "Actian"}, {"title": "IBM", "group": "Page", "id": 10143795, "value": 246, "label": "IBM"}, {"title": "IBM SQL/DS", "group": "Page", "id": 1253428, "value": 24, "label": "IBM SQL/DS"}, {"title": "Transact-SQL", "group": "Page", "id": 190517, "value": 68, "label": "Transact-SQL"}, {"title": "Hugh Darwen", "group": "Page", "id": 55352, "value": 44, "label": "Hugh Darwen"}, {"title": "IBM Business System 12", "group": "Page", "id": 55353, "value": 22, "label": "IBM Business System 12"}, {"title": "XQuery", "group": "Page", "id": 6346628, "value": 106, "label": "XQuery"}, {"title": "Database model", "group": "Page", "id": 3307580, "value": 24, "label": "Database model"}, {"title": "Sublanguage", "group": "Page", "id": 372797, "value": 5, "label": "Sublanguage"}, {"title": "SQream DB", "group": "Page", "id": 11487296, "value": 6, "label": "SQream DB"}, {"title": "Technical standard", "group": "Page", "id": 5210464, "value": 6, "label": "Technical standard"}, {"title": "Datalog", "group": "Page", "id": 552864, "value": 33, "label": "Datalog"}, {"title": "Semantic interoperability", "group": ...

# %% [markdown]
# #### What interesting relationships can you note in your plot above?

# %% [raw]
# # M4:P3:Q3
#
# # Add your analysis here
# # ----------------------
# It's too many relationships.  It's really crowded.  I can not see how they connect to each others.

# %%
# M4:P3:Q4

# Lookup another page and plot the relationships between
#  the nodes zero degrees away from it
# Note any interesting relationships or clusers of nodes you observe
#
# Note that this query can take awhile on very large pages.
# -----------------
query="""
MATCH (a:Page {title: 'ACID'})<-->(b)
WITH COLLECT(b) AS left_set, COLLECT(b) as right_set
UNWIND left_set AS left
UNWIND right_set AS right
MATCH (left)-[r]->(right)
RETURN left_set, collect(r)
"""
data = graph.run(query).to_table()

if not data:
    print("Page not found!")
draw_nr(data[0][0], data[0][1], {'Page':'title'}, len(data[0][0]) <= 150)
# Out:
# <div id="ecec5fc4-b52d-4bfc-86b3-7abca5481a41" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "Write\u2013read conflict", "group": "Page", "id": 150017, "value": 2, "label": "Write\u2013read conflict"}, {"title": "Voldemort (distributed data store)", "group": "Page", "id": 8121603, "value": 4, "label": "Voldemort (distributed data store)"}, {"title": "Microsoft Jet Database Engine", "group": "Page", "id": 960451, "value": 3, "label": "Microsoft Jet Database Engine"}, {"title": "Pyrrho (RDBMS)", "group": "Page", "id": 13756934, "value": 1, "label": "Pyrrho (RDBMS)"}, {"title": "Franz Inc.", "group": "Page", "id": 11709962, "value": 0, "label": "Franz Inc."}, {"title": "Isolation (database systems)", "group": "Page", "id": 207371, "value": 42, "label": "Isolation (database systems)"}, {"title": "DataObjects.NET", "group": "Page", "id": 6715660, "value": 3, "label": "DataObjects.NET"}, {"title": "Concurrency control", "group": "Page", "id": 149774, "value": 56, "label": "Concurrency control"}, {"title": "Raima Database Manager", "group": "Page", "id": 4223754, "value": 5, "label": "Raima Database Manager"}, {"title": "Exasol", "group": "Page", "id": 5326865, "value": 2, "label": "Exasol"}, {"title": "TIBCO Software", "group": "Page", "id": 3437009, "value": 1, "label": "TIBCO Software"}, {"title": "Multi-model database", "group": "Page", "id": 11188499, "value": 16, "label": "Multi-model database"}, {"title": "Enterprise JavaBeans", "group": "Page", "id": 28437, "value": 6, "label": "Enterprise JavaBeans"}, {"title": "Flash memory", "group": "Page", "id": 33246, "value": 1, "label": "Flash memory"}, {"title": "Cosmos DB", "group": "Page", "id": 11386394, "value": 6, "label": "Cosmos DB"}, {"title": "MagLev (software)", "group": "Page", "id": 9258267, "value": 0, "label": "MagLev (software)"}, {"title": "Java Transaction API", "group": "Page", "id": 28444, "value": 5, "label": "Java Transaction API"}, {"title": "Linearizability", "group": "Page", "id": 657370, "value": 5, "label": "Linearizability"}, {"title": "MarkLogic Server", "group": "Page", "id": 6018590, "value": 5, "label": "MarkLogic Server"}, {"title": "Outline of databases", "group": "Page", "id": 9077280, "value": 15, "label": "Outline of databases"}, {"title": "List of computing and IT abbreviations", "group": "Page", "id": 33456, "value": 6, "label": "List of computing and IT abbreviations"}, {"title": "Windows Vista I/O technologies", "group": "Page", "id": 2265635, "value": 0, "label": "Windows Vista I/O technologies"}, {"title": "Knowledge base", "group": "Page", "id": 162004, "value": 3, "label": "Knowledge base"}, {"title": "Neo4j", "group": "Page", "id": 6745383, "value": 5, "label": "Neo4j"}, {"title": "Database testing", "group": "Page", "id": 8681768, "value": 3, "label": "Database testing"}, {"title": "Oracle NoSQL Database", "group": "Page", "id": 9397291, "value": 11, "label": "Oracle NoSQL Database"}, {"title": "Atomicity (database systems)", "group": "Page", "id": 235052, "value": 48, "label": "Atomicity (database systems)"}, {"title": "Create, read, update and delete", "group": "Page", "id": 185389, "value": 10, "label": "Create, read, update and delete"}, {"title": "Acid (disambiguation)", "group": "Page", "id": 391726, "value": 0, "label": "Acid (disambiguation)"}, {"title": "Global serializability", "group": "Page", "id": 3503920, "value": 10, "label": "Global serializability"}, {"title": "Two phase locking", "group": "Page", "id": 5955123, "value": 1, "label": "Two phase locking"}, {"title": "TokuDB", "group": "Page", "id": 8423988, "value": 7, "label": "TokuDB"}, {"title": "GT.M", "group": "Page", "id": 646965, "value": 4, "label": "GT.M"}, {"title": "Journaling file system", "group": "Page", "id": 6265910, "value": 7, "label": "Journaling file system"}, {"title": "Benchmark (computing)", "group": "Page", "id": 973750, "value": 1, "label": "Benchmark (computing)"}, {"title": "VoltDB", "group": "Page", "id": 7178804, "value": 10, "label": "VoltDB"}, {"title": "Embedded database", "group": "Page", "id": 4342586, "value ...

# %% [markdown]
# #### What interesting relationships can you note in your plot above?

# %% [raw]
# # M4:P3:Q5
#
# # Add your analysis here
# # ----------------------
#
# It's the same as above. It's too many relationships.  It's really crowded.  I can not see how they connect to each others.

# %% [markdown]
# ----
# Let's branch out another hop.
# As you may recall, `Neo4j` starts out small enough, but once we get two hops out, we've reached 3% of Wikipedia!
#
# The fourth argument to our drawing function is a configuration dictionary that lets us control [vis.js settings](http://visjs.org/docs/network/),
# and we've prepared two simple ones.
# By default, the drawing functions use `small_options`.
# Let's see what that contains:

# %%
small_options
# Out:
# {'edges': {'arrows': {'to': {'enabled': True, 'scaleFactor': 0.5}},
#   'color': {'color': 'grey', 'highlight': '#404040'},
#   'font': {'align': 'middle', 'size': 14},
#   'smooth': {'enabled': True, 'type': 'dynamic'}},
#  'nodes': {'font': {'size': '14'}, 'shape': 'ellipse', 'size': 25},
#  'physics': {'enabled': False, 'solver': 'repulsion'}}

# %% [markdown]
# Our edges have arrows turned on at the destination end, scaled down slightly.
# The edge color is set to grey, and its labels (which we aren't using) are middle aligned with size 14 font.
# Edges are curved using the dynamic setting.
#
# Our nodes are ellipses with font size 14. Ellipses are label-size controlled, so the size setting doesn't apply.
#
# Physics are turned on, though the physics flag to the draw function overrides this, and uses the repulsion physics system.
#
# It works well for small graphs. Let's see what we have for large graphs (thousands of nodes):

# %%
large_options
# Out:
# {'edges': {'arrows': {'to': {'enabled': True, 'scaleFactor': 0.5}},
#   'color': {'color': 'grey', 'highlight': '#404040'},
#   'font': {'align': 'middle', 'size': 14},
#   'smooth': {'enabled': True, 'type': 'dynamic'}},
#  'nodes': {'font': {'background': 'white', 'size': '14'},
#   'scaling': {'label': {'enabled': True, 'max': 250, 'min': 14},
#    'max': 800,
#    'min': 10},
#   'shape': 'dot',
#   'size': 25},
#  'physics': {'enabled': False, 'solver': 'repulsion'}}

# %% [markdown]
# We've tweaked the edge highlight color, enabled node scaling, and switched to dots.
# In the background, the drawing functions track how many edges are attached to a given node, and this can be used for scaling.
#
# Let's enable scaling on our smaller option set and see what that looks like.
# Ellipses and label scaling is complicated, so let's just switch to dots for now.
#
# Scaling is done by node value.
# Each edge gives one value point to the nodes at either end.
# Each node's percentage of the total value of all nodes is used to place it on the range between min and max.

# %%
small_scale = {
    'edges': {
        'arrows': {
            'to': {
                'enabled': True,
                'scaleFactor': 0.5
            }
        },
        'color': {
            'color': 'grey',
            'highlight': '#404040'
        },
        'font': {
            'align': 'middle',
            'size': 14
        },
        'smooth': {
            'enabled': True,
            'type': 'dynamic'
        }
    },
    'nodes': {
        'font': {
            'size': '14'
        },
        'shape': 'dot',
        'size': 25,
        'scaling': {
            'min': 10,
            'max': 50
        }
    },
    'physics': {
        'enabled': True,
        'solver': 'repulsion'
    }
}

# %%
query="""
MATCH (a:Page {title: 'Neo4j'})<-->(b)
WITH COLLECT(b) AS left_set, COLLECT(b) as right_set
UNWIND left_set AS left
UNWIND right_set AS right
MATCH (left)-[r]->(right)
RETURN left_set, collect(r)
"""
data = graph.run(query).to_table()

# We only get one row back from our query
# The first element is a list of nodes, the second is our relationships
draw_nr(data[0][0], data[0][1], {'Page':'title'}, True, small_scale)
# Out:
# <div id="694c4c23-c73d-496b-8416-75bf35393a2e" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "ArangoDB", "group": "Page", "id": 11657601, "value": 10, "label": "ArangoDB"}, {"title": "Neo Technology", "group": "Page", "id": 6911747, "value": 0, "label": "Neo Technology"}, {"title": "Europe", "group": "Page", "id": 5656, "value": 5, "label": "Europe"}, {"title": "Graph database", "group": "Page", "id": 6596737, "value": 38, "label": "Graph database"}, {"title": "Intentional Software", "group": "Page", "id": 3876236, "value": 0, "label": "Intentional Software"}, {"title": "GPLv3", "group": "Page", "id": 1917072, "value": 0, "label": "GPLv3"}, {"title": "Linkurious", "group": "Page", "id": 12956440, "value": 2, "label": "Linkurious"}, {"title": "DB-Engines ranking", "group": "Page", "id": 13555986, "value": 2, "label": "DB-Engines ranking"}, {"title": "Connection pool", "group": "Page", "id": 1080067, "value": 0, "label": "Connection pool"}, {"title": "Remote backup service", "group": "Page", "id": 881262, "value": 0, "label": "Remote backup service"}, {"title": "United States", "group": "Page", "id": 1496086, "value": 7, "label": "United States"}, {"title": "Neo4J", "group": "Page", "id": 6911768, "value": 2, "label": "Neo4J"}, {"title": "Malm\u00f6", "group": "Page", "id": 12188, "value": 2, "label": "Malm\u00f6"}, {"title": "Java (programming language)", "group": "Page", "id": 10053, "value": 18, "label": "Java (programming language)"}, {"title": "Well-known text", "group": "Page", "id": 2283552, "value": 0, "label": "Well-known text"}, {"title": "OrientDB", "group": "Page", "id": 8241569, "value": 40, "label": "OrientDB"}, {"title": "Spring Framework", "group": "Page", "id": 2056612, "value": 5, "label": "Spring Framework"}, {"title": "Affero General Public License", "group": "Page", "id": 2438694, "value": 6, "label": "Affero General Public License"}, {"title": "NoSQL", "group": "Page", "id": 6400807, "value": 22, "label": "NoSQL"}, {"title": "Sweden", "group": "Page", "id": 1970728, "value": 3, "label": "Sweden"}, {"title": "FlockDB", "group": "Page", "id": 7059740, "value": 2, "label": "FlockDB"}, {"title": "AGPLv3", "group": "Page", "id": 6919349, "value": 0, "label": "AGPLv3"}, {"title": "North America", "group": "Page", "id": 13622, "value": 5, "label": "North America"}, {"title": "DataNucleus", "group": "Page", "id": 6247659, "value": 1, "label": "DataNucleus"}, {"title": "Hybrid transactional/analytical processing (HTAP)", "group": "Page", "id": 10861625, "value": 3, "label": "Hybrid transactional/analytical processing (HTAP)"}, {"title": "AllegroGraph", "group": "Page", "id": 7021627, "value": 10, "label": "AllegroGraph"}, {"title": "List of TCP and UDP port numbers", "group": "Page", "id": 219839, "value": 3, "label": "List of TCP and UDP port numbers"}, {"title": "Cypher Query Language", "group": "Page", "id": 10420416, "value": 14, "label": "Cypher Query Language"}, {"title": "CODASYL", "group": "Page", "id": 198304, "value": 3, "label": "CODASYL"}, {"title": "Query language", "group": "Page", "id": 302405, "value": 6, "label": "Query language"}, {"title": "Bolt (network protocol)", "group": "Page", "id": 12555532, "value": 1, "label": "Bolt (network protocol)"}, {"title": "List of JVM languages", "group": "Page", "id": 4350162, "value": 4, "label": "List of JVM languages"}, {"title": "Nikolaj Nyholm", "group": "Page", "id": 7546967, "value": 0, "label": "Nikolaj Nyholm"}, {"title": "Apache Giraph", "group": "Page", "id": 9539638, "value": 4, "label": "Apache Giraph"}, {"title": "Paradise Papers", "group": "Page", "id": 13418333, "value": 1, "label": "Paradise Papers"}, {"title": "Jelastic", "group": "Page", "id": 9836773, "value": 1, "label": "Jelastic"}, {"title": "Freemium", "group": "Page", "id": 2611238, "value": 0, "label": "Freemium"}, {"title": "ACID", "group": "Page", "id": 40550, "value": 5, "label": "ACID"}, {"title": "Comparison of structured storage software", "group": "Page", "id": 6630632, "value": 10, "label": "Comparison of structured storage software"}, {"title": " ...
# var edges = [{"from": 5656, "to": 13622, "title": "Europe -[Link]-> North America"}, {"from": 10053, "to": 4350162, "title": "Java (programming language) -[Link]-> List of JVM languages"}, {"from": 219839, "to": 8241569, "title": "List of TCP and UDP port numbers -[Link]-> OrientDB"}, {"from": 1826599, "to": 2438694, "title": "Spatial database -[Link]-> Affero General Public License"}, {"from": 1496086, "to": 5656, "title": "United States -[Link]-> Europe"}, {"from": 1826599, "to": 7021627, "title": "Spatial database -[Link]-> AllegroGraph"}, {"from": 13622, "to": 1496086, "title": "North America -[Link]-> United States"}, {"from": 8241569, "to": 8648946, "title": "OrientDB -[Link]-> Gremlin (programming language)"}, {"from": 8241569, "to": 10053, "title": "OrientDB -[Link]-> Java (programming language)"}, {"from": 9836773, "to": 10053, "title": "Jelastic -[Link]-> Java (programming language)"}, {"from": 8241569, "to": 40550, "title": "OrientDB -[Link]-> ACID"}, {"from": 4350162, "to": 10420416, "title": "List of JVM languages -[Link]-> Cypher Query Language"}, {"from": 5292782, "to": 1496086, "title": "San Francisco Bay Area -[Link]-> United States"}, {"from": 8241569, "to": 13555986, "title": "OrientDB -[Link]-> DB-Engines ranking"}, {"from": 1970728, "to": 12188, "title": "Sweden -[Link]-> Malm\u00f6"}, {"from": 11657601, "to": 6596737, "title": "ArangoDB -[Link]-> Graph database"}, {"from": 11657601, "to": 6400807, "title": "ArangoDB -[Link]-> NoSQL"}, {"from": 10053, "to": 2056612, "title": "Java (programming language) -[Link]-> Spring Framework"}, {"from": 8241569, "to": 6400807, "title": "OrientDB -[Link]-> NoSQL"}, {"from": 13622, "to": 5656, "title": "North America -[Link]-> Europe"}, {"from": 8241569, "to": 10420416, "title": "OrientDB -[Link]-> Cypher Query Language"}, {"from": 6247659, "to": 10053, "title": "DataNucleus -[Link]-> Java (programming language)"}, {"from": 9539638, "to": 10053, "title": "Apache Giraph -[Link]-> Java (programming language)"}, {"from": 8241569, "to": 6596737, "title": "OrientDB -[Link]-> Graph database"}, {"from": 302405, "to": 8648946, "title": "Query language -[Link]-> Gremlin (programming language)"}, {"from": 8379411, "to": 1496086, "title": "GameDuell -[Link]-> United States"}, {"from": 8241569, "to": 11657601, "title": "OrientDB -[Link]-> ArangoDB"}, {"from": 6400807, "to": 10420416, "title": "NoSQL -[Link]-> Cypher Query Language"}, {"from": 1496086, "to": 13622, "title": "United States -[Link]-> North America"}, {"from": 6596737, "to": 8648946, "title": "Graph database -[Link]-> Gremlin (programming language)"}, {"from": 219839, "to": 12555532, "title": "List of TCP and UDP port numbers -[Link]-> Bolt (network protocol)"}, {"from": 6596737, "to": 10053, "title": "Graph database -[Link]-> Java (programming language)"}, {"from": 7021627, "to": 8241569, "title": "AllegroGraph -[Link]-> OrientDB"}, {"from": 7059740, "to": 10053, "title": "FlockDB -[Link]-

# %% [markdown]
# ### <span style="background:yellow">Your Turn</span>
#
# Experiment with various configuration options on the page of your choosing.
# Shapes, colors, whatever you want.
# The documentation for nodes can be found [here](http://visjs.org/docs/network/nodes.html), and edges [here](http://visjs.org/docs/network/nodes.html).
# Global settings can be found [here](http://visjs.org/docs/network/edges.html), and you can experiment with physics [here](http://visjs.org/examples/network/physics/physicsConfiguration.html).
#
# You'll probably end up with a lot of JavaScript errors, but don't worry.
# Rerunning the cell should fix everything.
# JavaScript can be finnicky, and you may have had a typo in your settings dictionary.
#
# When in doubt, use the classic Control+Z keys in the code cell to undo changes!

# %%
# M4:P3:Q6

# Experiment with visualization settings and plot a page and its connections in the cell below.
# --------------------
my_options = {
    'edges': {
        'arrows': {
            'to': {
                'enabled': True,
                'scaleFactor': 0.5
            }
        },
        'color': {
              'color': 'red',
              'highlight': 'green',
        },
        'font': {
            'align': 'middle',
            'size': 14
        },
        'smooth': {
            'enabled': True,
            'type': 'dynamic'
        }
    },
    'nodes': {
        'font': {
            'background': 'white', 
            'size': '14'},
        'shape': 'dot',
        'size': 25,
        'scaling': {
            'min': 10,
            'max': 100
        }
    },
    'physics': {
        'enabled': False,
        'solver': 'repulsion'
    }
}

# %%
query="""
MATCH (a:Page {title: 'Neo4j'})<-->(b)
WITH COLLECT(b) AS left_set, COLLECT(b) as right_set
UNWIND left_set AS left
UNWIND right_set AS right
MATCH (left)-[r]->(right)
RETURN left_set, collect(r)
"""
data = graph.run(query).to_table()

draw_nr(data[0][0], data[0][1], {'Page':'title'}, True, my_options)
# Out:
# <div id="3494fcdd-eb64-4c4b-98e2-3de7055ddd7c" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "ArangoDB", "group": "Page", "id": 11657601, "value": 10, "label": "ArangoDB"}, {"title": "Neo Technology", "group": "Page", "id": 6911747, "value": 0, "label": "Neo Technology"}, {"title": "Europe", "group": "Page", "id": 5656, "value": 5, "label": "Europe"}, {"title": "Graph database", "group": "Page", "id": 6596737, "value": 38, "label": "Graph database"}, {"title": "Intentional Software", "group": "Page", "id": 3876236, "value": 0, "label": "Intentional Software"}, {"title": "GPLv3", "group": "Page", "id": 1917072, "value": 0, "label": "GPLv3"}, {"title": "Linkurious", "group": "Page", "id": 12956440, "value": 2, "label": "Linkurious"}, {"title": "DB-Engines ranking", "group": "Page", "id": 13555986, "value": 2, "label": "DB-Engines ranking"}, {"title": "Connection pool", "group": "Page", "id": 1080067, "value": 0, "label": "Connection pool"}, {"title": "Remote backup service", "group": "Page", "id": 881262, "value": 0, "label": "Remote backup service"}, {"title": "United States", "group": "Page", "id": 1496086, "value": 7, "label": "United States"}, {"title": "Neo4J", "group": "Page", "id": 6911768, "value": 2, "label": "Neo4J"}, {"title": "Malm\u00f6", "group": "Page", "id": 12188, "value": 2, "label": "Malm\u00f6"}, {"title": "Java (programming language)", "group": "Page", "id": 10053, "value": 18, "label": "Java (programming language)"}, {"title": "Well-known text", "group": "Page", "id": 2283552, "value": 0, "label": "Well-known text"}, {"title": "OrientDB", "group": "Page", "id": 8241569, "value": 40, "label": "OrientDB"}, {"title": "Spring Framework", "group": "Page", "id": 2056612, "value": 5, "label": "Spring Framework"}, {"title": "Affero General Public License", "group": "Page", "id": 2438694, "value": 6, "label": "Affero General Public License"}, {"title": "NoSQL", "group": "Page", "id": 6400807, "value": 22, "label": "NoSQL"}, {"title": "Sweden", "group": "Page", "id": 1970728, "value": 3, "label": "Sweden"}, {"title": "FlockDB", "group": "Page", "id": 7059740, "value": 2, "label": "FlockDB"}, {"title": "AGPLv3", "group": "Page", "id": 6919349, "value": 0, "label": "AGPLv3"}, {"title": "North America", "group": "Page", "id": 13622, "value": 5, "label": "North America"}, {"title": "DataNucleus", "group": "Page", "id": 6247659, "value": 1, "label": "DataNucleus"}, {"title": "Hybrid transactional/analytical processing (HTAP)", "group": "Page", "id": 10861625, "value": 3, "label": "Hybrid transactional/analytical processing (HTAP)"}, {"title": "AllegroGraph", "group": "Page", "id": 7021627, "value": 10, "label": "AllegroGraph"}, {"title": "List of TCP and UDP port numbers", "group": "Page", "id": 219839, "value": 3, "label": "List of TCP and UDP port numbers"}, {"title": "Cypher Query Language", "group": "Page", "id": 10420416, "value": 14, "label": "Cypher Query Language"}, {"title": "CODASYL", "group": "Page", "id": 198304, "value": 3, "label": "CODASYL"}, {"title": "Query language", "group": "Page", "id": 302405, "value": 6, "label": "Query language"}, {"title": "Bolt (network protocol)", "group": "Page", "id": 12555532, "value": 1, "label": "Bolt (network protocol)"}, {"title": "List of JVM languages", "group": "Page", "id": 4350162, "value": 4, "label": "List of JVM languages"}, {"title": "Nikolaj Nyholm", "group": "Page", "id": 7546967, "value": 0, "label": "Nikolaj Nyholm"}, {"title": "Apache Giraph", "group": "Page", "id": 9539638, "value": 4, "label": "Apache Giraph"}, {"title": "Paradise Papers", "group": "Page", "id": 13418333, "value": 1, "label": "Paradise Papers"}, {"title": "Jelastic", "group": "Page", "id": 9836773, "value": 1, "label": "Jelastic"}, {"title": "Freemium", "group": "Page", "id": 2611238, "value": 0, "label": "Freemium"}, {"title": "ACID", "group": "Page", "id": 40550, "value": 5, "label": "ACID"}, {"title": "Comparison of structured storage software", "group": "Page", "id": 6630632, "value": 10, "label": "Comparison of structured storage software"}, {"title": " ...
# var edges = [{"from": 5656, "to": 13622, "title": "Europe -[Link]-> North America"}, {"from": 10053, "to": 4350162, "title": "Java (programming language) -[Link]-> List of JVM languages"}, {"from": 219839, "to": 8241569, "title": "List of TCP and UDP port numbers -[Link]-> OrientDB"}, {"from": 1826599, "to": 2438694, "title": "Spatial database -[Link]-> Affero General Public License"}, {"from": 1496086, "to": 5656, "title": "United States -[Link]-> Europe"}, {"from": 1826599, "to": 7021627, "title": "Spatial database -[Link]-> AllegroGraph"}, {"from": 13622, "to": 1496086, "title": "North America -[Link]-> United States"}, {"from": 8241569, "to": 8648946, "title": "OrientDB -[Link]-> Gremlin (programming language)"}, {"from": 8241569, "to": 10053, "title": "OrientDB -[Link]-> Java (programming language)"}, {"from": 9836773, "to": 10053, "title": "Jelastic -[Link]-> Java (programming language)"}, {"from": 8241569, "to": 40550, "title": "OrientDB -[Link]-> ACID"}, {"from": 4350162, "to": 10420416, "title": "List of JVM languages -[Link]-> Cypher Query Language"}, {"from": 5292782, "to": 1496086, "title": "San Francisco Bay Area -[Link]-> United States"}, {"from": 8241569, "to": 13555986, "title": "OrientDB -[Link]-> DB-Engines ranking"}, {"from": 1970728, "to": 12188, "title": "Sweden -[Link]-> Malm\u00f6"}, {"from": 11657601, "to": 6596737, "title": "ArangoDB -[Link]-> Graph database"}, {"from": 11657601, "to": 6400807, "title": "ArangoDB -[Link]-> NoSQL"}, {"from": 10053, "to": 2056612, "title": "Java (programming language) -[Link]-> Spring Framework"}, {"from": 8241569, "to": 6400807, "title": "OrientDB -[Link]-> NoSQL"}, {"from": 13622, "to": 5656, "title": "North America -[Link]-> Europe"}, {"from": 8241569, "to": 10420416, "title": "OrientDB -[Link]-> Cypher Query Language"}, {"from": 6247659, "to": 10053, "title": "DataNucleus -[Link]-> Java (programming language)"}, {"from": 9539638, "to": 10053, "title": "Apache Giraph -[Link]-> Java (programming language)"}, {"from": 8241569, "to": 6596737, "title": "OrientDB -[Link]-> Graph database"}, {"from": 302405, "to": 8648946, "title": "Query language -[Link]-> Gremlin (programming language)"}, {"from": 8379411, "to": 1496086, "title": "GameDuell -[Link]-> United States"}, {"from": 8241569, "to": 11657601, "title": "OrientDB -[Link]-> ArangoDB"}, {"from": 6400807, "to": 10420416, "title": "NoSQL -[Link]-> Cypher Query Language"}, {"from": 1496086, "to": 13622, "title": "United States -[Link]-> North America"}, {"from": 6596737, "to": 8648946, "title": "Graph database -[Link]-> Gremlin (programming language)"}, {"from": 219839, "to": 12555532, "title": "List of TCP and UDP port numbers -[Link]-> Bolt (network protocol)"}, {"from": 6596737, "to": 10053, "title": "Graph database -[Link]-> Java (programming language)"}, {"from": 7021627, "to": 8241569, "title": "AllegroGraph -[Link]-> OrientDB"}, {"from": 7059740, "to": 10053, "title": "FlockDB -[Link]-

# %% [markdown]
# ---
# Let's take a look at all the pages and two hops from `Toudai temple`, in either direction, and their interconnections.
# You may recall that [Toudai temple](https://en.wikipedia.org/wiki/T%C5%8Ddai-ji) was in our link analysis lab as a page with the fewest links.
# Let's see if we can see what's going on.
#
# **Note:** The number of links explodes beyond 2 hops, so be careful with your visualization choices!

# %%
from timeit import default_timer as timer
from copy import deepcopy
query="""
MATCH (a:Page {title: 'Toudai temple'})<-[*1..2]->(b)
WITH COLLECT(DISTINCT b)+a AS left_set, COLLECT(DISTINCT b)+a as right_set
UNWIND left_set AS left
UNWIND right_set AS right
MATCH (left)-[r]->(right)
RETURN left_set, collect(r)
"""
begin = timer()
data = graph.run(query).to_table()
end = timer()
print(end-begin)

# Copying complex, nested dictionaries can get messy, let's get our own fresh copy.
medium_options = deepcopy(large_options)
# Let's dial down the scaling a bit
medium_options['nodes']['scaling']['min'] = 10
medium_options['nodes']['scaling']['max'] = 50
medium_options['nodes']['scaling']['label']['min'] = 12
medium_options['nodes']['scaling']['label']['max'] = 24


draw_nr(data[0][0], data[0][1], {'Page':'title'}, False, medium_options)
# Out:
# 1.626289292005822
# <div id="df5ece44-3c93-4db4-9b3a-79271e98a340" style="height: 600px;"></div>
# <script type="text/javascript">
# var nodes = [{"title": "List of H\u014dry\u016b-ji Treasures at Tokyo National Museum", "group": "Page", "id": 11253767, "value": 8, "label": "List of H\u014dry\u016b-ji Treasures at Tokyo National Museum"}, {"title": "756", "group": "Page", "id": 22982, "value": 6, "label": "756"}, {"title": "Nara Great Buddha", "group": "Page", "id": 2549769, "value": 1, "label": "Nara Great Buddha"}, {"title": "List of National Treasures of Japan (temples)", "group": "Page", "id": 6012426, "value": 42, "label": "List of National Treasures of Japan (temples)"}, {"title": "Sh\u014dr\u014d", "group": "Page", "id": 7562253, "value": 7, "label": "Sh\u014dr\u014d"}, {"title": "Folktales from Japan", "group": "Page", "id": 8955918, "value": 3, "label": "Folktales from Japan"}, {"title": "T\u014dfuku-ji", "group": "Page", "id": 3226641, "value": 17, "label": "T\u014dfuku-ji"}, {"title": "Toudai Temple", "group": "Page", "id": 1675011, "value": 1, "label": "Toudai Temple"}, {"title": "Nara University of Education", "group": "Page", "id": 4225044, "value": 6, "label": "Nara University of Education"}, {"title": "List of National Treasures of Japan (sculptures)", "group": "Page", "id": 6148117, "value": 48, "label": "List of National Treasures of Japan (sculptures)"}, {"title": "Kamakura period", "group": "Page", "id": 140310, "value": 61, "label": "Kamakura period"}, {"title": "Ganjin", "group": "Page", "id": 548888, "value": 8, "label": "Ganjin"}, {"title": "Saich\u014d", "group": "Page", "id": 283674, "value": 30, "label": "Saich\u014d"}, {"title": "Brahmajala Sutra (Mahayana)", "group": "Page", "id": 4361246, "value": 12, "label": "Brahmajala Sutra (Mahayana)"}, {"title": "Toudai temple", "group": "Page", "id": 1675013, "value": 1, "label": "Toudai temple"}, {"title": "Kusha (Buddhism)", "group": "Page", "id": 8856098, "value": 4, "label": "Kusha (Buddhism)"}, {"title": "Tenpy\u014d-sh\u014dh\u014d", "group": "Page", "id": 3688483, "value": 9, "label": "Tenpy\u014d-sh\u014dh\u014d"}, {"title": "Japanese art", "group": "Page", "id": 155175, "value": 37, "label": "Japanese art"}, {"title": "Mount Hiei", "group": "Page", "id": 283690, "value": 19, "label": "Mount Hiei"}, {"title": "Buddh\u0101bhiseka", "group": "Page", "id": 4876039, "value": 5, "label": "Buddh\u0101bhiseka"}, {"title": "Todaiji", "group": "Page", "id": 1344556, "value": 1, "label": "Todaiji"}, {"title": "Mus\u014d Soseki", "group": "Page", "id": 2175533, "value": 10, "label": "Mus\u014d Soseki"}, {"title": "Ruyi (scepter)", "group": "Page", "id": 2331182, "value": 7, "label": "Ruyi (scepter)"}, {"title": "8th century in architecture", "group": "Page", "id": 1566114, "value": 7, "label": "8th century in architecture"}, {"title": "Timeline of Japanese history", "group": "Page", "id": 3550258, "value": 22, "label": "Timeline of Japanese history"}, {"title": "Great Buddha of Nara", "group": "Page", "id": 2549767, "value": 2, "label": "Great Buddha of Nara"}, {"title": "Outline of Japan", "group": "Page", "id": 4564532, "value": 21, "label": "Outline of Japan"}, {"title": "Todai-ji Temple", "group": "Page", "id": 1675017, "value": 1, "label": "Todai-ji Temple"}, {"title": "Pindola Bharadvaja", "group": "Page", "id": 5025848, "value": 3, "label": "Pindola Bharadvaja"}, {"title": "Nio", "group": "Page", "id": 436793, "value": 19, "label": "Nio"}, {"title": "Todaiji Buddha", "group": "Page", "id": 230503, "value": 1, "label": "Todaiji Buddha"}, {"title": "Empress Michiko", "group": "Page", "id": 180635, "value": 6, "label": "Empress Michiko"}, {"title": "Mokoshi", "group": "Page", "id": 6682293, "value": 6, "label": "Mokoshi"}, {"title": "Bodhisena", "group": "Page", "id": 350272, "value": 15, "label": "Bodhisena"}, {"title": "Bell tower", "group": "Page", "id": 366145, "value": 6, "label": "Bell tower"}, {"title": "Kakuban", "group": "Page", "id": 4838978, "value": 9, "label": "Kakuban"}, {"title": "Vairocana", "group": "Page", "id": 284744, "value": 26, "label": "Vairocana"}, {"title": "Li ...

# %% [markdown]
# These connections get pretty messy!
# Notice that eight redirect pages place themselves on top of the node for `Tōdai-ji`, and one of them is `Toudai temple`!
#
# Nothing links to `Toudai temple`, it must be around to help with searches.
# `ō` isn't very easy to type on an English keyboard!
# There may still be links to the other redirects we aren't seeing, but nothing within two hops link to them.
#
# Even though we searched for everything one to two hops away, in reality we only got `Tōdai-ji` and everything attached to it, which is why it's at the center.

# %% [markdown]
# # Save your notebook, then `File > Close and Halt`

# %% [markdown]
# ---
